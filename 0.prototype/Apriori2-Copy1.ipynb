# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. 키워드 추출
#
# #### [2-1) 텍스트 데이터 전처리]

# %% [raw]
# # csv파일 불러오기
# df = pd.read_csv('tweet_temp4.csv')
# df.head()

# %% [raw]
# import re
#
# # 텍스트 정제 함수 : 할글 이외의 문자는 전부 제거
# def text_cleaning(text):
#     hangul = re.compile('[^ㄱ-ㅣ가-힣]+') #한글의 정규표현식을 나타냅니다.
#     result = hangul.sub('', text)
#     return result

# %% [raw]
# # 'tweet_text' 피처에 이를 적용합니다.
# df['ko_text'] = df['본문'].apply(lambda x: text_cleaning(x))
# df.head()

# %% [markdown]
# #### [2-2) KoNLPy를 이용한 키워드 추출 (형태소 분석기)]
# #### 한국어 약식 불용어 사전 사용 (http://ranks.nl/stopwords/korean)

# %%
df = pd.read_csv('news_data_ori_0701_0705_sample.csv')
df.head()
# Out:
#                                                   본문  \
# 0   인천해양경찰서(서장 신동삼)는 도서 지역 치안 강화를 위해 인천 중부경찰서와 지난...
# 1   작년말 대비 두 배 가까이 늘어 지난달 26일 하룻새 4조 급증 SK바이오팜 청약...
# 2   ［중부매일 서인석 기자］ 이차영 괴산군수가 1일 열린 직원조회에서 민선 7기 2년...
# 3   라임자산운용(라임)의 1조6000억원 펀드 환매 중단 사건을 수사 중인 검찰이 1...
# 4   시모네타 소마루가 스위스 대통령 [EPA=연합뉴스 자료사진] . (제네바=연합뉴스...
#
#                                                  형태소
# 0   인천해양경찰/NNG 서/JKB (/SS 서장/NNG 신동삼/NNG )/SS 는/J...
# 1   작년/NNG 말/NNB 대비/NNG 두/MM 배/NNG 가까이/MAG 늘/VV 어...
# 2   ［/SL 중부매/NNG 이/VCP ㄹ/ETM 서인석/NNP 기자/NNG ］/SL ...
# 3   라임자산운/NNG 용/XSN (/SS 라임/NNG )/SS 의/JKG 1/SN 조...
# 4   시모네/NNG 하/XSA 다/EC 소마루/NNG 가/JKS 스위스/NNP 대통령/...

# %%
# csv파일 불러오기
df = pd.read_csv('news_data_ori_0701_0705_sample.csv')
df.head()

print(df)


from konlpy.tag import Okt
from collections import Counter
from IPython.display import clear_output


korean_stopwords_path = './korean_stopwords.txt'
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]

nouns_cnt = 1
count_data = []

def get_nouns(x):
    global nouns_cnt, count_data
    
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(x)
    count_data.extend([y for y in nouns])
#     count_data.extend([z for y in nouns for z in y])

    #한글자 키워드를 제거합니다.
#     nouns = [noun for noun in nouns if len(noun) > 1]

    #불용어를 제거합니다.
    nouns = [noun for noun in nouns if noun not in stopwords]

    clear_output(wait=True)
    print(f'형태소,불용어 제거중 .. {round((nouns_cnt / df.shape[0])*100,3)} %')
    nouns_cnt+=1
    
    return nouns
# Out:
#                                                    본문  \
# 0    인천해양경찰서(서장 신동삼)는 도서 지역 치안 강화를 위해 인천 중부경찰서와 지난...
# 1    작년말 대비 두 배 가까이 늘어 지난달 26일 하룻새 4조 급증 SK바이오팜 청약...
# 2    ［중부매일 서인석 기자］ 이차영 괴산군수가 1일 열린 직원조회에서 민선 7기 2년...
# 3    라임자산운용(라임)의 1조6000억원 펀드 환매 중단 사건을 수사 중인 검찰이 1...
# 4    시모네타 소마루가 스위스 대통령 [EPA=연합뉴스 자료사진] . (제네바=연합뉴스...
# 5    [서울=뉴스핌] 정경환 기자 = 질병관리본부는 코로나19 치료제로 특례 수입된 '...
# 6    농림축산식품부 주최로 지난달 30일 세종 컨벤션센터에서 펼쳐진 ‘제1회 농식품 수...
# 7    viewer . 미래통합당 주호영 원내대표가 1일 오후 국회 원내대표회의실에서 비...
# 8    금융감독원이 2018년 11월 이후 은행·증권사 등 판매사들이 판매한 라임자산운용...
# 9    증권·은행팀 = 금융감독원이 2018년 11월 이후 라임자산운용 플루토 TF-1호...
# 10   한진칼이 발행을 추진하고 있는 신주인수권부사채(BW)가 인기몰이에 성공했다. 만기...
# 11   노은주·임형남 ㅣ 가온건축 공동대표 설계사무소를 개업한 초창기에 작은 시골집을 설...
# 12   대전선병원은 1일 54주년을 맞아 '언제나 제약 없이 최선의 진료 제공'이라는 비...
# 13   가수 신용재가 1일 오후 서울 마포구 서교동 하나투어 브이홀에서 열린 첫 번째 정...
# 14   민관 협력 수소경제 컨트롤 타워 '수소경제위원회' 출범 총리 주재로 정의선 수석부...
# 15   [송대익 유튜브 캡처] . [사진=유튜브 채널 '정배우:사건사고 이슈'] . 송대...
# 16   지난해 7월 1일 일본 정부가 한국에 대한 수출규제 조치를 단행하자, 일본 지식인...
# 17   [앵커] . 1조 6천억 원의 투자금 환매 중단사태를 빚은 라임 사모펀드와 관련해...
# 18   ‘인국공’은 인천국제공항의 약자다. 이 말이 유명해진 것은 최근 비정규직이었던 인...
# 19   7월1일부터 규제지역에서 주택담보대출을 받아 집을 사려면 6개월 안에 새로운 집에...
# 20   전대넷, 서울중앙지법 앞 기자회견 "등심위도 결산 내역 공유 못 받아" 상반기 등...
# 21   국립대전현충원은 7월의 현충인물로 박재권·남궁선·김기봉 이등중사를 선정했다. 이들...
# 22   가수 신용재가 1일 오후 서울 마포구 서교동 하나투어 브이홀에서 열린 첫 번째 정...
# 23   유럽연합(EU)이 한국에 대해 입국 제한을 해제한 1일 인천국제공항 출국장 전광판...
# 24   제주참여환경연대는 제주도의회가 교육의원제도에 대한 의견서를 헌법재판소에 제출한 것...
# 25   대전에서 초등학생이 잇따라 신종 코로나바이러스 감염증(코로나19) 양성 판정을 받...
# 26   [앵커] . 코로나19 확진자 동선이 나오면서 불안한 마음에 선별 진료소를 찾는 ...
# 27   ▲ 뮤지엄산 본관에서 명상관으로 향햐는 야외 길[강원도민일보 자료사진] [강원도민...
# 28   대전시 중구 박용갑 청장은 1일 중구보건소에 위치한 선별진료소 위킹스루 현장 방문...
# 29   전자신문과 금융AI전문기업 씽크풀의 증시분석 전문기자 로봇 ET가 쓴 기사입니다 ...
#
#                                                   형태소
# 0    인천해양경찰/NNG 서/JKB (/SS 서장/NNG 신동삼/NNG )/SS 는/J...
# 1    작년/NNG 말/NNB 대비/NNG 두/MM 배/NNG 가까이/MAG 늘/VV 어...
# 2    ［/SL 중부매/NNG 이/VCP ㄹ/ETM 서인석/NNP 기자/NNG ］/SL ...
# 3    라임자산운/NNG 용/XSN (/SS 라임/NNG )/SS 의/JKG 1/SN 조...
# 4    시모네/NNG 하/XSA 다/EC 소마루/NNG 가/JKS 스위스/NNP 대통령/...
# 5    [/SS 서울/NNP =/SW 뉴스핌/NNG ]/SS 정경환/NNG 기자/NNG ...
# 6    농림축산식품부/NNG 주최/NNG 로/JKB 지난달/NNG 30/SN 일/NNB ...
# 7    viewer/SL ./SF 미래통합/NNG 당/XSN 주호영/NNG 원내대표/NN...
# 8    금융감독원/NNG 이/JKS 2018/SN 년/NNB 11/SN 월/NNB 이후/...
# 9    증권/NNG ·/SP 은행팀/NNG =/SW 금융감독원/NNG 이/JKS 2018...
# 10   한진칼/NNG 이/JKS 발행/NNG 을/JKO 추진/NNG 하/XSV 고/EC ...
# 11   노은주/NNG ·/SP 임형남/NNG ㅣ/NNG 가온건축/NNG 공동대표/NNG ...
# 12   대전선병원/NNG 은/JX 1/SN 일/NR 54/SN 주년/NNB 을/JKO 맞...
# 13   가수/NNG 신용재/NNP 가/JKS 1/SN 일/NNB 오후/NNG 서울/NNP...
# 14   민관/NNG 협력/NNG 수소경/NNG 제/XSN 컨트롤/NNG 타/VV 어/EC...
# 15   [/SS 송대익/NNG 유튜브/NNG 캡처/NNG ]/SS ./SF [/SS 사진...
# 16   지난해/NNG 7/SN 월/NNB 1/SN 일/NNB 일본/NNP 정부/NNG 가...
# 17   [/SS 앵커/NNG ]/SS ./SF 1/SN 조/NNB 6/SN 천억/NR 원...
# 18   ‘/SS 인국공/NNP ’/SS 은/JX 인천국제공항/NNP 의/JKG 약자/NN...
# 19   7/SN 월/NNB 1/SN 일/NNB 부터/JX 규제지역/NNG 에서/JKB 주...
# 20   전대넷/NNG ,/SP 서울중앙지법/NNG 앞/NNG 기자회견/NNG "/SS 등...
# 21   국립대전현충원/NNG 은/JX 7/SN 월/NNB 의/JKG 현충인물/NNG 로/...
# 22   가수/NNG 신용재/NNP 가/JKS 1/SN 일/NNB 오후/NNG 서울/NNP...
# 23   유럽연합/NNP (/SS EU/SL )/SS 이/JKS 한국/NNP 에/JKB 대...
# 24   제주참여환경연/NNG 대/NNB 는/JX 제주도의회/NNG 가/JKS 교육의원제도...
# 25   대전/NNP 에서/JKB 초등학생/NNG 이/JKS 잇따르/VV 아/EC 신종/N...
# 26   [/SS 앵커/NNG ]/SS ./SF 코로나/NNG 19/SN 확진/NNG 이/...
# 27   ▲/SW 뮤지엄/NNG 산/XSN 본관/NNG 에서/JKB 명상관/NNG 으로/J...
# 28   대전시/NNP 중구/NNP 박용갑/NNP 청장/NNG 은/JX 1/SN 일/NNB...
# 29   전자신문/NNG 과/JC 금융/NNG AI/SL 전문기업/NNG 씽크풀/NNG 의...

# %%
# df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
df['nouns'] = df['본문'].apply(lambda x: get_nouns(x))
print(df.shape)
df.head()
# Out:
# 형태소,불용어 제거중 .. 100.0 %
# (30, 3)
#                                                   본문  \
# 0   인천해양경찰서(서장 신동삼)는 도서 지역 치안 강화를 위해 인천 중부경찰서와 지난...
# 1   작년말 대비 두 배 가까이 늘어 지난달 26일 하룻새 4조 급증 SK바이오팜 청약...
# 2   ［중부매일 서인석 기자］ 이차영 괴산군수가 1일 열린 직원조회에서 민선 7기 2년...
# 3   라임자산운용(라임)의 1조6000억원 펀드 환매 중단 사건을 수사 중인 검찰이 1...
# 4   시모네타 소마루가 스위스 대통령 [EPA=연합뉴스 자료사진] . (제네바=연합뉴스...
#
#                                                  형태소  \
# 0   인천해양경찰/NNG 서/JKB (/SS 서장/NNG 신동삼/NNG )/SS 는/J...
# 1   작년/NNG 말/NNB 대비/NNG 두/MM 배/NNG 가까이/MAG 늘/VV 어...
# 2   ［/SL 중부매/NNG 이/VCP ㄹ/ETM 서인석/NNP 기자/NNG ］/SL ...
# 3   라임자산운/NNG 용/XSN (/SS 라임/NNG )/SS 의/JKG 1/SN 조...
# 4   시모네/NNG 하/XSA 다/EC 소마루/NNG 가/JKS 스위스/NNP 대통령/...
#
#                                                nouns
# 0  [인천, 해양경찰, 서장, 신동, 도서, 지역, 치안, 강화, 위해, 인천, 중부,...
# 1  [작년, 말, 대비, 두, 배, 가까이, 지난달, 룻새, 급증, 바이오, 청약, 뭉...
# 2  [중부, 매일, 서인석, 기자, 차영, 괴산군, 수가, 직원, 조회, 민선, 기, ...
# 3  [라임, 자산운용, 라임, 펀드, 환매, 중단, 사건, 수사, 중인, 검찰, 신한은...
# 4  [시모네타, 마루, 스위스, 대통령, 연합뉴스, 자료, 사진, 제네바, 연합뉴스, ...

# %%
#빈도 수 구하기.

# count_data = [y for x in df['nouns'].tolist() for y in x]

from collections import Counter
count = Counter(count_data)

node_df = pd.DataFrame(count.items(), columns=['node', 'nodesize'])
# node_df = node_df[node_df['nodesize'] >= 50]

# 형태소 데이터 / csv파일로 저장
df.to_csv('save/tmp_data2.csv', index=False)
# 카운트 데이터 / csv파일로 저장
node_df.to_csv('save/tmp_count2.csv', index=False)

node_df.head()
# Out:
#    node  nodesize
# 0    인천         7
# 1  해양경찰         1
# 2    서장         1
# 3    신동         1
# 4     삼         1

# %%
from ast import literal_eval

# df = pd.read_csv('save/tmp_data2.csv')
df = pd.read_csv('save/tmp_data2.csv', converters={'nouns': eval})
# df = pd.read_csv('save/tmp_data2.csv', converters={'nouns': literal_eval}) # 주영씨 복사
# df = pd.read_csv('save/tmp_data2.csv', converters={'nouns': literal_eval}) # 직접작성

# node_df = pd.read_csv('save/tmp_count2.csv')

# %%
df['nouns'].tolist()
# Out:
# [['인천',
#   '해양경찰',
#   '서장',
#   '신동',
#   '도서',
#   '지역',
#   '치안',
#   '강화',
#   '위해',
#   '인천',
#   '중부',
#   '경찰서',
#   '지난달',
#   '업무',
#   '협약',
#   '체결',
#   '여름철',
#   '수기',
#   '치안',
#   '수요',
#   '증가',
#   '예상',
#   '도서',
#   '지역',
#   '특성',
#   '상',
#   '한정',
#   '근무',
#   '인원',
#   '현장',
#   '조치',
#   '대응',
#   '어려움',
#   '해경',
#   '육경',
#   '협조',
#   '체제',
#   '구축',
#   '위해',
#   '업무',
#   '협약',
#   '관할',
#   '구역',
#   '내',
#   '긴급',
#   '상황',
#   '발생',
#   '시',
#   '상호',
#   '인력',
#   '장비',
#   '지원',
#   '업무',
#   '사례',
#   '공유',
#   '데',
#   '협력',
#   '해경',
#   '관계자',
#   '업무',
#   '협약',
#   '육경',
#   '협조',
#   '체제',
#   '구축',
#   '치안',
#   '공백',
#   '최소',
#   '한편',
#   '지속',
#   '업무',
#   '개선',
#   '도서',
#   '지역',
#   '주민',
#   '편익',
#   '증진',
#   '위해',
#   '노력',
#   '고',
#   '말',
#   '인천',
#   '일보'],
#  ['작년',
#   '말',
#   '대비',
#   '두',
#   '배',
#   '가까이',
#   '지난달',
#   '룻새',
#   '급증',
#   '바이오',
#   '청약',
#   '뭉칫돈',
#   '유입',
#   '기관',
#   '외국인',
#   '팔면',
#   '매수',
#   '개미',
#   '시장',
#   '도세',
#   '부상',
#   '국내',
#   '증시',
#   '투자자',
#   '탁금',
#   '규모',
#   '사상',
#   '처음',
#   '지난해',
#   '말',
#   '수준',
#   '탁',
#   '금은',
#   '개월',
#   '약',
#   '두',
#   '배',
#   '불어',
#   '상반기',
#   '개인',
#   '투자자',
#   '코로나',
#   '발',
#   '폭락',
#   '계기',
#   '국내',
#   '주식시장',
#   '매수',
#   '반기',
#   '기준',
#   '역대',
#   '최고',
#   '치',
#   '매수',
#   '기록',
#   '증시',
#   '자금',
#   '개인',
#   '지속',
#   '투자',
#   '기회',
#   '노리',
#   '때문',
#   '풀이',
#   '올해',
#   '기업',
#   '공개',
#   '최대',
#   '유망',
#   '주인',
#   '바이오',
#   '일반',
#   '투자자',
#   '대상',
#   '모주',
#   '청약',
#   '증시',
#   '주변',
#   '자금',
#   '남아',
#   '뭉칫돈',
#   '향방',
#   '시장',
#   '눈길',
#   '상반기',
#   '주식',
#   '개인',
#   '금융투자',
#   '협회',
#   '지난',
#   '기준',
#   '투자자',
#   '탁',
#   '금은',
#   '기록',
#   '탁금',
#   '관련',
#   '통계',
#   '집계',
#   '이후',
#   '처음',
#   '투자자',
#   '탁',
#   '금은',
#   '증시',
#   '투입',
#   '수',
#   '자금',
#   '분류',
#   '지난해',
#   '말',
#   '해도',
#   '수준',
#   '탁',
#   '금은',
#   '서서히',
#   '증가',
#   '코로나',
#   '사태',
#   '증시',
#   '폭락',
#   '기점',
#   '불어',
#   '최근',
#   '후반',
#   '유지',
#   '탁',
#   '금은',
#   '다시',
#   '하루',
#   '사이',
#   '급증',
#   '증권',
#   '바이오',
#   '모주',
#   '배정',
#   '이후',
#   '청약',
#   '증거',
#   '금',
#   '환',
#   '불금',
#   '날',
#   '입금',
#   '영향',
#   '보고',
#   '일반',
#   '투자자',
#   '대상',
#   '바이오',
#   '청약',
#   '달',
#   '증거',
#   '금',
#   '역대',
#   '최대',
#   '기록',
#   '경쟁률',
#   '주식',
#   '배정',
#   '못',
#   '대부분',
#   '증거',
#   '금',
#   '환불',
#   '중',
#   '상당',
#   '금액',
#   '주식시장',
#   '주변',
#   '설명',
#   '개인',
#   '상반기',
#   '돈',
#   '국내',
#   '주식시장',
#   '유가',
#   '증권',
#   '시장',
#   '코스닥',
#   '코넥스',
#   '시장',
#   '합치',
#   '개인',
#   '국내',
#   '주식',
#   '매수',
#   '규모',
#   '달',
#   '기간',
#   '기관',
#   '외국인',
#   '매도',
#   '대조',
#   '개인',
#   '매수',
#   '사상',
#   '첫',
#   '개월',
#   '연속',
#   '매수',
#   '기록',
#   '탁',
#   '금은',
#   '두',
#   '배',
#   '증시',
#   '자금',
#   '향',
#   '인지',
#   '관심',
#   '바이오',
#   '청약',
#   '나선',
#   '신규',
#   '투자자',
#   '중',
#   '상당수',
#   '환불',
#   '증거',
#   '금',
#   '통해',
#   '주식',
#   '투자',
#   '가능성',
#   '겨냥',
#   '한국',
#   '투자',
#   '증권',
#   '바이오',
#   '청약',
#   '참여',
#   '영업',
#   '점',
#   '거래',
#   '고객',
#   '대상',
#   '펀드',
#   '가연',
#   '증권',
#   '가입',
#   '경우',
#   '현금',
#   '지급',
#   '이벤트',
#   '걸',
#   '기도',
#   '개인',
#   '지수',
#   '하락',
#   '매수',
#   '규모',
#   '하방',
#   '지지',
#   '주체',
#   '코스피지수',
#   '하락',
#   '세',
#   '개인',
#   '매수',
#   '외국인',
#   '기관',
#   '주식',
#   '개인',
#   '지수',
#   '틈',
#   '타',
#   '시장',
#   '패턴',
#   '반복',
#   '달',
#   '기관',
#   '매도',
#   '외국인',
#   '지난',
#   '달',
#   '매도',
#   '규모',
#   '축소',
#   '시장',
#   '급',
#   '상장',
#   '줄줄이',
#   '예정',
#   '쪽',
#   '뭉칫돈',
#   '가능성',
#   '제기',
#   '방탄소년단',
#   '소속사',
#   '빅히트',
#   '엔터테인먼트',
#   '카카오',
#   '게임',
#   '솔루엠',
#   '최근',
#   '상장',
#   '예비',
#   '심사',
#   '청구',
#   '하반기',
#   '모주',
#   '청약',
#   '예정',
#   '게임',
#   '테라',
#   '초대',
#   '급',
#   '크래프톤',
#   '블루홀',
#   '도',
#   '하반기',
#   '상장',
#   '예정',
#   '콘텐츠',
#   '대장',
#   '주로',
#   '관심',
#   '카카오페이지',
#   '하반기',
#   '내년',
#   '상장',
#   '준비',
#   '이진우',
#   '메',
#   '리츠',
#   '증권',
#   '연구원',
#   '최근',
#   '개인',
#   '투자자',
#   '열풍',
#   '유가',
#   '증권',
#   '시장',
#   '시가총액',
#   '대비',
#   '탁금',
#   '비율',
#   '기록',
#   '후반',
#   '고',
#   '분석',
#   '후반',
#   '시장',
#   '변동성',
#   '인터넷',
#   '보급',
#   '홈',
#   '트레이딩',
#   '서비스',
#   '개발',
#   '시장',
#   '참여',
#   '코로나',
#   '모바일',
#   '트레이딩',
#   '서비스',
#   '금융',
#   '플랫폼',
#   '이동',
#   '가속',
#   '개인',
#   '주식시장',
#   '접근성',
#   '설명',
#   '연구원',
#   '기술',
#   '진보',
#   '질병',
#   '자산',
#   '가격',
#   '급락',
#   '세',
#   '가지',
#   '요소',
#   '물리',
#   '시장',
#   '환경',
#   '고',
#   '분석'],
#  ['중부',
#   '매일',
#   '서인석',
#   '기자',
#   '차영',
#   '괴산군',
#   '수가',
#   '직원',
#   '조회',
#   '민선',
#   '기',
#   '군정',
#   '성과',
#   '후반기',
#   '군정',
#   '운영',
#   '방향',
#   '군수',
#   '민선',
#   '기',
#   '반기',
#   '마무리',
#   '후반기',
#   '시작',
#   '며',
#   '지난',
#   '여러',
#   '가지',
#   '어려움',
#   '속',
#   '성과',
#   '낼',
#   '수',
#   '군정',
#   '힘',
#   '주신',
#   '공무원',
#   '괴산',
#   '군민',
#   '깊이',
#   '감사',
#   '고',
#   '말',
#   '올해',
#   '상반기',
#   '코로나',
#   '대응',
#   '방역',
#   '활동',
#   '봄철',
#   '산불',
#   '예방',
#   '활동',
#   '총선',
#   '준비',
#   '코로나',
#   '지원',
#   '책',
#   '마련',
#   '추진',
#   '중고',
#   '겹',
#   '더욱',
#   '시기',
#   '며',
#   '위기',
#   '속',
#   '군민',
#   '공무원',
#   '하나로',
#   '극복',
#   '수',
#   '며',
#   '고마움',
#   '전',
#   '지난',
#   '반기',
#   '괴산',
#   '미래',
#   '수립',
#   '괴산',
#   '구체',
#   '미래',
#   '마련',
#   '역대',
#   '최대',
#   '규모',
#   '투자',
#   '유치',
#   '달성',
#   '정부',
#   '예산',
#   '확보',
#   '재정',
#   '기반',
#   '구축',
#   '고',
#   '군수',
#   '재정',
#   '기반',
#   '바탕',
#   '실행',
#   '확보',
#   '지속',
#   '발전',
#   '미래',
#   '기반',
#   '토대',
#   '고',
#   '강조',
#   '괴산',
#   '정신',
#   '정립',
#   '괴산',
#   '사랑',
#   '운동',
#   '적극',
#   '전개',
#   '통한',
#   '군민',
#   '간',
#   '소통',
#   '화합',
#   '문화',
#   '조성',
#   '지역',
#   '안정화',
#   '성과',
#   '고',
#   '군수',
#   '후반기',
#   '군정',
#   '운영',
#   '방향',
#   '제시',
#   '군수',
#   '후반기',
#   '지난',
#   '기반',
#   '바탕',
#   '가시',
#   '지역',
#   '발전',
#   '총력',
#   '며',
#   '위해',
#   '사업',
#   '별',
#   '진도',
#   '관리',
#   '말',
#   '미래',
#   '먹거리',
#   '창',
#   '위',
#   '농업',
#   '관광',
#   '제조',
#   '산업',
#   '분야',
#   '중점',
#   '육성',
#   '라며',
#   '의료',
#   '폐기물',
#   '소각',
#   '건립',
#   '청정',
#   '환경',
#   '저해',
#   '요소',
#   '천적',
#   '차단',
#   '적극',
#   '고',
#   '괴산읍',
#   '기능',
#   '구심력',
#   '정주',
#   '여건',
#   '개선',
#   '위',
#   '사업',
#   '적극',
#   '추진',
#   '며',
#   '단',
#   '명도',
#   '소외',
#   '촘촘',
#   '맞춤',
#   '복지',
#   '실현',
#   '보훈',
#   '단체',
#   '우도',
#   '국가',
#   '위해',
#   '헌신',
#   '더욱',
#   '우대',
#   '수',
#   '문화',
#   '조성',
#   '고',
#   '마지막',
#   '군수',
#   '공무원',
#   '역량',
#   '조직',
#   '군민',
#   '적극',
#   '소통',
#   '군민',
#   '행정',
#   '구현',
#   '며',
#   '공무원',
#   '지역',
#   '거주',
#   '실제',
#   '군민',
#   '호흡',
#   '지역',
#   '동화',
#   '수',
#   '달라',
#   '고',
#   '당부',
#   '한편',
#   '코로나',
#   '예방',
#   '위해',
#   '개월',
#   '개최',
#   '날',
#   '직원',
#   '조회',
#   '참석',
#   '인원',
#   '최소',
#   '발열',
#   '체크',
#   '손',
#   '소독',
#   '참석자',
#   '명단',
#   '기재',
#   '방역',
#   '칙',
#   '진행'],
#  ['라임',
#   '자산운용',
#   '라임',
#   '펀드',
#   '환매',
#   '중단',
#   '사건',
#   '수사',
#   '중인',
#   '검찰',
#   '신한은행',
#   '압수수색',
#   '남부',
#   '검',
#   '형사',
#   '부',
#   '부장',
#   '검사',
#   '조상원',
#   '날',
#   '오전',
#   '서울',
#   '중구',
#   '신한은행',
#   '본점',
#   '사관',
#   '저장',
#   '자료',
#   '관련',
#   '서류',
#   '크레디트',
#   '인',
#   '슈어드',
#   '호',
#   '펀드',
#   '판매',
#   '관련',
#   '자료',
#   '확보',
#   '중이',
#   '신한은행',
#   '펀드',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '부실',
#   '투',
#   '자금',
#   '위해',
#   '설정',
#   '상품',
#   '사실',
#   '투자자',
#   '판매',
#   '혐의',
#   '자본시장',
#   '금융투자',
#   '업',
#   '관',
#   '법률상',
#   '기적',
#   '부정',
#   '거래',
#   '불건전',
#   '영업',
#   '행위',
#   '신한은행',
#   '지난해',
#   '약',
#   '가량',
#   '라임',
#   '펀드',
#   '고객',
#   '판매',
#   '은행',
#   '당시',
#   '펀드',
#   '대해',
#   '해외',
#   '무역',
#   '금융',
#   '관련',
#   '매출채권',
#   '투자',
#   '원금',
#   '이자',
#   '대해',
#   '신용',
#   '보험',
#   '가입',
#   '상품',
#   '소개',
#   '펀드',
#   '중',
#   '자금',
#   '플루토',
#   '호',
#   '플루토',
#   '부실',
#   '발생',
#   '플루토',
#   '무역',
#   '금융',
#   '펀드',
#   '투입',
#   '플루토',
#   '무역',
#   '금융',
#   '펀드',
#   '현재',
#   '환매',
#   '중단',
#   '라임',
#   '개',
#   '펀드',
#   '중',
#   '펀드',
#   '투자자',
#   '명',
#   '지난',
#   '신한은행',
#   '기적',
#   '부정',
#   '거래',
#   '혐의',
#   '데',
#   '지난달',
#   '펀드',
#   '불건전',
#   '영업',
#   '행위',
#   '관련',
#   '혐의',
#   '추가',
#   '차로',
#   '신한은행',
#   '펀드',
#   '규모',
#   '현행법',
#   '규제',
#   '법망',
#   '피',
#   '주장',
#   '검찰',
#   '날',
#   '확보',
#   '압수',
#   '물',
#   '내용',
#   '분석',
#   '뒤',
#   '관련',
#   '차례',
#   '조사',
#   '계획'],
#  ['시모네타',
#   '마루',
#   '스위스',
#   '대통령',
#   '연합뉴스',
#   '자료',
#   '사진',
#   '제네바',
#   '연합뉴스',
#   '임은진',
#   '특파원',
#   '스위스',
#   '정부',
#   '대중교통',
#   '마스크',
#   '착용',
#   '의무',
#   '시모네타',
#   '마루',
#   '대통령',
#   '오후',
#   '현지',
#   '베른',
#   '기자',
#   '회견',
#   '시행',
#   '스위스',
#   '정부',
#   '위험',
#   '지역',
#   '스위스',
#   '입국',
#   '개인',
#   '대해',
#   '격리',
#   '의무',
#   '광고',
#   '스위스',
#   '유럽',
#   '국가',
#   '달리',
#   '코로나',
#   '사태',
#   '발생',
#   '이후',
#   '지금',
#   '마스크',
#   '착용',
#   '의무',
#   '최근',
#   '봉쇄',
#   '조치',
#   '달',
#   '완화',
#   '국경',
#   '개방',
#   '확',
#   '진자',
#   '수가',
#   '다시',
#   '증가',
#   '결정',
#   '연방',
#   '공중보건',
#   '청',
#   '전체',
#   '인구',
#   '스위스',
#   '코로나',
#   '누적',
#   '확',
#   '진자',
#   '날',
#   '현재',
#   '명',
#   '전날',
#   '명',
#   '증가',
#   '전날',
#   '신규',
#   '확',
#   '진자',
#   '명',
#   '비교',
#   '두',
#   '배',
#   '누적',
#   '사망자',
#   '명',
#   '전날',
#   '명'],
#  ['서울',
#   '뉴스',
#   '정경환',
#   '기자',
#   '질병',
#   '관리',
#   '본부',
#   '코로나',
#   '치료',
#   '제로',
#   '특례',
#   '수입',
#   '렘데',
#   '시비르',
#   '공급',
#   '고',
#   '지난',
#   '식품의약품안전처',
#   '특례',
#   '수입',
#   '결정',
#   '후',
#   '질',
#   '수입',
#   '길리',
#   '드',
#   '스코리아',
#   '국내',
#   '도입',
#   '협의',
#   '통해',
#   '지난',
#   '의약품',
#   '무상',
#   '공급',
#   '계약',
#   '체결',
#   '도입',
#   '물량',
#   '대해',
#   '길리어드',
#   '계약',
#   '조건',
#   '비공개',
#   '특례수입',
#   '감염병',
#   '대유행',
#   '공중보건',
#   '위기',
#   '상황',
#   '대처',
#   '위해',
#   '관계',
#   '부처',
#   '요청',
#   '식약처',
#   '국내',
#   '허가',
#   '의약품',
#   '수입',
#   '통해',
#   '수입',
#   '제도',
#   '렘데',
#   '시비르',
#   '투약',
#   '수',
#   '환자',
#   '폐렴',
#   '산소',
#   '치료',
#   '중증',
#   '환자',
#   '제한',
#   '중증',
#   '환자',
#   '치료',
#   '병원',
#   '국립',
#   '중앙',
#   '의료',
#   '의약품',
#   '공급',
#   '요청',
#   '국립',
#   '중앙',
#   '의료',
#   '필요',
#   '시',
#   '신종',
#   '감염병',
#   '중앙',
#   '임',
#   '위원회',
#   '자문',
#   '요청',
#   '투약',
#   '대상자',
#   '결정',
#   '용량',
#   '투여',
#   '기간',
#   '바이',
#   '알',
#   '투여',
#   '원칙',
#   '필요',
#   '시',
#   '연장',
#   '전체',
#   '투여',
#   '기간',
#   '최대',
#   '정은경',
#   '질',
#   '본부장',
#   '렘데',
#   '시비르',
#   '추가',
#   '물량',
#   '확보',
#   '위해',
#   '국내',
#   '수입',
#   '길리',
#   '드',
#   '스코리아',
#   '계속',
#   '협력',
#   '치료',
#   '확보',
#   '최선',
#   '달',
#   '무상',
#   '공급',
#   '물량',
#   '확보',
#   '이후',
#   '가격',
#   '협상',
#   '통한',
#   '구매',
#   '계획'],
#  ['농림축산식품부',
#   '주최',
#   '지난달',
#   '세종',
#   '컨벤션',
#   '센터',
#   '농',
#   '식품',
#   '수출',
#   '우수',
#   '지방자치단체',
#   '경진',
#   '대회',
#   '북도',
#   '광역',
#   '자치',
#   '단체',
#   '부',
#   '최우수상',
#   '김천시',
#   '기초',
#   '자치',
#   '단체',
#   '부',
#   '대상',
#   '상주시',
#   '청도군',
#   '우수상',
#   '차지',
#   '전국',
#   '개',
#   '수상',
#   '자치',
#   '단체',
#   '중',
#   '개',
#   '경북',
#   '농',
#   '식품',
#   '수출',
#   '정책',
#   '전국',
#   '최고',
#   '임',
#   '증명',
#   '경진',
#   '대회',
#   '전국',
#   '자치',
#   '단체',
#   '중',
#   '예선',
#   '통과',
#   '개',
#   '지자체',
#   '광역',
#   '기초',
#   '지난달',
#   '차',
#   '대국민',
#   '호감',
#   '평가',
#   '지난달',
#   '차',
#   '전문가',
#   '평가',
#   '통해',
#   '최종',
#   '선정',
#   '북도',
#   '수출',
#   '확대',
#   '위',
#   '개념',
#   '과일',
#   '종이',
#   '트',
#   '레이',
#   '개발',
#   '우수',
#   '높이',
#   '김천시',
#   '망',
#   '고향이',
#   '샤인',
#   '머스켓',
#   '수출',
#   '전략',
#   '품목',
#   '육성',
#   '중국',
#   '동남아',
#   '중심',
#   '괄목',
#   '만',
#   '수출',
#   '증대',
#   '평가',
#   '상주시',
#   '해외',
#   '지인',
#   '접근',
#   '수',
#   '고안',
#   '노출',
#   '대화',
#   '미니',
#   '홍보',
#   '관',
#   '운영',
#   '포도',
#   '곶감',
#   '홍보',
#   '효과',
#   '청도군',
#   '수출',
#   '유망',
#   '품목',
#   '감',
#   '말랭이',
#   '신규',
#   '수출',
#   '상품',
#   '개발',
#   '수출',
#   '확대',
#   '기여',
#   '점',
#   '호평',
#   '경북',
#   '도의',
#   '개념',
#   '과일',
#   '트',
#   '레이',
#   '사과',
#   '유통',
#   '과정',
#   '사용',
#   '발포',
#   '폴리에틸렌',
#   '스티로폼',
#   '트레이',
#   '압상',
#   '눌림',
#   '상처',
#   '문제',
#   '기능',
#   '종이',
#   '대체',
#   '획기',
#   '해결',
#   '함',
#   '수출',
#   '과일',
#   '품질',
#   '유지',
#   '수',
#   '최근',
#   '국내외',
#   '친환경',
#   '정책',
#   '확산',
#   '향후',
#   '보급',
#   '증가',
#   '기대',
#   '한편',
#   '북도',
#   '지속',
#   '농',
#   '식품',
#   '수출',
#   '시책',
#   '추진',
#   '통해',
#   '수준',
#   '농',
#   '식품',
#   '수출',
#   '실적',
#   '돌파',
#   '지난해',
#   '연속',
#   '초과',
#   '달성',
#   '성과'],
#  ['미래',
#   '통합',
#   '주호영',
#   '원내대표',
#   '오후',
#   '국회',
#   '원내대표',
#   '회의실',
#   '비공개',
#   '율',
#   '출신',
#   '의원',
#   '회의',
#   '관련',
#   '브리핑',
#   '뒤',
#   '퇴장',
#   '주',
#   '원내대표',
#   '날',
#   '가슴',
#   '규탄',
#   '민주당',
#   '민주주의',
#   '붕괴',
#   '리본',
#   '연합뉴스',
#   '과거',
#   '세월호',
#   '사고',
#   '교통사고',
#   '던',
#   '주호영',
#   '미래',
#   '통합',
#   '원내대표',
#   '국회',
#   '세월호',
#   '여론',
#   '민주당',
#   '주',
#   '원내대표',
#   '국회',
#   '세월호',
#   '데',
#   '대해',
#   '착오',
#   '인식',
#   '고',
#   '비판',
#   '박성준',
#   '민주당',
#   '대변인',
#   '날',
#   '논평',
#   '통해',
#   '통합',
#   '세월호',
#   '참사',
#   '언급',
#   '자격',
#   '며',
#   '민생',
#   '외면',
#   '통합',
#   '모습',
#   '승객',
#   '안전',
#   '홀로',
#   '세월호',
#   '선장',
#   '모습',
#   '중첩',
#   '고',
#   '지적',
#   '지금',
#   '미래',
#   '통합',
#   '박근혜',
#   '정부',
#   '탄생',
#   '기여',
#   '과거',
#   '새누리당',
#   '모습',
#   '고',
#   '주',
#   '원내대표',
#   '날',
#   '오전',
#   '소셜네트워크서비스',
#   '폭주',
#   '기관차',
#   '개문',
#   '발차',
#   '세월호',
#   '글',
#   '국회',
#   '추미애',
#   '법무',
#   '장관',
#   '얘기',
#   '통제',
#   '폭주',
#   '기관차',
#   '며',
#   '폭주',
#   '열차',
#   '세월호',
#   '고',
#   '주장',
#   '개문',
#   '발차',
#   '국회',
#   '수렁',
#   '처',
#   '폭주',
#   '세월호',
#   '항해',
#   '맹골수도',
#   '생명',
#   '희생',
#   '채',
#   '침몰',
#   '고',
#   '지난',
#   '오후',
#   '경기도',
#   '안산시',
#   '단원구',
#   '화랑유원지',
#   '세월호',
#   '참사',
#   '주기',
#   '기억',
#   '사회',
#   '거리',
#   '두기',
#   '일환',
#   '의자',
#   '일정',
#   '간격',
#   '연합뉴스',
#   '주',
#   '원내대표',
#   '지난',
#   '새누리당',
#   '정책',
#   '위',
#   '의장',
#   '시절',
#   '당',
#   '최고',
#   '위원',
#   '회의',
#   '당시',
#   '야당',
#   '새정치',
#   '민주',
#   '연합',
#   '세월호',
#   '특별법',
#   '협상',
#   '과정',
#   '대해',
#   '설명',
#   '도중',
#   '새누리당',
#   '입장',
#   '기본',
#   '사고',
#   '교통사고',
#   '주장',
#   '사람',
#   '희생',
#   '케이스',
#   '재판',
#   '절차',
#   '간소',
#   '하자',
#   '국가',
#   '보상',
#   '배상금',
#   '전액',
#   '대납',
#   '국가',
#   '나중',
#   '절차',
#   '청해진해운',
#   '세월호',
#   '특별법',
#   '설계',
#   '라며',
#   '그것',
#   '해도',
#   '일반',
#   '사고',
#   '비',
#   '특례',
#   '규정',
#   '지적',
#   '주',
#   '원내대표',
#   '지난',
#   '달',
#   '원내대표',
#   '경선',
#   '토론회',
#   '지금',
#   '소신',
#   '전혀',
#   '고',
#   '답',
#   '강',
#   '병원',
#   '민주당',
#   '의원',
#   '주',
#   '원내대표',
#   '소신',
#   '납득',
#   '수',
#   '소신',
#   '유가족',
#   '아픔',
#   '기억',
#   '추모',
#   '국민',
#   '수',
#   '상처',
#   '주더',
#   '세월호',
#   '거론',
#   '국회',
#   '원',
#   '구성',
#   '저주',
#   '고',
#   '비판',
#   '도대체',
#   '세월호',
#   '정',
#   '쟁의',
#   '도구로',
#   '상대',
#   '정파',
#   '비난',
#   '수단',
#   '악용',
#   '강',
#   '의원',
#   '세월호',
#   '참사',
#   '책임',
#   '정당',
#   '일원',
#   '안전',
#   '사회',
#   '건설',
#   '성찰',
#   '동참',
#   '인식',
#   '소신',
#   '양',
#   '비유',
#   '양',
#   '포장',
#   '고',
#   '주',
#   '원내대표',
#   '비판',
#   '정의당',
#   '배진교',
#   '원내대표',
#   '가운데',
#   '국회',
#   '의원',
#   '총회',
#   '발언',
#   '연합뉴스',
#   '정의당',
#   '비판',
#   '행렬',
#   '가세',
#   '김종철',
#   '선임',
#   '대변인',
#   '국회',
#   '상황',
#   '세월호',
#   '침몰',
#   '유가족',
#   '예의',
#   '라며',
#   '주',
#   '원내대표',
#   '발언',
#   '취소',
#   '사과',
#   '하라',
#   '고',
#   '김',
#   '선',
#   '입대',
#   '변인',
#   '비판',
#   '금도',
#   '라며',
#   '지금',
#   '상황',
#   '마음',
#   '비판',
#   '해도',
#   '유가족',
#   '마음',
#   '대못',
#   '수도',
#   '세월호',
#   '침몰',
#   '꼭',
#   '질문',
#   '실제',
#   '지난',
#   '박근혜',
#   '정권',
#   '미래',
#   '통합',
#   '전신',
#   '새누리당',
#   '알',
#   '통합',
#   '세월호',
#   '대해',
#   '지금',
#   '세월호',
#   '걱정',
#   '척',
#   '실제',
#   '대못',
#   '행위',
#   '누가',
#   '주호영',
#   '원내대표',
#   '발언',
#   '이해해',
#   '줄',
#   '수',
#   '말',
#   '정의당',
#   '주',
#   '원내대표',
#   '발언',
#   '철회',
#   '유족',
#   '대한',
#   '사과',
#   '요구'],
#  ['금융감독원',
#   '이후',
#   '은행',
#   '증권사',
#   '판매',
#   '판매',
#   '라임',
#   '자산운용',
#   '무역',
#   '금융',
#   '펀드',
#   '플루토',
#   '호',
#   '분쟁',
#   '조정',
#   '건',
#   '대해',
#   '투자',
#   '원금',
#   '전액',
#   '투자자',
#   '반환',
#   '결정',
#   '금감원',
#   '금융',
#   '분쟁',
#   '조정',
#   '위원회',
#   '분조',
#   '위',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '분쟁',
#   '조정',
#   '신청',
#   '건',
#   '대해',
#   '착오',
#   '계약',
#   '취소',
#   '결론',
#   '분쟁',
#   '조정',
#   '과정',
#   '계약',
#   '취소',
#   '원금',
#   '반환',
#   '결정',
#   '처음',
#   '분조',
#   '위',
#   '계약',
#   '체결',
#   '시점',
#   '펀드',
#   '투자',
#   '원금',
#   '최대',
#   '달',
#   '손실',
#   '발생',
#   '상황',
#   '운용',
#   '투자',
#   '제안',
#   '수익률',
#   '투자',
#   '위험',
#   '핵심',
#   '정보',
#   '허위',
#   '부실',
#   '기재',
#   '며',
#   '판매',
#   '투자',
#   '제안',
#   '내용',
#   '그대로',
#   '설명',
#   '함',
#   '투자자',
#   '착오',
#   '유발',
#   '고',
#   '분조',
#   '위',
#   '판매',
#   '자의',
#   '허위',
#   '투자',
#   '정보',
#   '설명',
#   '투자자',
#   '성향',
#   '임의',
#   '기재',
#   '손실',
#   '보전',
#   '각서',
#   '작성',
#   '합리',
#   '투자',
#   '판단',
#   '기회',
#   '박탈',
#   '점',
#   '고려',
#   '투자자',
#   '중과실',
#   '보기',
#   '판단',
#   '사기',
#   '착오',
#   '계약',
#   '취소',
#   '판단',
#   '향후',
#   '라임',
#   '운용',
#   '사태',
#   '관련',
#   '법원',
#   '판단',
#   '결론',
#   '날',
#   '때문',
#   '원금',
#   '배상',
#   '전례',
#   '수준',
#   '해외',
#   '금리',
#   '계',
#   '파생',
#   '결합',
#   '펀드',
#   '사태',
#   '당시',
#   '분쟁',
#   '조정',
#   '투자',
#   '손실',
#   '최대',
#   '배상하',
#   '결정',
#   '금감원',
#   '분조',
#   '위',
#   '결정',
#   '내용',
#   '개인',
#   '명',
#   '법인',
#   '개사',
#   '대해',
#   '최대',
#   '원',
#   '보상',
#   '전망'],
#  ['증권',
#   '은행',
#   '팀',
#   '금융감독원',
#   '이후',
#   '라임',
#   '자산운용',
#   '플루토',
#   '호',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '가입',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '결정',
#   '리자',
#   '펀드',
#   '판',
#   '은행',
#   '증권사',
#   '정안',
#   '수용',
#   '검토',
#   '조정',
#   '대상',
#   '이후',
#   '판매',
#   '분만',
#   '개별',
#   '은행',
#   '증권사',
#   '억원',
#   '규모',
#   '플루토',
#   '호',
#   '판',
#   '은행',
#   '경우',
#   '자금',
#   '여력',
#   '이의',
#   '정안',
#   '관측',
#   '금감원',
#   '분쟁',
#   '조정',
#   '위원회',
#   '날',
#   '환매',
#   '중단',
#   '플루토',
#   '호',
#   '관련',
#   '건의',
#   '분쟁',
#   '대해',
#   '판매',
#   '이후',
#   '펀드',
#   '산',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '조정',
#   '결정',
#   '투자자',
#   '계약',
#   '체결',
#   '시점',
#   '펀드',
#   '투자',
#   '원금',
#   '기준',
#   '최대',
#   '손실',
#   '발생',
#   '상황',
#   '운용',
#   '투자',
#   '제안',
#   '수익률',
#   '허위',
#   '부실',
#   '기재',
#   '판매',
#   '사도',
#   '내용',
#   '그대로',
#   '설명',
#   '투자자',
#   '착오',
#   '유발',
#   '이유',
#   '조정',
#   '안이',
#   '결정',
#   '건의',
#   '경우',
#   '판매',
#   '우리은행',
#   '하나은행',
#   '금융투자',
#   '미래에셋',
#   '대우',
#   '우리은행',
#   '분쟁',
#   '조정',
#   '결정',
#   '문',
#   '접수',
#   '후',
#   '내부',
#   '의사결정',
#   '과정',
#   '수락',
#   '결정',
#   '예정',
#   '공식',
#   '입장',
#   '하나은행',
#   '분쟁',
#   '정위',
#   '결정',
#   '검토',
#   '은행',
#   '수',
#   '범위',
#   '내',
#   '최대한',
#   '투자자',
#   '보호',
#   '위',
#   '의사결정',
#   '고',
#   '말',
#   '금융투자',
#   '관계자',
#   '부적',
#   '검토',
#   '결정',
#   '계획',
#   '이사회',
#   '결정',
#   '나기',
#   '주일',
#   '정도',
#   '설명',
#   '미래에셋',
#   '대우',
#   '분쟁',
#   '정결',
#   '정문',
#   '수령',
#   '고객',
#   '입장',
#   '고려',
#   '해당',
#   '내용',
#   '검토',
#   '예정',
#   '결정',
#   '문',
#   '보통',
#   '안',
#   '해당',
#   '기관',
#   '통지',
#   '기관',
#   '결정',
#   '문',
#   '통지',
#   '이후',
#   '안',
#   '분쟁',
#   '조정',
#   '수용',
#   '결정',
#   '조정',
#   '이의',
#   '제기',
#   '절차',
#   '수락',
#   '유서',
#   '제출',
#   '수',
#   '분조',
#   '위',
#   '건의',
#   '분쟁',
#   '관',
#   '조정',
#   '결정',
#   '분조',
#   '위',
#   '이후',
#   '가입',
#   '투자자',
#   '제기',
#   '분쟁',
#   '조정',
#   '신청',
#   '건수',
#   '건',
#   '가운데',
#   '대표',
#   '유형',
#   '사례',
#   '건',
#   '심의',
#   '결정',
#   '이기',
#   '때문',
#   '사실',
#   '이후',
#   '플루토',
#   '가입',
#   '모든',
#   '투자자',
#   '원금',
#   '전액',
#   '결정',
#   '플루토',
#   '호',
#   '펀드',
#   '판매',
#   '액',
#   '가운데',
#   '말',
#   '이후',
#   '판매',
#   '규모',
#   '정도',
#   '지금',
#   '중도',
#   '환매',
#   '금액',
#   '개인',
#   '명',
#   '법인',
#   '개사',
#   '분쟁',
#   '조정',
#   '대상',
#   '오른',
#   '셈',
#   '은행권',
#   '수',
#   '원대',
#   '개별',
#   '은행',
#   '판매',
#   '액',
#   '이후',
#   '규모',
#   '판매',
#   '은행',
#   '조정',
#   '결정',
#   '가능성',
#   '관측',
#   '판매',
#   '사가',
#   '건의',
#   '분조',
#   '위',
#   '결정',
#   '수용',
#   '나머지',
#   '투자자',
#   '판매',
#   '반환',
#   '위',
#   '자율',
#   '조정',
#   '절차',
#   '반환',
#   '정안',
#   '판매',
#   '해도',
#   '이전',
#   '플루토',
#   '가입',
#   '투자자',
#   '반환',
#   '대상',
#   '은행',
#   '관계자',
#   '이후',
#   '은행',
#   '판매',
#   '플루토',
#   '호의',
#   '경우',
#   '은행',
#   '운용',
#   '설명',
#   '진위',
#   '제대로',
#   '확인',
#   '못',
#   '판매',
#   '측면',
#   '때문',
#   '조정',
#   '결정',
#   '가능성',
#   '며',
#   '이전',
#   '해당',
#   '펀드',
#   '은행권',
#   '취급',
#   '소수',
#   '판매',
#   '사례',
#   '불완전',
#   '판매',
#   '보기',
#   '게',
#   '은행',
#   '판단',
#   '만큼',
#   '일괄',
#   '반환',
#   '증권사',
#   '경우',
#   '이전',
#   '판매',
#   '규모',
#   '개별',
#   '회사',
#   '수',
#   '천억원',
#   '경우',
#   '만큼',
#   '더욱',
#   '일괄',
#   '반환',
#   '난색',
#   '가능성',
#   '상황'],
#  ['한진',
#   '칼',
#   '발행',
#   '추진',
#   '신주인수권',
#   '부',
#   '사채',
#   '인기',
#   '몰이',
#   '만기',
#   '금리',
#   '비교',
#   '금리',
#   '신주인수권',
#   '행사',
#   '가가',
#   '현',
#   '주가',
#   '대비',
#   '경영',
#   '분쟁',
#   '진행',
#   '중인',
#   '까닭',
#   '개인',
#   '투자자',
#   '중심',
#   '향후',
#   '차익',
#   '실현',
#   '대감',
#   '겹',
#   '강',
#   '성부',
#   '펀드',
#   '비롯',
#   '주주',
#   '연합',
#   '측은',
#   '청약',
#   '참여',
#   '반면',
#   '조원태',
#   '한진',
#   '그룹',
#   '회장',
#   '일가',
#   '불참',
#   '기사',
#   '참전',
#   '주목',
#   '한진',
#   '칼',
#   '발행',
#   '주간',
#   '사인',
#   '유진',
#   '투자',
#   '증권',
#   '규모',
#   '발행',
#   '청약',
#   '개인',
#   '기관',
#   '청약',
#   '증거',
#   '금',
#   '몰리',
#   '최종',
#   '경쟁률',
#   '기록',
#   '신용등급',
#   '전망',
#   '부정',
#   '펀더',
#   '멘털',
#   '대비',
#   '한진',
#   '칼',
#   '주가',
#   '기관',
#   '참여',
#   '상대',
#   '주주',
#   '연합',
#   '측은',
#   '신주인수권',
#   '확보',
#   '위해',
#   '직접',
#   '청약',
#   '반면',
#   '조',
#   '회장',
#   '일가',
#   '청약',
#   '불참',
#   '전언',
#   '관건',
#   '조',
#   '회장',
#   '기사',
#   '투자자',
#   '참여',
#   '기관',
#   '투자가',
#   '참여',
#   '조건',
#   '전략',
#   '제휴',
#   '관계',
#   '염두',
#   '기업',
#   '투자자',
#   '기사',
#   '가능성'],
#  ['노은주',
#   '임',
#   '형남',
#   '가온',
#   '건축',
#   '공동',
#   '대표',
#   '설계',
#   '사무소',
#   '개업',
#   '초창',
#   '기',
#   '시골',
#   '집',
#   '설계',
#   '일이',
#   '집',
#   '땅',
#   '우물',
#   '여러',
#   '가지',
#   '사정',
#   '상황',
#   '그냥',
#   '흙',
#   '시멘트',
#   '방법',
#   '여러',
#   '가지',
#   '궁리',
#   '마침',
#   '이웃',
#   '어르신',
#   '조언',
#   '우물',
#   '먼저',
#   '돌',
#   '위로',
#   '돌',
#   '자갈',
#   '순서',
#   '흙',
#   '래야',
#   '땅',
#   '아래',
#   '물의',
#   '길',
#   '물',
#   '원래',
#   '길',
#   '가게',
#   '사람',
#   '위',
#   '살',
#   '이야기',
#   '사실',
#   '말',
#   '자연',
#   '조화',
#   '이지',
#   '막상',
#   '방법',
#   '실행',
#   '모습',
#   '적',
#   '별로',
#   '무척',
#   '말',
#   '점',
#   '이후',
#   '생각',
#   '내',
#   '책상',
#   '머리',
#   '항상',
#   '인간',
#   '스스로',
#   '무척',
#   '생각',
#   '과학',
#   '기술',
#   '이면',
#   '화성',
#   '이건',
#   '수',
#   '자부',
#   '룻',
#   '저녁',
#   '비',
#   '도로',
#   '물',
#   '잠기',
#   '옹벽',
#   '인명',
#   '피해',
#   '속출',
#   '속수무책',
#   '순간',
#   '세찬',
#   '바람',
#   '집들이',
#   '자동차',
#   '매년',
#   '인간',
#   '자연',
#   '통제',
#   '활용',
#   '수',
#   '정신승리',
#   '구가',
#   '자연',
#   '늘',
#   '길',
#   '간다',
#   '자연',
#   '보호',
#   '자연',
#   '비',
#   '존재',
#   '인간',
#   '살기',
#   '위해',
#   '파악',
#   '자연',
#   '타협',
#   '그게',
#   '길이',
#   '풍수',
#   '알',
#   '자연',
#   '대한',
#   '두려움',
#   '시작',
#   '자연',
#   '방법',
#   '모색',
#   '도선국사',
#   '무학대사',
#   '생각',
#   '한국',
#   '풍수',
#   '사상',
#   '더욱',
#   '돈',
#   '아들',
#   '장수',
#   '술법',
#   '자연',
#   '대한',
#   '외가',
#   '뼈대',
#   '환경',
#   '친',
#   '화란',
#   '소위',
#   '친환경',
#   '자재',
#   '무',
#   '농약',
#   '농산물',
#   '대한',
#   '선호',
#   '자연',
#   '대한',
#   '인간',
#   '자세',
#   '인간',
#   '오만',
#   '탐욕',
#   '대한',
#   '고등',
#   '여러',
#   '번',
#   '외면',
#   '포클레인',
#   '위',
#   '흙',
#   '콘크리트',
#   '옹벽',
#   '집',
#   '기술',
#   '강의',
#   '물길',
#   '산',
#   '허리',
#   '길',
#   '가책',
#   '두려움',
#   '세상',
#   '가장',
#   '공생',
#   '윤리',
#   '부정',
#   '면역',
#   '체계',
#   '파괴',
#   '탐욕',
#   '바이러스',
#   '전',
#   '세상',
#   '생태',
#   '운동',
#   '김종철',
#   '선생',
#   '칼럼',
#   '메시지',
#   '더욱',
#   '절실'],
#  ['전선',
#   '병원',
#   '주년',
#   '제약',
#   '최선',
#   '진료',
#   '제공',
#   '선포',
#   '선',
#   '병원',
#   '병상',
#   '선정',
#   '외과의',
#   '시작',
#   '현재',
#   '개',
#   '전문',
#   '진료',
#   '센터',
#   '개',
#   '진료',
#   '명의',
#   '전문',
#   '의료',
#   '진',
#   '종합병원',
#   '이규',
#   '은',
#   '선',
#   '병원',
#   '재단',
#   '관원',
#   '모든',
#   '제약',
#   '최선',
#   '진료',
#   '병원',
#   '사명',
#   '바탕',
#   '환자',
#   '며',
#   '하루',
#   '변화',
#   '세상',
#   '의료',
#   '환경',
#   '속',
#   '시대',
#   '요구',
#   '변화',
#   '부응',
#   '환자',
#   '배려',
#   '문화',
#   '병원',
#   '수',
#   '노력',
#   '고',
#   '포부'],
#  ['가수',
#   '신용재',
#   '오후',
#   '서울',
#   '마포구',
#   '서교동',
#   '하나투어',
#   '브이',
#   '홀',
#   '첫',
#   '정규',
#   '앨범',
#   '디어',
#   '발매',
#   '기념',
#   '쇼케이스',
#   '참석',
#   '신곡'],
#  ['민관',
#   '협력',
#   '수소',
#   '경제',
#   '컨트롤',
#   '타워',
#   '위원회',
#   '출범',
#   '총리',
#   '주재',
#   '정의선',
#   '수석',
#   '부회장',
#   '명의',
#   '위원',
#   '임명',
#   '위촉',
#   '정',
#   '총리',
#   '수소차',
#   '보조금',
#   '부품',
#   '국산',
#   '투자',
#   '폭',
#   '지원',
#   '정',
#   '수석',
#   '부회장',
#   '정책',
#   '지원',
#   '요청',
#   '산업',
#   '발전',
#   '가능성',
#   '아시아',
#   '경제',
#   '우수',
#   '연',
#   '기자',
#   '김지희',
#   '기자',
#   '대한민국',
#   '경제',
#   '컨트롤',
#   '타워',
#   '위원회',
#   '출범',
#   '정세균',
#   '국무총리',
#   '정의선',
#   '현대',
#   '자동차',
#   '그룹',
#   '총괄',
#   '수석',
#   '부회장',
#   '민관',
#   '핵심',
#   '인사',
#   '위원',
#   '참여',
#   '위원회',
#   '경제',
#   '실현',
#   '위',
#   '정책',
#   '산업',
#   '발전',
#   '역할',
#   '담당',
#   '날',
#   '모빌리티',
#   '쇼',
#   '조직',
#   '위원회',
#   '민관',
#   '참여',
#   '위원회',
#   '일산',
#   '킨텍스',
#   '출범',
#   '경제',
#   '관련',
#   '정책',
#   '현안',
#   '논의',
#   '세계',
#   '최초',
#   '수소',
#   '모빌리티',
#   '전시회',
#   '모빌리티',
#   '쇼',
#   '개막',
#   '일정',
#   '출범',
#   '위원회',
#   '범',
#   '정부',
#   '차원',
#   '수소',
#   '에너지',
#   '컨트롤',
#   '타워',
#   '일원화',
#   '수소',
#   '경제',
#   '정책',
#   '마련',
#   '초석',
#   '기대',
#   '위원회',
#   '정',
#   '총리',
#   '비롯',
#   '개',
#   '부처',
#   '장관',
#   '정부',
#   '위원',
#   '정',
#   '수석',
#   '부회장',
#   '산업',
#   '학계',
#   '임명',
#   '명의',
#   '민간',
#   '위원',
#   '구성',
#   '날',
#   '첫',
#   '회의',
#   '위원',
#   '대한',
#   '위촉',
#   '수여',
#   '상견례',
#   '자리',
#   '수소',
#   '산업',
#   '생태계',
#   '조성',
#   '방안',
#   '전담',
#   '기관',
#   '지정',
#   '구체',
#   '방안',
#   '논의',
#   '위원장',
#   '정',
#   '총리',
#   '수소차',
#   '보조금',
#   '수소',
#   '에너지',
#   '연구개발',
#   '투자',
#   '부품',
#   '소재',
#   '국산',
#   '율',
#   '민간',
#   '주도',
#   '경제',
#   '실현',
#   '위해',
#   '모든',
#   '정책',
#   '지원',
#   '입장',
#   '수소',
#   '에너지',
#   '발전',
#   '중요성',
#   '선도',
#   '국가',
#   '로서',
#   '한국',
#   '위상',
#   '고',
#   '강조',
#   '정',
#   '총리',
#   '수소',
#   '에너지',
#   '생산',
#   '공급',
#   '확대',
#   '약속',
#   '경제',
#   '지속가능성',
#   '언급',
#   '국민',
#   '부담',
#   '가격',
#   '수소',
#   '구매',
#   '수',
#   '산업',
#   '생태계',
#   '창',
#   '출하',
#   '출력',
#   '제한',
#   '전기',
#   '활용',
#   '수소',
#   '생산',
#   '수',
#   '고',
#   '말',
#   '민간',
#   '위원',
#   '임명',
#   '정',
#   '부회장',
#   '범',
#   '정부',
#   '차원',
#   '지속',
#   '수소',
#   '경제',
#   '활성화',
#   '정책',
#   '지원',
#   '요청',
#   '현대차',
#   '그룹',
#   '기술',
#   '개발',
#   '산업',
#   '측면',
#   '글로벌',
#   '경제',
#   '화답',
#   '위원회',
#   '출범',
#   '당초',
#   '내년',
#   '예정',
#   '경제',
#   '컨트롤',
#   '타워',
#   '부재',
#   '정책',
#   '지연',
#   '경쟁',
#   '국가',
#   '기술',
#   '발전',
#   '대응',
#   '사안',
#   '감안',
#   '달',
#   '지난해',
#   '초',
#   '정부',
#   '국내',
#   '수소',
#   '전기차',
#   '누적',
#   '보급',
#   '충전',
#   '소',
#   '개',
#   '구축',
#   '골자',
#   '수소',
#   '경제',
#   '활성화',
#   '로드맵',
#   '발표',
#   '올해',
#   '수소',
#   '전기차',
#   '국내',
#   '누적',
#   '보급',
#   '대수',
#   '육박',
#   '충전',
#   '소',
#   '올해',
#   '설치',
#   '계획',
#   '현대차',
#   '수소',
#   '전용',
#   '트럭',
#   '콘셉트카',
#   '넵튠',
#   '산업',
#   '측면',
#   '경제',
#   '선도',
#   '현대차',
#   '그룹',
#   '수소',
#   '전기',
#   '스포츠',
#   '유틸리티',
#   '차량',
#   '넥쏘',
#   '데',
#   '상용차',
#   '시장',
#   '연료',
#   '전지',
#   '적용',
#   '범위',
#   '확대',
#   '지난해',
#   '현대차',
#   '스위스',
#   '수소',
#   '에너지',
#   '기업',
#   '에너지',
#   '합작',
#   '법인',
#   '설립',
#   '유럽',
#   '시장',
#   '규모',
#   '수소',
#   '전기',
#   '대형',
#   '트럭',
#   '공급',
#   '미국',
#   '커민',
#   '스',
#   '북미',
#   '상용차',
#   '시장',
#   '연료',
#   '시스템',
#   '공급',
#   '업무',
#   '협약',
#   '체결',
#   '양사',
#   '친환경',
#   '파워',
#   '트레인',
#   '공동',
#   '개발',
#   '현대차',
#   '첫',
#   '수소',
#   '전용',
#   '대형',
#   '트럭',
#   '콘셉트',
#   '카',
#   '넵튠',
#   '북미',
#   '시장',
#   '세계',
#   '최초',
#   '공개',
#   '공격',
#   '북미',
#   '상용차',
#   '시장',
#   '진출',
#   '염두',
#   '때문',
#   '날',
#   '현대차',
#   '코스피',
#   '증권',
#   '정보',
#   '현재',
#   '전일',
#   '대비',
#   '등락',
#   '률',
#   '거래',
#   '량',
#   '전일',
#   '장',
#   '모빌리티',
#   '쇼',
#   '통해',
#   '넵튠',
#   '콘셉트카',
#   '국내',
#   '최초',
#   '공개',
#   '이동형',
#   '연료',
#   '전지',
#   '발전기',
#   '연료',
#   '시스템',
#   '분야',
#   '확장',
#   '가능성',
#   '제시',
#   '현대차',
#   '향후',
#   '이내',
#   '대형',
#   '트럭',
#   '최적화',
#   '출력',
#   '연료',
#   '시스템',
#   '개발',
#   '출시',
#   '예정',
#   '한편',
#   '세계',
#   '최초',
#   '수소',
#   '모빌리티',
#   '전시회',
#   '모빌리티',
#   '쇼',
#   '날',
#   '일산',
#   '킨텍스',
#   '개최',
#   '개국',
#   '수소',
#   '모빌리티',
#   '관련',
#   '기관',
#   '기업',
#   '곳',
#   '참여',
#   '현대차',
#   '모빌리티',
#   '쇼',
#   '통해',
#   '콘셉트',
#   '카',
#   '넵튠',
#   '국내',
#   '시장',
#   '최초',
#   '정',
#   '만기',
#   '조직',
#   '위원장',
#   '전시회',
#   '수소',
#   '에너지',
#   '기술',
#   '발전',
#   '최신',
#   '트렌드',
#   '공유',
#   '무역',
#   '거래',
#   '촉진',
#   '위',
#   '교류',
#   '장',
#   '활용',
#   '며',
#   '향후',
#   '모빌리티',
#   '쇼',
#   '국가',
#   '핵심',
#   '전시회',
#   '말'],
#  ['송대',
#   '익',
#   '유튜브',
#   '캡처',
#   '사진',
#   '유튜브',
#   '채널',
#   '정',
#   '배우',
#   '사건',
#   '사고',
#   '이슈',
#   '송대',
#   '익',
#   '채널',
#   '동영상',
#   '삭제',
#   '지난달',
#   '유튜버',
#   '정',
#   '배우',
#   '송대',
#   '익',
#   '자영',
#   '업자',
#   '악의',
#   '주작',
#   '제목',
#   '영상',
#   '게재',
#   '저격',
#   '앞서',
#   '송대',
#   '피자',
#   '치킨',
#   '판매',
#   '브랜드',
#   '피자',
#   '치킨',
#   '공주',
#   '음식',
#   '배달',
#   '해당',
#   '영상',
#   '피자',
#   '채',
#   '치킨',
#   '조각',
#   '튀김',
#   '껍질',
#   '확인',
#   '송대',
#   '당황',
#   '표정',
#   '매장',
#   '항의',
#   '송대',
#   '환불',
#   '요구',
#   '업주',
#   '거절',
#   '미온',
#   '태도',
#   '업주',
#   '비난',
#   '관련',
#   '정',
#   '조작',
#   '방송',
#   '주장',
#   '직접',
#   '가맹',
#   '점',
#   '점주',
#   '통화',
#   '결과',
#   '답변',
#   '본사',
#   '통화',
#   '명예훼손',
#   '라며',
#   '처리',
#   '부탁',
#   '고',
#   '전',
#   '송대',
#   '익',
#   '댓글',
#   '수천',
#   '삭제',
#   '댓글',
#   '못',
#   '달',
#   '조작',
#   '증거',
#   '대한',
#   '답변',
#   '댓글',
#   '삭제',
#   '현재',
#   '송대',
#   '익',
#   '채널',
#   '속',
#   '해당',
#   '영상',
#   '삭제',
#   '상태',
#   '송대',
#   '약',
#   '명',
#   '독자',
#   '보유',
#   '유명',
#   '유튜버',
#   '먹방',
#   '몰카',
#   '개그',
#   '여자친구',
#   '이민영',
#   '데이트',
#   '브이',
#   '로그',
#   '콘텐츠',
#   '주로'],
#  ['지난해',
#   '일본',
#   '정부',
#   '한국',
#   '대한',
#   '수출',
#   '규제',
#   '조치',
#   '단행',
#   '일본',
#   '지식인',
#   '한국',
#   '적',
#   '제목',
#   '성명',
#   '발표',
#   '전직',
#   '외교관',
#   '변호사',
#   '시민사회',
#   '활동가',
#   '명',
#   '주축',
#   '성명',
#   '양국',
#   '반향',
#   '당시',
#   '성명',
#   '게재',
#   '홈페이지',
#   '첫',
#   '화면',
#   '한국',
#   '적',
#   '한국',
#   '적',
#   '인터뷰',
#   '한국',
#   '적',
#   '주도',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '수출',
#   '규제',
#   '조치',
#   '비판',
#   '지식인',
#   '성명',
#   '한국',
#   '적',
#   '발표',
#   '뒤',
#   '현재',
#   '한국',
#   '적',
#   '이름',
#   '홈페이지',
#   '캡쳐',
#   '서명',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '약',
#   '다시',
#   '우치다',
#   '변호사',
#   '역사',
#   '문제',
#   '판결',
#   '해결',
#   '수',
#   '면서',
#   '압류',
#   '자산',
#   '현금화',
#   '전',
#   '일본',
#   '기업',
#   '피해자',
#   '화해',
#   '고',
#   '말',
#   '협정',
#   '역사',
#   '대한',
#   '인식',
#   '처음',
#   '공유',
#   '김대중',
#   '오부',
#   '치',
#   '선언',
#   '문제',
#   '해결',
#   '출발점',
#   '말',
#   '인터뷰',
#   '전문',
#   '작년',
#   '한국',
#   '적',
#   '서명',
#   '운동',
#   '이후',
#   '상황',
#   '달라',
#   '정도',
#   '서명',
#   '참여',
#   '이후',
#   '법률가',
#   '동성',
#   '정부',
#   '별도',
#   '해결',
#   '책',
#   '모색',
#   '앞',
#   '경제',
#   '정계',
#   '전직',
#   '외교관',
#   '참여',
#   '낼',
#   '계획',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '도쿄',
#   '사무실',
#   '중앙',
#   '일보',
#   '인터뷰',
#   '역사',
#   '문제',
#   '문제',
#   '엮',
#   '정책',
#   '일본',
#   '기업',
#   '결코',
#   '결정',
#   '일본',
#   '수출',
#   '기업',
#   '불만',
#   '겉',
#   '청구권',
#   '협정',
#   '해결',
#   '일본',
#   '정부',
#   '논리',
#   '영향',
#   '일반인',
#   '사이',
#   '징용',
#   '공',
#   '단어',
#   '꽤',
#   '일본',
#   '정부',
#   '논리',
#   '널리',
#   '청구권',
#   '문제',
#   '해결',
#   '건',
#   '일본',
#   '정부',
#   '스스로',
#   '인정',
#   '문제',
#   '참의원',
#   '예산',
#   '위원회',
#   '나이',
#   '순',
#   '외무성',
#   '약국',
#   '개인',
#   '청구권',
#   '자체',
#   '국내법',
#   '의미',
#   '소멸',
#   '답변',
#   '아베',
#   '정권',
#   '고',
#   '주장',
#   '미쓰비시',
#   '머터',
#   '리얼',
#   '중국',
#   '강제',
#   '징용',
#   '피해자',
#   '화해',
#   '일본',
#   '정부',
#   '반발',
#   '중',
#   '관계',
#   '중',
#   '동성',
#   '침략',
#   '전쟁',
#   '대한',
#   '인식',
#   '공유',
#   '반면',
#   '조약',
#   '식민',
#   '지배',
#   '대한',
#   '공통',
#   '인식',
#   '반영',
#   '문제',
#   '처음',
#   '언급',
#   '김대중',
#   '대통령',
#   '오부',
#   '치',
#   '게이조',
#   '총리',
#   '세기',
#   '파트너',
#   '선언',
#   '중',
#   '공동',
#   '성명',
#   '수준',
#   '인식',
#   '선언',
#   '출발점',
#   '일본',
#   '정부',
#   '지금',
#   '협정',
#   '지난해',
#   '인터뷰',
#   '수출',
#   '규제',
#   '조치',
#   '관계',
#   '위기',
#   '헌법',
#   '개정',
#   '의도',
#   '지적',
#   '생각',
#   '동시',
#   '한국',
#   '여론',
#   '분열',
#   '의도',
#   '생각',
#   '아베',
#   '정권',
#   '의도',
#   '아베',
#   '정권',
#   '징용',
#   '공',
#   '문제',
#   '해결',
#   '최소한',
#   '관계',
#   '더',
#   '방법',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '도쿄',
#   '사무실',
#   '중앙',
#   '일보',
#   '인터뷰',
#   '일본',
#   '기업',
#   '자산',
#   '현금화',
#   '관계',
#   '악화',
#   '예상',
#   '역사',
#   '문제',
#   '해결',
#   '법률',
#   '해결',
#   '판결',
#   '집행',
#   '해결',
#   '안',
#   '진짜',
#   '해결',
#   '사실',
#   '인정',
#   '책임',
#   '인정',
#   '사죄',
#   '현금화',
#   '절반',
#   '승리',
#   '뿐',
#   '해결',
#   '수',
#   '일본',
#   '기업',
#   '먼저',
#   '압류',
#   '자산',
#   '현금화',
#   '전',
#   '피해자',
#   '측',
#   '화해',
#   '위',
#   '움직임',
#   '구체',
#   '현금화',
#   '움직임',
#   '중단',
#   '수',
#   '화해',
#   '해결',
#   '더',
#   '구체',
#   '얘기',
#   '가해',
#   '사실',
#   '인정',
#   '책임',
#   '인정',
#   '사죄',
#   '게',
#   '첫',
#   '번',
#   '두',
#   '번',
#   '책임',
#   '인정',
#   '증표',
#   '화해',
#   '금',
#   '지급',
#   '세',
#   '번',
#   '잘못',
#   '반복',
#   '위해',
#   '문제',
#   '역사',
#   '거울',
#   '역사',
#   '교육',
#   '게',
#   '위해',
#   '선',
#   '역사',
#   '마주',
#   '김대중',
#   '오부',
#   '치',
#   '선언',
#   '과거',
#   '직시',
#   '공통',
#   '인식',
#   '대전',
#   '제로',
#   '문제',
#   '해결'],
#  ['앵커',
#   '원',
#   '투',
#   '자금',
#   '환매',
#   '중단',
#   '사태',
#   '빚',
#   '라임',
#   '사모펀드',
#   '관련',
#   '금융감독원',
#   '첫',
#   '분쟁',
#   '조정',
#   '결과',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '판매',
#   '사가',
#   '가입자',
#   '원금',
#   '전액',
#   '결정',
#   '금융투자',
#   '상품',
#   '결정',
#   '건',
#   '처음',
#   '라임',
#   '판매',
#   '사가',
#   '부실',
#   '펀드',
#   '계속',
#   '게',
#   '윱니',
#   '김민철',
#   '기자',
#   '보도',
#   '리포트',
#   '투자',
#   '원금',
#   '최대',
#   '손실',
#   '발생',
#   '운용',
#   '판매',
#   '부실',
#   '펀드',
#   '계속',
#   '금융감독원',
#   '금융',
#   '분쟁',
#   '조정',
#   '위원회',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '관련',
#   '판단',
#   '금감원',
#   '판매',
#   '이후',
#   '펀드',
#   '산',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '결정',
#   '민법',
#   '착오',
#   '계약',
#   '취소',
#   '적용',
#   '원금',
#   '반환',
#   '결정',
#   '금융투자',
#   '상품',
#   '분쟁',
#   '조정',
#   '사상',
#   '처음',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '금융투자',
#   '수익',
#   '스와프',
#   '대출',
#   '자금',
#   '활용',
#   '개',
#   '해외',
#   '무역',
#   '금융',
#   '펀드',
#   '투자',
#   '중',
#   '개',
#   '펀드',
#   '문제',
#   '금감원',
#   '라임',
#   '금투',
#   '부실',
#   '청산',
#   '절차',
#   '개시',
#   '통지',
#   '투자',
#   '원금',
#   '최대',
#   '달',
#   '손실',
#   '발생',
#   '운용',
#   '사인',
#   '라임',
#   '투자',
#   '제안',
#   '수익률',
#   '투자',
#   '위험',
#   '핵심',
#   '정보',
#   '허위',
#   '부실',
#   '기재',
#   '고',
#   '판매',
#   '사인',
#   '금투',
#   '그대로',
#   '투자자',
#   '제공',
#   '거나',
#   '설명',
#   '착오',
#   '과정',
#   '판매',
#   '자의',
#   '허위',
#   '투자',
#   '정보',
#   '설명',
#   '거나',
#   '투자자',
#   '성향',
#   '임의',
#   '기재',
#   '합리',
#   '투자',
#   '판단',
#   '기회',
#   '박탈',
#   '판단',
#   '분쟁',
#   '조정은',
#   '개',
#   '신청',
#   '건',
#   '중',
#   '대표',
#   '사례',
#   '건',
#   '심의',
#   '결과',
#   '나머지',
#   '투자',
#   '피해자',
#   '대해',
#   '선',
#   '자율',
#   '정이',
#   '진행',
#   '계획',
#   '대해',
#   '금감원',
#   '조정',
#   '절차',
#   '최대',
#   '천',
#   '원',
#   '투자',
#   '원금',
#   '반환',
#   '예상',
#   '고',
#   '대해',
#   '금투',
#   '우리은행',
#   '판매',
#   '내부',
#   '의사결정',
#   '과정',
#   '수락',
#   '결정',
#   '예정',
#   '뉴스',
#   '김민철'],
#  ['인국공',
#   '은',
#   '인천',
#   '국제공항',
#   '약자',
#   '말',
#   '최근',
#   '비정규직',
#   '인천',
#   '국제공항',
#   '보안요원',
#   '정규직',
#   '전환',
#   '논란',
#   '때문',
#   '취업',
#   '난',
#   '층',
#   '중심',
#   '공공기관',
#   '비정규직',
#   '정규직',
#   '전환',
#   '대한',
#   '반감',
#   '논란',
#   '배경',
#   '경쟁',
#   '취업',
#   '취업',
#   '과정',
#   '공정',
#   '문제',
#   '제기',
#   '대해',
#   '인천공항',
#   '공사',
#   '비정규직',
#   '정규직',
#   '화로',
#   '취업',
#   '준비',
#   '생',
#   '일자리',
#   '우려',
#   '사실',
#   '강조',
#   '정규직',
#   '전환',
#   '해도',
#   '비정규직',
#   '당시',
#   '임금',
#   '인상',
#   '해명',
#   '여권',
#   '비정규직',
#   '정규직',
#   '기회',
#   '싸움',
#   '입장',
#   '보이',
#   '최근',
#   '비정규직',
#   '정규직',
#   '전환',
#   '대한',
#   '여론조사',
#   '역차별',
#   '우려',
#   '고려',
#   '보류',
#   '장기',
#   '고용체',
#   '변화',
#   '위해',
#   '지속',
#   '추진',
#   '부정',
#   '의견',
#   '오차',
#   '범위',
#   '내',
#   '취업',
#   '직면',
#   '정규직',
#   '전환',
#   '보류',
#   '응답',
#   '달',
#   '반면',
#   '정규직',
#   '전환',
#   '계속',
#   '추진',
#   '의견',
#   '더',
#   '대조',
#   '현상',
#   '대해',
#   '전문가',
#   '정규직',
#   '비정규직',
#   '사회',
#   '계급',
#   '분석',
#   '사회',
#   '지위',
#   '처우',
#   '현격',
#   '차이',
#   '보이',
#   '우리나라',
#   '정규직',
#   '비정규직',
#   '대한',
#   '인식',
#   '청년',
#   '층',
#   '그대로',
#   '투영',
#   '사실',
#   '비정규직',
#   '문제',
#   '고질',
#   '고용',
#   '불안',
#   '양극화',
#   '것임',
#   '인국공',
#   '논란',
#   '일부',
#   '정치권',
#   '언론',
#   '갈등',
#   '한몫',
#   '인국공',
#   '논란',
#   '그동안',
#   '특권',
#   '층',
#   '이익',
#   '위해',
#   '희생',
#   '강요',
#   '불공정',
#   '경험',
#   '기인',
#   '비정규직',
#   '문제',
#   '해결',
#   '위',
#   '사회',
#   '합의',
#   '장애',
#   '요인',
#   '작용',
#   '싸움',
#   '돌',
#   '리기',
#   '사회',
#   '팽배',
#   '불신',
#   '골',
#   '천남',
#   '수',
#   '강원',
#   '사회',
#   '연구소장'],
#  ['규제',
#   '지역',
#   '주택',
#   '담보',
#   '대출',
#   '집',
#   '사려',
#   '개월',
#   '안',
#   '집',
#   '전입',
#   '주택',
#   '매매',
#   '임대',
#   '사업자',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '금융',
#   '위원회',
#   '금융감독원',
#   '부동산',
#   '대책',
#   '주택',
#   '담보',
#   '대출',
#   '관련',
#   '행정지도',
#   '시행',
#   '먼저',
#   '무',
#   '주택',
#   '투기지역',
#   '투기',
#   '지구',
#   '조정',
#   '대상',
#   '지역',
#   '규제',
#   '지역',
#   '주택',
#   '구매',
#   '위',
#   '주택',
#   '담보',
#   '대출',
#   '개월',
#   '안',
#   '전입',
#   '주택',
#   '가격',
#   '전입',
#   '의무',
#   '부과',
#   '주택',
#   '자의',
#   '경우',
#   '개월',
#   '안',
#   '기존',
#   '주택',
#   '처분',
#   '신규',
#   '주택',
#   '개월',
#   '산정',
#   '시점',
#   '주택',
#   '담보',
#   '대출',
#   '실행',
#   '중도',
#   '금',
#   '주비',
#   '대출',
#   '경우',
#   '신규',
#   '주택',
#   '소유권',
#   '이전',
#   '등기',
#   '일로',
#   '개월',
#   '신규',
#   '행정지도',
#   '시행일',
#   '이후',
#   '신규',
#   '대출',
#   '신청',
#   '규제',
#   '적용',
#   '주택',
#   '매매',
#   '계약',
#   '체결',
#   '계약금',
#   '납부',
#   '사실',
#   '증명',
#   '대출',
#   '금융',
#   '회사',
#   '전산',
#   '등록',
#   '통해',
#   '대출',
#   '신청',
#   '접수',
#   '대출',
#   '금융',
#   '대출',
#   '만기',
#   '연장',
#   '통보',
#   '대출',
#   '종전',
#   '규정',
#   '적용',
#   '집단',
#   '대출',
#   '경우',
#   '입',
#   '주자',
#   '모집',
#   '공고',
#   '입',
#   '주자',
#   '모집',
#   '공고',
#   '경우',
#   '착공',
#   '신고',
#   '재건축',
#   '재개발',
#   '사업',
#   '조합원',
#   '경우',
#   '관리',
#   '처분',
#   '사업',
#   '대해',
#   '종전',
#   '규정',
#   '적용',
#   '달',
#   '모든',
#   '지역',
#   '주택',
#   '매매',
#   '임대',
#   '사업자',
#   '대한',
#   '주택',
#   '담보',
#   '대출',
#   '금지',
#   '주택',
#   '구입',
#   '용',
#   '자금',
#   '주택',
#   '수리',
#   '비',
#   '운전',
#   '자금',
#   '용',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '구입',
#   '주택',
#   '담보',
#   '임차보증금',
#   '반환',
#   '목적',
#   '대출',
#   '취급',
#   '종전',
#   '규정',
#   '적용',
#   '국토교통부',
#   '예외',
#   '인정',
#   '비영리',
#   '법인',
#   '공익',
#   '법인',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '박현',
#   '기자'],
#  ['전대',
#   '서울중앙지법',
#   '앞',
#   '기자회견',
#   '등심',
#   '위도',
#   '결산',
#   '역',
#   '공유',
#   '못',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '주장',
#   '소송',
#   '등록금',
#   '반환',
#   '청구',
#   '서울',
#   '뉴시스',
#   '최현호',
#   '기자',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '여파',
#   '대학',
#   '비대',
#   '수업',
#   '온라인',
#   '수업',
#   '진행',
#   '가운데',
#   '대학생',
#   '단체',
#   '수업',
#   '침해',
#   '등록금',
#   '반환',
#   '주장',
#   '대학',
#   '국가',
#   '상대로',
#   '송전',
#   '돌입',
#   '전국',
#   '대학',
#   '학생회',
#   '네트워크',
#   '전대',
#   '서울',
#   '서초구',
#   '서울중앙지법',
#   '앞',
#   '기자회견',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '고',
#   '주장',
#   '학교',
#   '법인',
#   '국가',
#   '상대로',
#   '소송',
#   '접수',
#   '소송',
#   '지난달',
#   '모집',
#   '전국',
#   '여개',
#   '대학',
#   '여명',
#   '대학생',
#   '참여',
#   '전대',
#   '측은',
#   '기자회견',
#   '문',
#   '통해',
#   '대학',
#   '교육부',
#   '국회',
#   '등록금',
#   '반환',
#   '논의',
#   '과정',
#   '학생',
#   '학교',
#   '학생',
#   '법적',
#   '보장',
#   '등록금',
#   '심의',
#   '위원회',
#   '제대로',
#   '결산',
#   '역',
#   '공유',
#   '고',
#   '지난달',
#   '등록금',
#   '반환',
#   '안',
#   '국회',
#   '교육',
#   '위원회',
#   '추경',
#   '예산',
#   '통과',
#   '금액',
#   '학교',
#   '당',
#   '정도',
#   '금액',
#   '반환',
#   '가정',
#   '책정',
#   '금액',
#   '현재',
#   '교육부',
#   '국회',
#   '논의',
#   '흐름',
#   '대학생',
#   '민심',
#   '제대로',
#   '반영',
#   '물',
#   '수',
#   '면서',
#   '대학생',
#   '학습',
#   '교육',
#   '헌법',
#   '명시',
#   '대학',
#   '교육부',
#   '보장',
#   '기본권',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '등록금',
#   '반환',
#   '논의',
#   '학생',
#   '의견',
#   '즉각',
#   '수용',
#   '요구',
#   '소송',
#   '대리인',
#   '단',
#   '민주',
#   '사회',
#   '위',
#   '변호사',
#   '모임',
#   '민변',
#   '날',
#   '접수',
#   '소장',
#   '사립대',
#   '재학생',
#   '학교',
#   '법인',
#   '대한민국',
#   '상대로',
#   '반환',
#   '소송',
#   '국립대',
#   '재학생',
#   '반환',
#   '소송',
#   '사립대',
#   '경우',
#   '전국',
#   '개',
#   '학교',
#   '학생',
#   '명',
#   '참여',
#   '국립대',
#   '전국',
#   '개',
#   '대학',
#   '소속',
#   '학생',
#   '명',
#   '참여',
#   '사립대',
#   '중',
#   '명',
#   '학생',
#   '원고',
#   '참여',
#   '학교',
#   '계원예대',
#   '홍익대',
#   '이화여대',
#   '숙명여대',
#   '한성대',
#   '소송',
#   '통해',
#   '학생',
#   '측',
#   '청구',
#   '반환',
#   '금액',
#   '등록금',
#   '수준',
#   '사립대',
#   '경우',
#   '원고',
#   '국립대',
#   '경우',
#   '원고',
#   '정도',
#   '민변',
#   '관계자',
#   '날',
#   '소송',
#   '차',
#   '소장',
#   '접수',
#   '소송',
#   '과정',
#   '대학',
#   '결산',
#   '자료',
#   '제출',
#   '구체',
#   '산정',
#   '예정',
#   '전',
#   '민변',
#   '관계자',
#   '예술',
#   '계열',
#   '경우',
#   '곳',
#   '더',
#   '등록금',
#   '실기',
#   '비율',
#   '작업실',
#   '사용',
#   '못',
#   '교수',
#   '작품',
#   '피드백',
#   '얻지',
#   '반면',
#   '집',
#   '과제',
#   '상황',
#   '반환',
#   '필요성',
#   '더욱',
#   '절감',
#   '상당수',
#   '학생',
#   '원고',
#   '참여',
#   '고',
#   '전',
#   '홍익대',
#   '이대',
#   '경우',
#   '대표',
#   '적립금',
#   '곳',
#   '학교',
#   '재정',
#   '능력',
#   '입장',
#   '학생',
#   '더',
#   '의식',
#   '날',
#   '기자회견',
#   '발언',
#   '류',
#   '환',
#   '청년',
#   '대표',
#   '소송',
#   '대학',
#   '정부',
#   '대학생',
#   '목소리',
#   '무시',
#   '시작',
#   '면서',
#   '대학생',
#   '학기',
#   '시작',
#   '전',
#   '기자회견',
#   '면담',
#   '설문조사',
#   '통해',
#   '대책',
#   '마련',
#   '요구',
#   '대학',
#   '교육부',
#   '지침',
#   '이유',
#   '묵살',
#   '고',
#   '주장',
#   '대학',
#   '반환',
#   '규정',
#   '때문',
#   '반환',
#   '수',
#   '답변',
#   '등록금',
#   '기준',
#   '책정',
#   '때문',
#   '환불',
#   '기준',
#   '등록금',
#   '반환',
#   '요구',
#   '내',
#   '돈',
#   '반환',
#   '요구',
#   '지금',
#   '무시',
#   '침해',
#   '대학생',
#   '권리',
#   '요구',
#   '의미',
#   '함축',
#   '행동',
#   '말',
#   '지난달',
#   '대학교육',
#   '연구소',
#   '올해',
#   '기준',
#   '대학',
#   '교비',
#   '회계',
#   '결산',
#   '통해',
#   '확인',
#   '발표',
#   '사립',
#   '대학',
#   '누적',
#   '적립금',
#   '현황',
#   '자료',
#   '전체',
#   '사립대',
#   '개',
#   '대학',
#   '중',
#   '개교',
#   '누적',
#   '적립금',
#   '학교',
#   '누적',
#   '적립금',
#   '합계',
#   '달',
#   '최근',
#   '대학생',
#   '상대로',
#   '설문조사',
#   '결과',
#   '응답',
#   '자의',
#   '등록금',
#   '응답',
#   '응답',
#   '등록금',
#   '환액',
#   '판단',
#   '금액',
#   '평균값',
#   '등록금',
#   '대학',
#   '알리',
#   '전국',
#   '대학',
#   '학기',
#   '등록금',
#   '평균',
#   '약'],
#  ['국립대전현충원',
#   '충',
#   '인물',
#   '권',
#   '남궁',
#   '선',
#   '김기봉',
#   '중사',
#   '선정',
#   '비무장지대',
#   '남북',
#   '공동',
#   '유해',
#   '발굴',
#   '사업',
#   '통해',
#   '화살',
#   '머리',
#   '고지',
#   '신원',
#   '확인',
#   '권',
#   '중사',
#   '경남',
#   '사천',
#   '당시',
#   '살의',
#   '나이',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '참전',
#   '화살',
#   '머리',
#   '고지',
#   '중공군',
#   '두',
#   '차례',
#   '전투',
#   '참여',
#   '달',
#   '전사',
#   '남궁',
#   '선',
#   '중사',
#   '강원도',
#   '홍천',
#   '슬하',
#   '남',
#   '녀',
#   '상황',
#   '입대',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '전쟁',
#   '참여',
#   '소총수',
#   '철원',
#   '상석',
#   '지구',
#   '전투',
#   '활약',
#   '중공군',
#   '대적',
#   '공습',
#   '교전',
#   '중',
#   '포탄',
#   '파편',
#   '사망',
#   '김기봉',
#   '중사',
#   '경남',
#   '거제',
#   '당시',
#   '살의',
#   '나이',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '활동',
#   '시작',
#   '중공군',
#   '공격',
#   '두',
#   '차례',
#   '접전',
#   '끝',
#   '고지',
#   '사수',
#   '전투',
#   '전인',
#   '화살',
#   '머리',
#   '고지',
#   '숨',
#   '지난해',
#   '국립대전현충원',
#   '안장'],
#  ['가수',
#   '신용재',
#   '오후',
#   '서울',
#   '마포구',
#   '서교동',
#   '하나투어',
#   '브이',
#   '홀',
#   '첫',
#   '정규',
#   '앨범',
#   '디어',
#   '발매',
#   '기념',
#   '쇼케이스',
#   '참석',
#   '신곡'],
#  ['유럽연합',
#   '한국',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '인천',
#   '국제공항',
#   '출국',
#   '전광판',
#   '유럽',
#   '행',
#   '비행기',
#   '출발',
#   '정보',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확산',
#   '위해',
#   '지난',
#   '외국인',
#   '입국',
#   '제한',
#   '회원',
#   '국',
#   '날',
#   '한국',
#   '개국',
#   '알제리',
#   '호주',
#   '캐나다',
#   '조지아',
#   '일본',
#   '몬테네그로',
#   '모로코',
#   '뉴질랜드',
#   '르완다',
#   '세르비아',
#   '태국',
#   '튀니지',
#   '우루과이',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '사진',
#   '뉴스',
#   '코로나',
#   '하늘',
#   '길이',
#   '리기',
#   '시작',
#   '여름',
#   '수기',
#   '여행객',
#   '국가',
#   '유럽',
#   '초토화',
#   '관광',
#   '산업',
#   '시작',
#   '국내',
#   '여행객',
#   '가장',
#   '선망',
#   '여행지',
#   '유럽',
#   '여행',
#   '교류',
#   '재개',
#   '여행객',
#   '관심',
#   '코로나',
#   '지속',
#   '점',
#   '해외여행',
#   '수요',
#   '회복',
#   '관측',
#   '경제',
#   '회생',
#   '고육책',
#   '유럽',
#   '문',
#   '유럽연합',
#   '한국',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '인천',
#   '국제공항',
#   '출국',
#   '탑승객',
#   '출국',
#   '수속',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확산',
#   '위해',
#   '지난',
#   '외국인',
#   '입국',
#   '제한',
#   '회원',
#   '국',
#   '날',
#   '한국',
#   '개국',
#   '알제리',
#   '호주',
#   '캐나다',
#   '조지아',
#   '일본',
#   '몬테네그로',
#   '모로코',
#   '뉴질랜드',
#   '르완다',
#   '세르비아',
#   '태국',
#   '튀니지',
#   '우루과이',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '사진',
#   '뉴스',
#   '현지',
#   '로이터',
#   '외신',
#   '회원',
#   '국',
#   '대표',
#   '기구',
#   '이사회',
#   '여행',
#   '출장',
#   '목적',
#   '개국',
#   '국민',
#   '대한',
#   '입국',
#   '제한',
#   '해제',
#   '합의',
#   '날',
#   '한국',
#   '비롯',
#   '일본',
#   '호주',
#   '캐나다',
#   '뉴질랜드',
#   '태국',
#   '우루과이',
#   '튀니지',
#   '세르비아',
#   '르완다',
#   '모로코',
#   '몬테네그로',
#   '조지아',
#   '알제리',
#   '개국',
#   '국가',
#   '여행',
#   '코로나',
#   '꽉',
#   '유럽',
#   '여행',
#   '길이',
#   '전망',
#   '찌',
#   '감치',
#   '예견',
#   '앞서',
#   '유럽',
#   '관광',
#   '대국',
#   '이탈리아',
#   '지난달',
#   '개월',
#   '국경',
#   '개방',
#   '그리스도',
#   '외국인',
#   '입국',
#   '허용',
#   '결정',
#   '관광',
#   '교류',
#   '재개',
#   '움직임',
#   '때문',
#   '백신',
#   '개발',
#   '커녕',
#   '세계보건기구',
#   '코로나',
#   '팬데믹',
#   '종식',
#   '근처',
#   '못',
#   '경고',
#   '상황',
#   '관광',
#   '개방',
#   '회생',
#   '위',
#   '고육책',
#   '유럽',
#   '국가',
#   '관광객',
#   '지출',
#   '국가',
#   '경제',
#   '지탱',
#   '관광',
#   '국내총생산',
#   '차지',
#   '고용',
#   '비중',
#   '핵심',
#   '산업',
#   '중',
#   '관광객',
#   '가장',
#   '여름',
#   '수기',
#   '국경',
#   '개방',
#   '이유',
#   '세계',
#   '관광',
#   '기구',
#   '세계',
#   '각국',
#   '여행',
#   '제한',
#   '지속',
#   '전',
#   '세계',
#   '총',
#   '관광객',
#   '수가',
#   '예상',
#   '초',
#   '여행',
#   '제한',
#   '해제',
#   '경우',
#   '대비',
#   '감소',
#   '데',
#   '관광',
#   '나라',
#   '국경',
#   '봉쇄',
#   '해제',
#   '수',
#   '여행',
#   '수',
#   '현실',
#   '불가능',
#   '국내',
#   '유럽',
#   '행',
#   '비행기',
#   '탈',
#   '수',
#   '대한',
#   '여행객',
#   '관심',
#   '회원',
#   '수',
#   '명',
#   '유럽',
#   '여행',
#   '커뮤니티',
#   '유랑',
#   '유럽',
#   '여행',
#   '가능',
#   '질문',
#   '현지',
#   '상황',
#   '대한',
#   '공유',
#   '모습',
#   '여행객',
#   '기대',
#   '달리',
#   '당분간',
#   '유럽',
#   '여행',
#   '전망',
#   '행업',
#   '코로나',
#   '사태',
#   '데',
#   '현지',
#   '사정',
#   '국내',
#   '방역',
#   '현황',
#   '볼',
#   '물리',
#   '여행',
#   '보고',
#   '결정',
#   '회원',
#   '국',
#   '그대로',
#   '이행',
#   '대한',
#   '불분명',
#   '입국',
#   '허용',
#   '격리',
#   '거나',
#   '국가',
#   '비자',
#   '요구',
#   '수도',
#   '유럽',
#   '단일국가',
#   '여행',
#   '국경',
#   '나라',
#   '유람',
#   '경우',
#   '점',
#   '전',
#   '여행',
#   '수',
#   '국내',
#   '상황',
#   '녹록',
#   '전반',
#   '여행',
#   '업계',
#   '직원',
#   '대다수',
#   '유',
#   '무직',
#   '휴직',
#   '돌입',
#   '여행',
#   '관련',
#   '상품',
#   '업무',
#   '민원',
#   '처리',
#   '주요',
#   '여행사',
#   '경우',
#   '여행',
#   '상품',
#   '운영',
#   '아예',
#   '안',
#   '상품',
#   '최소',
#   '상태',
#   '가장',
#   '국내',
#   '방역',
#   '당국',
#   '지침',
#   '여행',
#   '주',
#   '격리',
#   '점',
#   '유럽',
#   '장거리',
#   '만큼',
#   '최소',
#   '일주일',
#   '여행',
#   '게',
#   '일반',
#   '귀국',
#   '주',
#   '자가',
#   '격리',
#   '경우',
#   '업무',
#   '학업',
#   '빚',
#   '차질',
#   '현실',
#   '유럽',
#   '여행',
#   '국내',
#   '최대',
#   '여행사',
#   '하나투어',
#   '조만간',
#   '해외여행',
#   '프로모션',
#   '열',
#   '예정',
#   '이후',
#   '출발',
#   '상품',
#   '예정',
#   '여행',
#   '판단',
#   '여행사',
#   '관계자',
#   '말',
#   '그대로',
#   '여행',
#   '것일',
#   '뿐',
#   '실질',
#   '여행',
#   '수',
#   '환경',
#   '말',
#   '수',
#   '며',
#   '업무',
#   '친지',
#   '방문',
#   '주',
#   '자가',
#   '격리',
#   '수',
#   '경우',
#   '제외',
#   '유럽',
#   '여행',
#   '수',
#   '상황',
#   '말'],
#  ['참여',
#   '환경',
#   '연대',
#   '제주도',
#   '의회',
#   '교육',
#   '제도',
#   '대한',
#   '의견서',
#   '헌법재판소',
#   '제출',
#   '관련',
#   '성명',
#   '제주도',
#   '회의',
#   '가짜',
#   '의견서',
#   '제출',
#   '의혹',
#   '대한',
#   '해명',
#   '요구',
#   '제주도',
#   '의회',
#   '헌법재판소',
#   '제출',
#   '의견서',
#   '교육',
#   '위원회',
#   '교육',
#   '의원',
#   '명',
#   '포함',
#   '명',
#   '전원',
#   '참여',
#   '환경',
#   '대가',
#   '주장',
#   '의견',
#   '반대',
#   '참여',
#   '환경',
#   '연대',
#   '송창',
#   '은실',
#   '의원',
#   '확인',
#   '결과',
#   '교육',
#   '위원회',
#   '차원',
#   '의견',
#   '회의',
#   '공지',
#   '적',
#   '며',
#   '의견서',
#   '작성',
#   '과정',
#   '의혹',
#   '제기',
#   '제주도',
#   '의회',
#   '의견서',
#   '교육',
#   '위원회',
#   '명',
#   '소속',
#   '의원',
#   '전원',
#   '반대',
#   '며',
#   '의견',
#   '서거',
#   '과정',
#   '통해',
#   '작성',
#   '헌법재판소',
#   '제출',
#   '고',
#   '강조',
#   '주',
#   '내',
#   '경위',
#   '경우',
#   '항의',
#   '헌법재판소',
#   '사실',
#   '전달'],
#  ['대전',
#   '초등학생',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '양성',
#   '판정',
#   '건',
#   '관련',
#   '방역',
#   '당국',
#   '교내',
#   '전파',
#   '의심',
#   '사례',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확',
#   '진자',
#   '발생',
#   '폐쇄',
#   '조치',
#   '대전',
#   '초등학교',
#   '교실',
#   '적막',
#   '감',
#   '김성태',
#   '정은경',
#   '중앙',
#   '방역',
#   '대책',
#   '본부장',
#   '정례',
#   '브리핑',
#   '대전',
#   '지역',
#   '초등학교',
#   '학생',
#   '간',
#   '접촉',
#   '감염',
#   '사례',
#   '관련',
#   '교내',
#   '전파',
#   '의심',
#   '고',
#   '말',
#   '확',
#   '진자',
#   '사이',
#   '접촉',
#   '명',
#   '확진',
#   '의정부',
#   '아파트',
#   '주민',
#   '전수',
#   '조사',
#   '정',
#   '본부장',
#   '그동안',
#   '등교',
#   '수업',
#   '관련',
#   '집단',
#   '감염',
#   '사례',
#   '보고',
#   '며',
#   '코로나',
#   '특징',
#   '증',
#   '면서',
#   '무증상',
#   '감염',
#   '이기',
#   '때문',
#   '학교',
#   '밖',
#   '감염',
#   '학',
#   '유입',
#   '가능성',
#   '피',
#   '상황',
#   '전시',
#   '지난달',
#   '대전',
#   '동구',
#   '초등학교',
#   '학년',
#   '학생',
#   '명',
#   '확진',
#   '뒤',
#   '학년',
#   '학생',
#   '명',
#   '추가',
#   '양성',
#   '판정',
#   '중',
#   '명',
#   '첫',
#   '확',
#   '진자',
#   '반',
#   '학생',
#   '확인',
#   '정',
#   '본부장',
#   '대전',
#   '가족',
#   '간',
#   '전파',
#   '초등학생',
#   '명',
#   '감염',
#   '초등학생',
#   '학원',
#   '접촉',
#   '명과',
#   '학교',
#   '반',
#   '학생',
#   '명',
#   '양성',
#   '확인',
#   '고',
#   '말',
#   '급반',
#   '학생',
#   '초등학생',
#   '확',
#   '진자',
#   '사이',
#   '만큼',
#   '라며',
#   '학생',
#   '전파',
#   '보고',
#   '고',
#   '말',
#   '전파',
#   '규모',
#   '역학',
#   '조사',
#   '학생',
#   '전수',
#   '조사',
#   '결과',
#   '뒤',
#   '추후',
#   '발표',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확',
#   '진자',
#   '발생',
#   '폐쇄',
#   '조치',
#   '대전',
#   '초등학교',
#   '적막',
#   '감',
#   '김성태',
#   '정',
#   '본부장',
#   '교내',
#   '전파',
#   '의심',
#   '사례',
#   '발생',
#   '함',
#   '학교',
#   '방역',
#   '칙',
#   '준수',
#   '다시',
#   '한번',
#   '당부',
#   '며',
#   '학생',
#   '교직원',
#   '등교',
#   '전',
#   '발열',
#   '호흡기',
#   '증상',
#   '경우',
#   '등교',
#   '출근',
#   '개인',
#   '위생',
#   '칙',
#   '준수',
#   '고',
#   '강조',
#   '한편',
#   '경기',
#   '의정부시',
#   '아파트',
#   '최근',
#   '새',
#   '주민',
#   '명',
#   '확진',
#   '관련',
#   '선',
#   '해당',
#   '명의',
#   '주민',
#   '전수',
#   '검사',
#   '정',
#   '본부장',
#   '세',
#   '가족',
#   '계',
#   '상황',
#   '라며',
#   '가족',
#   '간',
#   '개인',
#   '접촉',
#   '확인',
#   '엘리베이터',
#   '용공',
#   '통한',
#   '접촉',
#   '전파',
#   '가능성',
#   '역학',
#   '조사',
#   '진행',
#   '고',
#   '말',
#   '지난달',
#   '광주',
#   '광역시',
#   '동구',
#   '운림',
#   '광륵사',
#   '문',
#   '앞',
#   '출입',
#   '금지',
#   '간판',
#   '광주',
#   '광역시',
#   '전남',
#   '목포',
#   '전북',
#   '전주',
#   '경기',
#   '파주',
#   '코로나',
#   '확',
#   '진자',
#   '곳',
#   '방문',
#   '프리랜서',
#   '장정',
#   '필',
#   '당국',
#   '광주',
#   '불교',
#   '사찰',
#   '광륵사',
#   '관련',
#   '접촉',
#   '명',
#   '추가',
#   '확진',
#   '관련',
#   '누적',
#   '확',
#   '진자',
#   '명',
#   '감염',
#   '경로',
#   '오리무중',
#   '충북',
#   '옥천군',
#   '소재',
#   '자동차',
#   '부품',
#   '회사',
#   '관련',
#   '초등생',
#   '명',
#   '추가',
#   '확진',
#   '누적',
#   '확',
#   '진자',
#   '총',
#   '명',
#   '집계'],
#  ['앵커',
#   '코로나',
#   '확',
#   '진자',
#   '동선',
#   '마음',
#   '선별',
#   '진료',
#   '소',
#   '사람',
#   '늘',
#   '중증',
#   '환자',
#   '확',
#   '진자',
#   '증가',
#   '폭',
#   '의료',
#   '병상',
#   '확보',
#   '백미',
#   '선',
#   '기자',
#   '리포트',
#   '광주',
#   '시내',
#   '선별',
#   '진료',
#   '소',
#   '코로나',
#   '검사',
#   '사람',
#   '차례',
#   '확',
#   '진자',
#   '수가',
#   '급증',
#   '선',
#   '진료',
#   '소',
#   '방문자',
#   '최근',
#   '나흘',
#   '사이',
#   '배',
#   '김정애',
#   '광주',
#   '보건',
#   '사업',
#   '과장',
#   '평균',
#   '건',
#   '정도',
#   '검사',
#   '지난',
#   '토요일',
#   '이후',
#   '광주시',
#   '전체',
#   '확진',
#   '건',
#   '건',
#   '정도',
#   '검사',
#   '상황',
#   '의심',
#   '신고',
#   '검체',
#   '채취',
#   '병상',
#   '확보',
#   '비상',
#   '전남대',
#   '병원',
#   '마련',
#   '음압',
#   '병상',
#   '격리',
#   '실',
#   '곳',
#   '비롯',
#   '광주시',
#   '가용',
#   '병상',
#   '개',
#   '광주시',
#   '확',
#   '진자',
#   '경우',
#   '대비',
#   '빛고을',
#   '전남대',
#   '병원',
#   '병상',
#   '개',
#   '추가',
#   '확보',
#   '상대',
#   '여유',
#   '인근',
#   '지역',
#   '시설',
#   '이용',
#   '협조',
#   '변수',
#   '확',
#   '진자',
#   '집중',
#   '상당수',
#   '당뇨',
#   '심장병',
#   '질환',
#   '확',
#   '진자',
#   '수가',
#   '폭발',
#   '가능성',
#   '은',
#   '중증',
#   '환자',
#   '수',
#   '이야기',
#   '음압',
#   '병상',
#   '이동식',
#   '시설',
#   '광주',
#   '전남',
#   '개',
#   '류소연',
#   '조선',
#   '대학교',
#   '의과대학',
#   '예방의학',
#   '교실',
#   '교수',
#   '질병',
#   '진행',
#   '경과',
#   '앞',
#   '가능성',
#   '점',
#   '염려',
#   '부분',
#   '보시',
#   '코로나',
#   '확산',
#   '우려',
#   '대비',
#   '병상',
#   '확보',
#   '비상',
#   '뉴스',
#   '백미',
#   '선'],
#  ['뮤',
#   '지엄',
#   '산',
#   '본관',
#   '명',
#   '상관',
#   '향햐',
#   '야외',
#   '길',
#   '강원',
#   '도민',
#   '일보',
#   '자료',
#   '사진',
#   '강원',
#   '도민',
#   '일보',
#   '윤',
#   '종진',
#   '기자',
#   '문화',
#   '체육관',
#   '광부',
#   '한국',
#   '관광',
#   '공사',
#   '약',
#   '개',
#   '월간',
#   '추천',
#   '웰니스',
#   '관광지',
#   '개소',
#   '대한',
#   '할인',
#   '캠페인',
#   '시작',
#   '대상',
#   '강원',
#   '동해',
#   '위치',
#   '동해',
#   '무릉',
#   '건강',
#   '숲',
#   '경북',
#   '김천',
#   '국립',
#   '치유',
#   '숲',
#   '밀',
#   '집도',
#   '자연',
#   '숲',
#   '치유',
#   '시설',
#   '강원',
#   '홍천',
#   '힐리',
#   '언스',
#   '선',
#   '마을',
#   '원주',
#   '뮤',
#   '지엄',
#   '산',
#   '명',
#   '상관',
#   '충북',
#   '충주',
#   '산속',
#   '옹달샘',
#   '아침',
#   '편지',
#   '명상',
#   '치유',
#   '센터',
#   '대표',
#   '힐링',
#   '명상',
#   '시설',
#   '서울',
#   '티',
#   '테라',
#   '피',
#   '대구',
#   '하늘',
#   '호수',
#   '방',
#   '개소',
#   '포함',
#   '개소',
#   '캠페인',
#   '누리집',
#   '여행',
#   '주간',
#   '누리집',
#   '대한민국',
#   '구석구석',
#   '누리집',
#   '통해',
#   '참여',
#   '캠페인',
#   '희망',
#   '시설',
#   '쿠폰',
#   '다운',
#   '현장',
#   '사용',
#   '최대',
#   '할인',
#   '수',
#   '추천',
#   '웰니스',
#   '관광지',
#   '별',
#   '할인',
#   '쿠폰',
#   '수량',
#   '상이',
#   '총',
#   '명',
#   '할인',
#   '혜택',
#   '제공',
#   '쿠폰',
#   '사용',
#   '현장',
#   '사용',
#   '기준',
#   '방문',
#   '전',
#   '쿠폰',
#   '잔',
#   '수량',
#   '꼭',
#   '확인',
#   '한국',
#   '관광',
#   '공사',
#   '의료',
#   '웰',
#   '스팀',
#   '김정아',
#   '팀',
#   '캠페인',
#   '계기',
#   '시기',
#   '국민',
#   '힐링',
#   '한편',
#   '웰니스',
#   '관광업',
#   '도움',
#   '며',
#   '할인',
#   '캠페인',
#   '기간',
#   '시설',
#   '방역',
#   '체크',
#   '리스트',
#   '관리',
#   '동시',
#   '이용자',
#   '대상',
#   '마스크',
#   '안전',
#   '여행',
#   '가이드',
#   '제공',
#   '안전',
#   '여행',
#   '관리',
#   '고'],
#  ['전시',
#   '중구',
#   '박용',
#   '갑',
#   '청장',
#   '중구',
#   '보건소',
#   '위치',
#   '선',
#   '진료',
#   '소',
#   '위',
#   '킹스',
#   '루',
#   '현장',
#   '방문',
#   '민선',
#   '기',
#   '후반기',
#   '시작',
#   '박',
#   '청장',
#   '중구',
#   '선',
#   '진료',
#   '소',
#   '방문',
#   '내',
#   '외부',
#   '시설',
#   '물',
#   '점검',
#   '의료',
#   '진과',
#   '관계자',
#   '노고',
#   '감사',
#   '표',
#   '중구',
#   '청장',
#   '취임',
#   '주년',
#   '민선',
#   '기',
#   '후반기',
#   '맞이',
#   '성과',
#   '미래',
#   '포스트',
#   '코로나',
#   '구정',
#   '방향',
#   '제시',
#   '주민',
#   '화합',
#   '발전',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '고',
#   '다짐',
#   '성과',
#   '도심',
#   '활성화',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '건설',
#   '꼽았다',
#   '중구',
#   '도심',
#   '활성화',
#   '위해',
#   '문화',
#   '흐름',
#   '중교',
#   '조성',
#   '사업',
#   '대흥동',
#   '골목길',
#   '재생',
#   '사업',
#   '공원',
#   '주변',
#   '재창',
#   '사업',
#   '대제',
#   '커플',
#   '존',
#   '가로',
#   '확장',
#   '사업',
#   '린',
#   '공원',
#   '조성',
#   '사업',
#   '선화',
#   '확장',
#   '사업',
#   '대표',
#   '추진',
#   '결과',
#   '대흥동',
#   '은행동',
#   '선화동',
#   '지역',
#   '젊은이',
#   '곳',
#   '탈바꿈',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '건설',
#   '위해',
#   '효',
#   '문화',
#   '뿌리',
#   '축제',
#   '뿌리',
#   '공원',
#   '중심',
#   '효',
#   '문화',
#   '확산',
#   '노력',
#   '효',
#   '문화',
#   '뿌리',
#   '축제',
#   '연속',
#   '국가',
#   '유망',
#   '축제',
#   '선정',
#   '지난해',
#   '한국',
#   '기업',
#   '평판',
#   '연구소',
#   '빅데이터',
#   '분석',
#   '결과',
#   '국내',
#   '소비자',
#   '전국',
#   '개',
#   '축제',
#   '중',
#   '브랜드',
#   '평가',
#   '위',
#   '차지',
#   '성과',
#   '개장',
#   '뿌리',
#   '공원',
#   '성씨',
#   '조형',
#   '물',
#   '시작',
#   '현재',
#   '성장',
#   '야간',
#   '경관',
#   '조명등',
#   '설치',
#   '뿌리',
#   '공원',
#   '단장',
#   '인터넷',
#   '포털사이트',
#   '전시',
#   '만',
#   '곳',
#   '위',
#   '분',
#   '명품',
#   '공원',
#   '중구',
#   '민선',
#   '기',
#   '후반기',
#   '구정',
#   '지향',
#   '점',
#   '대한',
#   '미래',
#   '비',
#   '전도',
#   '제시',
#   '대표',
#   '사업',
#   '재개발',
#   '재건축',
#   '도시재생',
#   '뉴딜',
#   '사업',
#   '추진',
#   '효',
#   '문화',
#   '뿌리',
#   '마을',
#   '뿌리',
#   '공원',
#   '조성',
#   '중구',
#   '청사',
#   '건축물',
#   '리뉴얼',
#   '사업',
#   '추진',
#   '민중',
#   '심의',
#   '동행',
#   '정복',
#   '센터',
#   '신축',
#   '전시',
#   '정부',
#   '부처',
#   '협력',
#   '추진',
#   '베이스볼',
#   '드림파크',
#   '중구',
#   '건립',
#   '보문산',
#   '관광',
#   '활성화',
#   '나라',
#   '대전',
#   '통합',
#   '청사',
#   '신축',
#   '코로나',
#   '이후',
#   '사회',
#   '변화',
#   '예측',
#   '중구',
#   '차원',
#   '포스트',
#   '코로나',
#   '대응',
#   '전략',
#   '설명',
#   '주민',
#   '밀착',
#   '지역',
#   '주민',
#   '소외',
#   '수',
#   '현실',
#   '전략',
#   '가장',
#   '개인',
#   '위생',
#   '칙',
#   '준수',
#   '강조',
#   '차원',
#   '전략',
#   '중앙',
#   '지하상가',
#   '특',
#   '거리',
#   '대한',
#   '시설',
#   '개선',
#   '마케팅',
#   '지원',
#   '위생',
#   '단속',
#   '방역',
#   '관리',
#   '환경',
#   '정비',
#   '실시',
#   '주민',
#   '감염병',
#   '대한',
#   '불안감',
#   '해소',
#   '보건관리',
#   '강화',
#   '통한',
#   '감염병',
#   '사전',
#   '예방',
#   '추진',
#   '박용',
#   '갑',
#   '청장',
#   '지역',
#   '내',
#   '코로나',
#   '예방',
#   '확산',
#   '방지',
#   '위해',
#   '촘촘',
#   '방역',
#   '망',
#   '구축',
#   '대책',
#   '마련',
#   '최선',
#   '강조',
#   '앞',
#   '초심',
#   '그대로',
#   '청장',
#   '살림',
#   '청장',
#   '명예',
#   '선',
#   '구청',
#   '고',
#   '소감'],
#  ['전자신문',
#   '금융',
#   '전문',
#   '기업',
#   '풀',
#   '증시',
#   '분석',
#   '전문',
#   '기자',
#   '로봇',
#   '기사',
#   '하이',
#   '투자',
#   '증권',
#   '유한양행',
#   '대해',
#   '레이저',
#   '티닙',
#   '순항',
#   '중',
#   '라며',
#   '투자',
#   '의견',
#   '유지',
#   '제시',
#   '목표',
#   '주가',
#   '하이',
#   '투자',
#   '증권',
#   '박재경',
#   '애널',
#   '리스트',
#   '종목',
#   '대하',
#   '제시',
#   '유지',
#   '의견',
#   '하이',
#   '투자',
#   '증권',
#   '직전',
#   '매매',
#   '의견',
#   '올해',
#   '초반',
#   '매매',
#   '의견',
#   '기준',
#   '볼때',
#   '역시',
#   '매수',
#   '의견',
#   '계속',
#   '유지',
#   '상태',
#   '최근',
#   '분기',
#   '내',
#   '발표',
#   '전체',
#   '증권사',
#   '리포트',
#   '컨센서스',
#   '비교',
#   '경우',
#   '오늘',
#   '발표',
#   '투자',
#   '의견',
#   '체적',
#   '평균',
#   '치',
#   '해당',
#   '수준',
#   '의견',
#   '종목',
#   '대한',
#   '전체',
#   '흐름',
#   '크게',
#   '분석',
#   '목표',
#   '주가',
#   '추이',
#   '최근',
#   '차례',
#   '연속',
#   '목표',
#   '가가',
#   '목표',
#   '가의',
#   '상승',
#   '폭도',
#   '더욱',
#   '모습',
#   '전일',
#   '종가',
#   '기준',
#   '볼때',
#   '종목',
#   '주가',
#   '제시',
#   '목표',
#   '대비',
#   '추가',
#   '상승',
#   '여력',
#   '해석',
#   '제시',
#   '하이',
#   '투자',
#   '증권',
#   '유한양행',
#   '대해',
#   '레이저',
#   '티닙',
#   '상',
#   '종료',
#   '마일',
#   '스톤',
#   '중',
#   '약',
#   '인식',
#   '예정',
#   '연매출',
#   '규모',
#   '글리벡',
#   '도입',
#   '통한',
#   '매출',
#   '성장',
#   '순항',
#   '레이저',
#   '티닙',
#   '하반기',
#   '조건',
#   '부',
#   '허가',
#   '신청',
#   '기대',
#   '내년',
#   '초',
#   '승인',
#   '기대',
#   '분석',
#   '하이',
#   '투자',
#   '증권',
#   '매출',
#   '액',
#   '영업',
#   '이익',
#   '흑자',
#   '전환',
#   '기록',
#   '컨센서스',
#   '상회',
#   '전망',
#   '매출',
#   '액',
#   '영업',
#   '이익',
#   '전망',
#   '하이',
#   '투자',
#   '증권',
#   '종목',
#   '대한',
#   '최근',
#   '개월',
#   '투자',
#   '의견',
#   '전체',
#   '변화',
#   '유지',
#   '목표',
#   '주가',
#   '점',
#   '반대',
#   '점',
#   '제시',
#   '이후',
#   '수준',
#   '조정',
#   '오늘',
#   '하이',
#   '투자',
#   '증권',
#   '발표',
#   '유지',
#   '의견',
#   '목표',
#   '주가',
#   '전체',
#   '컨센서스',
#   '대비',
#   '체적',
#   '평균',
#   '치',
#   '해당',
#   '수준',
#   '의견',
#   '종목',
#   '대한',
#   '전체',
#   '흐름',
#   '크게',
#   '파악',
#   '목표',
#   '평균',
#   '대비',
#   '차이',
#   '집계',
#   '참고',
#   '최근',
#   '목표',
#   '주가',
#   '가장',
#   '공격',
#   '제시',
#   '금융투자',
#   '증권',
#   '투자',
#   '의견',
#   '목표',
#   '주가',
#   '제일',
#   '보수',
#   '의견',
#   '제시',
#   '투자',
#   '증권',
#   '투자',
#   '의견',
#   '하향',
#   '목표',
#   '주가',
#   '제시',
#   '바',
#   '하이',
#   '투자',
#   '증권',
#   '투자',
#   '의견',
#   '추이',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '전체',
#   '증권사',
#   '최근',
#   '리포트',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '하이',
#   '투자',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '현대차',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '한화',
#   '투자',
#   '증권']]

# %% [markdown]
# ## 3. 연관 키워드 추출하기

# %% [markdown]
# ### [트위터 연관 키워드 분석]

# %%
transactions = df['nouns'].tolist()
transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지합니다.and
transactions
# Out:
# [['인천',
#   '해양경찰',
#   '서장',
#   '신동',
#   '도서',
#   '지역',
#   '치안',
#   '강화',
#   '위해',
#   '인천',
#   '중부',
#   '경찰서',
#   '지난달',
#   '업무',
#   '협약',
#   '체결',
#   '여름철',
#   '수기',
#   '치안',
#   '수요',
#   '증가',
#   '예상',
#   '도서',
#   '지역',
#   '특성',
#   '상',
#   '한정',
#   '근무',
#   '인원',
#   '현장',
#   '조치',
#   '대응',
#   '어려움',
#   '해경',
#   '육경',
#   '협조',
#   '체제',
#   '구축',
#   '위해',
#   '업무',
#   '협약',
#   '관할',
#   '구역',
#   '내',
#   '긴급',
#   '상황',
#   '발생',
#   '시',
#   '상호',
#   '인력',
#   '장비',
#   '지원',
#   '업무',
#   '사례',
#   '공유',
#   '데',
#   '협력',
#   '해경',
#   '관계자',
#   '업무',
#   '협약',
#   '육경',
#   '협조',
#   '체제',
#   '구축',
#   '치안',
#   '공백',
#   '최소',
#   '한편',
#   '지속',
#   '업무',
#   '개선',
#   '도서',
#   '지역',
#   '주민',
#   '편익',
#   '증진',
#   '위해',
#   '노력',
#   '고',
#   '말',
#   '인천',
#   '일보'],
#  ['작년',
#   '말',
#   '대비',
#   '두',
#   '배',
#   '가까이',
#   '지난달',
#   '룻새',
#   '급증',
#   '바이오',
#   '청약',
#   '뭉칫돈',
#   '유입',
#   '기관',
#   '외국인',
#   '팔면',
#   '매수',
#   '개미',
#   '시장',
#   '도세',
#   '부상',
#   '국내',
#   '증시',
#   '투자자',
#   '탁금',
#   '규모',
#   '사상',
#   '처음',
#   '지난해',
#   '말',
#   '수준',
#   '탁',
#   '금은',
#   '개월',
#   '약',
#   '두',
#   '배',
#   '불어',
#   '상반기',
#   '개인',
#   '투자자',
#   '코로나',
#   '발',
#   '폭락',
#   '계기',
#   '국내',
#   '주식시장',
#   '매수',
#   '반기',
#   '기준',
#   '역대',
#   '최고',
#   '치',
#   '매수',
#   '기록',
#   '증시',
#   '자금',
#   '개인',
#   '지속',
#   '투자',
#   '기회',
#   '노리',
#   '때문',
#   '풀이',
#   '올해',
#   '기업',
#   '공개',
#   '최대',
#   '유망',
#   '주인',
#   '바이오',
#   '일반',
#   '투자자',
#   '대상',
#   '모주',
#   '청약',
#   '증시',
#   '주변',
#   '자금',
#   '남아',
#   '뭉칫돈',
#   '향방',
#   '시장',
#   '눈길',
#   '상반기',
#   '주식',
#   '개인',
#   '금융투자',
#   '협회',
#   '지난',
#   '기준',
#   '투자자',
#   '탁',
#   '금은',
#   '기록',
#   '탁금',
#   '관련',
#   '통계',
#   '집계',
#   '이후',
#   '처음',
#   '투자자',
#   '탁',
#   '금은',
#   '증시',
#   '투입',
#   '수',
#   '자금',
#   '분류',
#   '지난해',
#   '말',
#   '해도',
#   '수준',
#   '탁',
#   '금은',
#   '서서히',
#   '증가',
#   '코로나',
#   '사태',
#   '증시',
#   '폭락',
#   '기점',
#   '불어',
#   '최근',
#   '후반',
#   '유지',
#   '탁',
#   '금은',
#   '다시',
#   '하루',
#   '사이',
#   '급증',
#   '증권',
#   '바이오',
#   '모주',
#   '배정',
#   '이후',
#   '청약',
#   '증거',
#   '금',
#   '환',
#   '불금',
#   '날',
#   '입금',
#   '영향',
#   '보고',
#   '일반',
#   '투자자',
#   '대상',
#   '바이오',
#   '청약',
#   '달',
#   '증거',
#   '금',
#   '역대',
#   '최대',
#   '기록',
#   '경쟁률',
#   '주식',
#   '배정',
#   '못',
#   '대부분',
#   '증거',
#   '금',
#   '환불',
#   '중',
#   '상당',
#   '금액',
#   '주식시장',
#   '주변',
#   '설명',
#   '개인',
#   '상반기',
#   '돈',
#   '국내',
#   '주식시장',
#   '유가',
#   '증권',
#   '시장',
#   '코스닥',
#   '코넥스',
#   '시장',
#   '합치',
#   '개인',
#   '국내',
#   '주식',
#   '매수',
#   '규모',
#   '달',
#   '기간',
#   '기관',
#   '외국인',
#   '매도',
#   '대조',
#   '개인',
#   '매수',
#   '사상',
#   '첫',
#   '개월',
#   '연속',
#   '매수',
#   '기록',
#   '탁',
#   '금은',
#   '두',
#   '배',
#   '증시',
#   '자금',
#   '향',
#   '인지',
#   '관심',
#   '바이오',
#   '청약',
#   '나선',
#   '신규',
#   '투자자',
#   '중',
#   '상당수',
#   '환불',
#   '증거',
#   '금',
#   '통해',
#   '주식',
#   '투자',
#   '가능성',
#   '겨냥',
#   '한국',
#   '투자',
#   '증권',
#   '바이오',
#   '청약',
#   '참여',
#   '영업',
#   '점',
#   '거래',
#   '고객',
#   '대상',
#   '펀드',
#   '가연',
#   '증권',
#   '가입',
#   '경우',
#   '현금',
#   '지급',
#   '이벤트',
#   '걸',
#   '기도',
#   '개인',
#   '지수',
#   '하락',
#   '매수',
#   '규모',
#   '하방',
#   '지지',
#   '주체',
#   '코스피지수',
#   '하락',
#   '세',
#   '개인',
#   '매수',
#   '외국인',
#   '기관',
#   '주식',
#   '개인',
#   '지수',
#   '틈',
#   '타',
#   '시장',
#   '패턴',
#   '반복',
#   '달',
#   '기관',
#   '매도',
#   '외국인',
#   '지난',
#   '달',
#   '매도',
#   '규모',
#   '축소',
#   '시장',
#   '급',
#   '상장',
#   '줄줄이',
#   '예정',
#   '쪽',
#   '뭉칫돈',
#   '가능성',
#   '제기',
#   '방탄소년단',
#   '소속사',
#   '빅히트',
#   '엔터테인먼트',
#   '카카오',
#   '게임',
#   '솔루엠',
#   '최근',
#   '상장',
#   '예비',
#   '심사',
#   '청구',
#   '하반기',
#   '모주',
#   '청약',
#   '예정',
#   '게임',
#   '테라',
#   '초대',
#   '급',
#   '크래프톤',
#   '블루홀',
#   '도',
#   '하반기',
#   '상장',
#   '예정',
#   '콘텐츠',
#   '대장',
#   '주로',
#   '관심',
#   '카카오페이지',
#   '하반기',
#   '내년',
#   '상장',
#   '준비',
#   '이진우',
#   '메',
#   '리츠',
#   '증권',
#   '연구원',
#   '최근',
#   '개인',
#   '투자자',
#   '열풍',
#   '유가',
#   '증권',
#   '시장',
#   '시가총액',
#   '대비',
#   '탁금',
#   '비율',
#   '기록',
#   '후반',
#   '고',
#   '분석',
#   '후반',
#   '시장',
#   '변동성',
#   '인터넷',
#   '보급',
#   '홈',
#   '트레이딩',
#   '서비스',
#   '개발',
#   '시장',
#   '참여',
#   '코로나',
#   '모바일',
#   '트레이딩',
#   '서비스',
#   '금융',
#   '플랫폼',
#   '이동',
#   '가속',
#   '개인',
#   '주식시장',
#   '접근성',
#   '설명',
#   '연구원',
#   '기술',
#   '진보',
#   '질병',
#   '자산',
#   '가격',
#   '급락',
#   '세',
#   '가지',
#   '요소',
#   '물리',
#   '시장',
#   '환경',
#   '고',
#   '분석'],
#  ['중부',
#   '매일',
#   '서인석',
#   '기자',
#   '차영',
#   '괴산군',
#   '수가',
#   '직원',
#   '조회',
#   '민선',
#   '기',
#   '군정',
#   '성과',
#   '후반기',
#   '군정',
#   '운영',
#   '방향',
#   '군수',
#   '민선',
#   '기',
#   '반기',
#   '마무리',
#   '후반기',
#   '시작',
#   '며',
#   '지난',
#   '여러',
#   '가지',
#   '어려움',
#   '속',
#   '성과',
#   '낼',
#   '수',
#   '군정',
#   '힘',
#   '주신',
#   '공무원',
#   '괴산',
#   '군민',
#   '깊이',
#   '감사',
#   '고',
#   '말',
#   '올해',
#   '상반기',
#   '코로나',
#   '대응',
#   '방역',
#   '활동',
#   '봄철',
#   '산불',
#   '예방',
#   '활동',
#   '총선',
#   '준비',
#   '코로나',
#   '지원',
#   '책',
#   '마련',
#   '추진',
#   '중고',
#   '겹',
#   '더욱',
#   '시기',
#   '며',
#   '위기',
#   '속',
#   '군민',
#   '공무원',
#   '하나로',
#   '극복',
#   '수',
#   '며',
#   '고마움',
#   '전',
#   '지난',
#   '반기',
#   '괴산',
#   '미래',
#   '수립',
#   '괴산',
#   '구체',
#   '미래',
#   '마련',
#   '역대',
#   '최대',
#   '규모',
#   '투자',
#   '유치',
#   '달성',
#   '정부',
#   '예산',
#   '확보',
#   '재정',
#   '기반',
#   '구축',
#   '고',
#   '군수',
#   '재정',
#   '기반',
#   '바탕',
#   '실행',
#   '확보',
#   '지속',
#   '발전',
#   '미래',
#   '기반',
#   '토대',
#   '고',
#   '강조',
#   '괴산',
#   '정신',
#   '정립',
#   '괴산',
#   '사랑',
#   '운동',
#   '적극',
#   '전개',
#   '통한',
#   '군민',
#   '간',
#   '소통',
#   '화합',
#   '문화',
#   '조성',
#   '지역',
#   '안정화',
#   '성과',
#   '고',
#   '군수',
#   '후반기',
#   '군정',
#   '운영',
#   '방향',
#   '제시',
#   '군수',
#   '후반기',
#   '지난',
#   '기반',
#   '바탕',
#   '가시',
#   '지역',
#   '발전',
#   '총력',
#   '며',
#   '위해',
#   '사업',
#   '별',
#   '진도',
#   '관리',
#   '말',
#   '미래',
#   '먹거리',
#   '창',
#   '위',
#   '농업',
#   '관광',
#   '제조',
#   '산업',
#   '분야',
#   '중점',
#   '육성',
#   '라며',
#   '의료',
#   '폐기물',
#   '소각',
#   '건립',
#   '청정',
#   '환경',
#   '저해',
#   '요소',
#   '천적',
#   '차단',
#   '적극',
#   '고',
#   '괴산읍',
#   '기능',
#   '구심력',
#   '정주',
#   '여건',
#   '개선',
#   '위',
#   '사업',
#   '적극',
#   '추진',
#   '며',
#   '단',
#   '명도',
#   '소외',
#   '촘촘',
#   '맞춤',
#   '복지',
#   '실현',
#   '보훈',
#   '단체',
#   '우도',
#   '국가',
#   '위해',
#   '헌신',
#   '더욱',
#   '우대',
#   '수',
#   '문화',
#   '조성',
#   '고',
#   '마지막',
#   '군수',
#   '공무원',
#   '역량',
#   '조직',
#   '군민',
#   '적극',
#   '소통',
#   '군민',
#   '행정',
#   '구현',
#   '며',
#   '공무원',
#   '지역',
#   '거주',
#   '실제',
#   '군민',
#   '호흡',
#   '지역',
#   '동화',
#   '수',
#   '달라',
#   '고',
#   '당부',
#   '한편',
#   '코로나',
#   '예방',
#   '위해',
#   '개월',
#   '개최',
#   '날',
#   '직원',
#   '조회',
#   '참석',
#   '인원',
#   '최소',
#   '발열',
#   '체크',
#   '손',
#   '소독',
#   '참석자',
#   '명단',
#   '기재',
#   '방역',
#   '칙',
#   '진행'],
#  ['라임',
#   '자산운용',
#   '라임',
#   '펀드',
#   '환매',
#   '중단',
#   '사건',
#   '수사',
#   '중인',
#   '검찰',
#   '신한은행',
#   '압수수색',
#   '남부',
#   '검',
#   '형사',
#   '부',
#   '부장',
#   '검사',
#   '조상원',
#   '날',
#   '오전',
#   '서울',
#   '중구',
#   '신한은행',
#   '본점',
#   '사관',
#   '저장',
#   '자료',
#   '관련',
#   '서류',
#   '크레디트',
#   '인',
#   '슈어드',
#   '호',
#   '펀드',
#   '판매',
#   '관련',
#   '자료',
#   '확보',
#   '중이',
#   '신한은행',
#   '펀드',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '부실',
#   '투',
#   '자금',
#   '위해',
#   '설정',
#   '상품',
#   '사실',
#   '투자자',
#   '판매',
#   '혐의',
#   '자본시장',
#   '금융투자',
#   '업',
#   '관',
#   '법률상',
#   '기적',
#   '부정',
#   '거래',
#   '불건전',
#   '영업',
#   '행위',
#   '신한은행',
#   '지난해',
#   '약',
#   '가량',
#   '라임',
#   '펀드',
#   '고객',
#   '판매',
#   '은행',
#   '당시',
#   '펀드',
#   '대해',
#   '해외',
#   '무역',
#   '금융',
#   '관련',
#   '매출채권',
#   '투자',
#   '원금',
#   '이자',
#   '대해',
#   '신용',
#   '보험',
#   '가입',
#   '상품',
#   '소개',
#   '펀드',
#   '중',
#   '자금',
#   '플루토',
#   '호',
#   '플루토',
#   '부실',
#   '발생',
#   '플루토',
#   '무역',
#   '금융',
#   '펀드',
#   '투입',
#   '플루토',
#   '무역',
#   '금융',
#   '펀드',
#   '현재',
#   '환매',
#   '중단',
#   '라임',
#   '개',
#   '펀드',
#   '중',
#   '펀드',
#   '투자자',
#   '명',
#   '지난',
#   '신한은행',
#   '기적',
#   '부정',
#   '거래',
#   '혐의',
#   '데',
#   '지난달',
#   '펀드',
#   '불건전',
#   '영업',
#   '행위',
#   '관련',
#   '혐의',
#   '추가',
#   '차로',
#   '신한은행',
#   '펀드',
#   '규모',
#   '현행법',
#   '규제',
#   '법망',
#   '피',
#   '주장',
#   '검찰',
#   '날',
#   '확보',
#   '압수',
#   '물',
#   '내용',
#   '분석',
#   '뒤',
#   '관련',
#   '차례',
#   '조사',
#   '계획'],
#  ['시모네타',
#   '마루',
#   '스위스',
#   '대통령',
#   '연합뉴스',
#   '자료',
#   '사진',
#   '제네바',
#   '연합뉴스',
#   '임은진',
#   '특파원',
#   '스위스',
#   '정부',
#   '대중교통',
#   '마스크',
#   '착용',
#   '의무',
#   '시모네타',
#   '마루',
#   '대통령',
#   '오후',
#   '현지',
#   '베른',
#   '기자',
#   '회견',
#   '시행',
#   '스위스',
#   '정부',
#   '위험',
#   '지역',
#   '스위스',
#   '입국',
#   '개인',
#   '대해',
#   '격리',
#   '의무',
#   '광고',
#   '스위스',
#   '유럽',
#   '국가',
#   '달리',
#   '코로나',
#   '사태',
#   '발생',
#   '이후',
#   '지금',
#   '마스크',
#   '착용',
#   '의무',
#   '최근',
#   '봉쇄',
#   '조치',
#   '달',
#   '완화',
#   '국경',
#   '개방',
#   '확',
#   '진자',
#   '수가',
#   '다시',
#   '증가',
#   '결정',
#   '연방',
#   '공중보건',
#   '청',
#   '전체',
#   '인구',
#   '스위스',
#   '코로나',
#   '누적',
#   '확',
#   '진자',
#   '날',
#   '현재',
#   '명',
#   '전날',
#   '명',
#   '증가',
#   '전날',
#   '신규',
#   '확',
#   '진자',
#   '명',
#   '비교',
#   '두',
#   '배',
#   '누적',
#   '사망자',
#   '명',
#   '전날',
#   '명'],
#  ['서울',
#   '뉴스',
#   '정경환',
#   '기자',
#   '질병',
#   '관리',
#   '본부',
#   '코로나',
#   '치료',
#   '제로',
#   '특례',
#   '수입',
#   '렘데',
#   '시비르',
#   '공급',
#   '고',
#   '지난',
#   '식품의약품안전처',
#   '특례',
#   '수입',
#   '결정',
#   '후',
#   '질',
#   '수입',
#   '길리',
#   '드',
#   '스코리아',
#   '국내',
#   '도입',
#   '협의',
#   '통해',
#   '지난',
#   '의약품',
#   '무상',
#   '공급',
#   '계약',
#   '체결',
#   '도입',
#   '물량',
#   '대해',
#   '길리어드',
#   '계약',
#   '조건',
#   '비공개',
#   '특례수입',
#   '감염병',
#   '대유행',
#   '공중보건',
#   '위기',
#   '상황',
#   '대처',
#   '위해',
#   '관계',
#   '부처',
#   '요청',
#   '식약처',
#   '국내',
#   '허가',
#   '의약품',
#   '수입',
#   '통해',
#   '수입',
#   '제도',
#   '렘데',
#   '시비르',
#   '투약',
#   '수',
#   '환자',
#   '폐렴',
#   '산소',
#   '치료',
#   '중증',
#   '환자',
#   '제한',
#   '중증',
#   '환자',
#   '치료',
#   '병원',
#   '국립',
#   '중앙',
#   '의료',
#   '의약품',
#   '공급',
#   '요청',
#   '국립',
#   '중앙',
#   '의료',
#   '필요',
#   '시',
#   '신종',
#   '감염병',
#   '중앙',
#   '임',
#   '위원회',
#   '자문',
#   '요청',
#   '투약',
#   '대상자',
#   '결정',
#   '용량',
#   '투여',
#   '기간',
#   '바이',
#   '알',
#   '투여',
#   '원칙',
#   '필요',
#   '시',
#   '연장',
#   '전체',
#   '투여',
#   '기간',
#   '최대',
#   '정은경',
#   '질',
#   '본부장',
#   '렘데',
#   '시비르',
#   '추가',
#   '물량',
#   '확보',
#   '위해',
#   '국내',
#   '수입',
#   '길리',
#   '드',
#   '스코리아',
#   '계속',
#   '협력',
#   '치료',
#   '확보',
#   '최선',
#   '달',
#   '무상',
#   '공급',
#   '물량',
#   '확보',
#   '이후',
#   '가격',
#   '협상',
#   '통한',
#   '구매',
#   '계획'],
#  ['농림축산식품부',
#   '주최',
#   '지난달',
#   '세종',
#   '컨벤션',
#   '센터',
#   '농',
#   '식품',
#   '수출',
#   '우수',
#   '지방자치단체',
#   '경진',
#   '대회',
#   '북도',
#   '광역',
#   '자치',
#   '단체',
#   '부',
#   '최우수상',
#   '김천시',
#   '기초',
#   '자치',
#   '단체',
#   '부',
#   '대상',
#   '상주시',
#   '청도군',
#   '우수상',
#   '차지',
#   '전국',
#   '개',
#   '수상',
#   '자치',
#   '단체',
#   '중',
#   '개',
#   '경북',
#   '농',
#   '식품',
#   '수출',
#   '정책',
#   '전국',
#   '최고',
#   '임',
#   '증명',
#   '경진',
#   '대회',
#   '전국',
#   '자치',
#   '단체',
#   '중',
#   '예선',
#   '통과',
#   '개',
#   '지자체',
#   '광역',
#   '기초',
#   '지난달',
#   '차',
#   '대국민',
#   '호감',
#   '평가',
#   '지난달',
#   '차',
#   '전문가',
#   '평가',
#   '통해',
#   '최종',
#   '선정',
#   '북도',
#   '수출',
#   '확대',
#   '위',
#   '개념',
#   '과일',
#   '종이',
#   '트',
#   '레이',
#   '개발',
#   '우수',
#   '높이',
#   '김천시',
#   '망',
#   '고향이',
#   '샤인',
#   '머스켓',
#   '수출',
#   '전략',
#   '품목',
#   '육성',
#   '중국',
#   '동남아',
#   '중심',
#   '괄목',
#   '만',
#   '수출',
#   '증대',
#   '평가',
#   '상주시',
#   '해외',
#   '지인',
#   '접근',
#   '수',
#   '고안',
#   '노출',
#   '대화',
#   '미니',
#   '홍보',
#   '관',
#   '운영',
#   '포도',
#   '곶감',
#   '홍보',
#   '효과',
#   '청도군',
#   '수출',
#   '유망',
#   '품목',
#   '감',
#   '말랭이',
#   '신규',
#   '수출',
#   '상품',
#   '개발',
#   '수출',
#   '확대',
#   '기여',
#   '점',
#   '호평',
#   '경북',
#   '도의',
#   '개념',
#   '과일',
#   '트',
#   '레이',
#   '사과',
#   '유통',
#   '과정',
#   '사용',
#   '발포',
#   '폴리에틸렌',
#   '스티로폼',
#   '트레이',
#   '압상',
#   '눌림',
#   '상처',
#   '문제',
#   '기능',
#   '종이',
#   '대체',
#   '획기',
#   '해결',
#   '함',
#   '수출',
#   '과일',
#   '품질',
#   '유지',
#   '수',
#   '최근',
#   '국내외',
#   '친환경',
#   '정책',
#   '확산',
#   '향후',
#   '보급',
#   '증가',
#   '기대',
#   '한편',
#   '북도',
#   '지속',
#   '농',
#   '식품',
#   '수출',
#   '시책',
#   '추진',
#   '통해',
#   '수준',
#   '농',
#   '식품',
#   '수출',
#   '실적',
#   '돌파',
#   '지난해',
#   '연속',
#   '초과',
#   '달성',
#   '성과'],
#  ['미래',
#   '통합',
#   '주호영',
#   '원내대표',
#   '오후',
#   '국회',
#   '원내대표',
#   '회의실',
#   '비공개',
#   '율',
#   '출신',
#   '의원',
#   '회의',
#   '관련',
#   '브리핑',
#   '뒤',
#   '퇴장',
#   '주',
#   '원내대표',
#   '날',
#   '가슴',
#   '규탄',
#   '민주당',
#   '민주주의',
#   '붕괴',
#   '리본',
#   '연합뉴스',
#   '과거',
#   '세월호',
#   '사고',
#   '교통사고',
#   '던',
#   '주호영',
#   '미래',
#   '통합',
#   '원내대표',
#   '국회',
#   '세월호',
#   '여론',
#   '민주당',
#   '주',
#   '원내대표',
#   '국회',
#   '세월호',
#   '데',
#   '대해',
#   '착오',
#   '인식',
#   '고',
#   '비판',
#   '박성준',
#   '민주당',
#   '대변인',
#   '날',
#   '논평',
#   '통해',
#   '통합',
#   '세월호',
#   '참사',
#   '언급',
#   '자격',
#   '며',
#   '민생',
#   '외면',
#   '통합',
#   '모습',
#   '승객',
#   '안전',
#   '홀로',
#   '세월호',
#   '선장',
#   '모습',
#   '중첩',
#   '고',
#   '지적',
#   '지금',
#   '미래',
#   '통합',
#   '박근혜',
#   '정부',
#   '탄생',
#   '기여',
#   '과거',
#   '새누리당',
#   '모습',
#   '고',
#   '주',
#   '원내대표',
#   '날',
#   '오전',
#   '소셜네트워크서비스',
#   '폭주',
#   '기관차',
#   '개문',
#   '발차',
#   '세월호',
#   '글',
#   '국회',
#   '추미애',
#   '법무',
#   '장관',
#   '얘기',
#   '통제',
#   '폭주',
#   '기관차',
#   '며',
#   '폭주',
#   '열차',
#   '세월호',
#   '고',
#   '주장',
#   '개문',
#   '발차',
#   '국회',
#   '수렁',
#   '처',
#   '폭주',
#   '세월호',
#   '항해',
#   '맹골수도',
#   '생명',
#   '희생',
#   '채',
#   '침몰',
#   '고',
#   '지난',
#   '오후',
#   '경기도',
#   '안산시',
#   '단원구',
#   '화랑유원지',
#   '세월호',
#   '참사',
#   '주기',
#   '기억',
#   '사회',
#   '거리',
#   '두기',
#   '일환',
#   '의자',
#   '일정',
#   '간격',
#   '연합뉴스',
#   '주',
#   '원내대표',
#   '지난',
#   '새누리당',
#   '정책',
#   '위',
#   '의장',
#   '시절',
#   '당',
#   '최고',
#   '위원',
#   '회의',
#   '당시',
#   '야당',
#   '새정치',
#   '민주',
#   '연합',
#   '세월호',
#   '특별법',
#   '협상',
#   '과정',
#   '대해',
#   '설명',
#   '도중',
#   '새누리당',
#   '입장',
#   '기본',
#   '사고',
#   '교통사고',
#   '주장',
#   '사람',
#   '희생',
#   '케이스',
#   '재판',
#   '절차',
#   '간소',
#   '하자',
#   '국가',
#   '보상',
#   '배상금',
#   '전액',
#   '대납',
#   '국가',
#   '나중',
#   '절차',
#   '청해진해운',
#   '세월호',
#   '특별법',
#   '설계',
#   '라며',
#   '그것',
#   '해도',
#   '일반',
#   '사고',
#   '비',
#   '특례',
#   '규정',
#   '지적',
#   '주',
#   '원내대표',
#   '지난',
#   '달',
#   '원내대표',
#   '경선',
#   '토론회',
#   '지금',
#   '소신',
#   '전혀',
#   '고',
#   '답',
#   '강',
#   '병원',
#   '민주당',
#   '의원',
#   '주',
#   '원내대표',
#   '소신',
#   '납득',
#   '수',
#   '소신',
#   '유가족',
#   '아픔',
#   '기억',
#   '추모',
#   '국민',
#   '수',
#   '상처',
#   '주더',
#   '세월호',
#   '거론',
#   '국회',
#   '원',
#   '구성',
#   '저주',
#   '고',
#   '비판',
#   '도대체',
#   '세월호',
#   '정',
#   '쟁의',
#   '도구로',
#   '상대',
#   '정파',
#   '비난',
#   '수단',
#   '악용',
#   '강',
#   '의원',
#   '세월호',
#   '참사',
#   '책임',
#   '정당',
#   '일원',
#   '안전',
#   '사회',
#   '건설',
#   '성찰',
#   '동참',
#   '인식',
#   '소신',
#   '양',
#   '비유',
#   '양',
#   '포장',
#   '고',
#   '주',
#   '원내대표',
#   '비판',
#   '정의당',
#   '배진교',
#   '원내대표',
#   '가운데',
#   '국회',
#   '의원',
#   '총회',
#   '발언',
#   '연합뉴스',
#   '정의당',
#   '비판',
#   '행렬',
#   '가세',
#   '김종철',
#   '선임',
#   '대변인',
#   '국회',
#   '상황',
#   '세월호',
#   '침몰',
#   '유가족',
#   '예의',
#   '라며',
#   '주',
#   '원내대표',
#   '발언',
#   '취소',
#   '사과',
#   '하라',
#   '고',
#   '김',
#   '선',
#   '입대',
#   '변인',
#   '비판',
#   '금도',
#   '라며',
#   '지금',
#   '상황',
#   '마음',
#   '비판',
#   '해도',
#   '유가족',
#   '마음',
#   '대못',
#   '수도',
#   '세월호',
#   '침몰',
#   '꼭',
#   '질문',
#   '실제',
#   '지난',
#   '박근혜',
#   '정권',
#   '미래',
#   '통합',
#   '전신',
#   '새누리당',
#   '알',
#   '통합',
#   '세월호',
#   '대해',
#   '지금',
#   '세월호',
#   '걱정',
#   '척',
#   '실제',
#   '대못',
#   '행위',
#   '누가',
#   '주호영',
#   '원내대표',
#   '발언',
#   '이해해',
#   '줄',
#   '수',
#   '말',
#   '정의당',
#   '주',
#   '원내대표',
#   '발언',
#   '철회',
#   '유족',
#   '대한',
#   '사과',
#   '요구'],
#  ['금융감독원',
#   '이후',
#   '은행',
#   '증권사',
#   '판매',
#   '판매',
#   '라임',
#   '자산운용',
#   '무역',
#   '금융',
#   '펀드',
#   '플루토',
#   '호',
#   '분쟁',
#   '조정',
#   '건',
#   '대해',
#   '투자',
#   '원금',
#   '전액',
#   '투자자',
#   '반환',
#   '결정',
#   '금감원',
#   '금융',
#   '분쟁',
#   '조정',
#   '위원회',
#   '분조',
#   '위',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '분쟁',
#   '조정',
#   '신청',
#   '건',
#   '대해',
#   '착오',
#   '계약',
#   '취소',
#   '결론',
#   '분쟁',
#   '조정',
#   '과정',
#   '계약',
#   '취소',
#   '원금',
#   '반환',
#   '결정',
#   '처음',
#   '분조',
#   '위',
#   '계약',
#   '체결',
#   '시점',
#   '펀드',
#   '투자',
#   '원금',
#   '최대',
#   '달',
#   '손실',
#   '발생',
#   '상황',
#   '운용',
#   '투자',
#   '제안',
#   '수익률',
#   '투자',
#   '위험',
#   '핵심',
#   '정보',
#   '허위',
#   '부실',
#   '기재',
#   '며',
#   '판매',
#   '투자',
#   '제안',
#   '내용',
#   '그대로',
#   '설명',
#   '함',
#   '투자자',
#   '착오',
#   '유발',
#   '고',
#   '분조',
#   '위',
#   '판매',
#   '자의',
#   '허위',
#   '투자',
#   '정보',
#   '설명',
#   '투자자',
#   '성향',
#   '임의',
#   '기재',
#   '손실',
#   '보전',
#   '각서',
#   '작성',
#   '합리',
#   '투자',
#   '판단',
#   '기회',
#   '박탈',
#   '점',
#   '고려',
#   '투자자',
#   '중과실',
#   '보기',
#   '판단',
#   '사기',
#   '착오',
#   '계약',
#   '취소',
#   '판단',
#   '향후',
#   '라임',
#   '운용',
#   '사태',
#   '관련',
#   '법원',
#   '판단',
#   '결론',
#   '날',
#   '때문',
#   '원금',
#   '배상',
#   '전례',
#   '수준',
#   '해외',
#   '금리',
#   '계',
#   '파생',
#   '결합',
#   '펀드',
#   '사태',
#   '당시',
#   '분쟁',
#   '조정',
#   '투자',
#   '손실',
#   '최대',
#   '배상하',
#   '결정',
#   '금감원',
#   '분조',
#   '위',
#   '결정',
#   '내용',
#   '개인',
#   '명',
#   '법인',
#   '개사',
#   '대해',
#   '최대',
#   '원',
#   '보상',
#   '전망'],
#  ['증권',
#   '은행',
#   '팀',
#   '금융감독원',
#   '이후',
#   '라임',
#   '자산운용',
#   '플루토',
#   '호',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '가입',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '결정',
#   '리자',
#   '펀드',
#   '판',
#   '은행',
#   '증권사',
#   '정안',
#   '수용',
#   '검토',
#   '조정',
#   '대상',
#   '이후',
#   '판매',
#   '분만',
#   '개별',
#   '은행',
#   '증권사',
#   '억원',
#   '규모',
#   '플루토',
#   '호',
#   '판',
#   '은행',
#   '경우',
#   '자금',
#   '여력',
#   '이의',
#   '정안',
#   '관측',
#   '금감원',
#   '분쟁',
#   '조정',
#   '위원회',
#   '날',
#   '환매',
#   '중단',
#   '플루토',
#   '호',
#   '관련',
#   '건의',
#   '분쟁',
#   '대해',
#   '판매',
#   '이후',
#   '펀드',
#   '산',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '조정',
#   '결정',
#   '투자자',
#   '계약',
#   '체결',
#   '시점',
#   '펀드',
#   '투자',
#   '원금',
#   '기준',
#   '최대',
#   '손실',
#   '발생',
#   '상황',
#   '운용',
#   '투자',
#   '제안',
#   '수익률',
#   '허위',
#   '부실',
#   '기재',
#   '판매',
#   '사도',
#   '내용',
#   '그대로',
#   '설명',
#   '투자자',
#   '착오',
#   '유발',
#   '이유',
#   '조정',
#   '안이',
#   '결정',
#   '건의',
#   '경우',
#   '판매',
#   '우리은행',
#   '하나은행',
#   '금융투자',
#   '미래에셋',
#   '대우',
#   '우리은행',
#   '분쟁',
#   '조정',
#   '결정',
#   '문',
#   '접수',
#   '후',
#   '내부',
#   '의사결정',
#   '과정',
#   '수락',
#   '결정',
#   '예정',
#   '공식',
#   '입장',
#   '하나은행',
#   '분쟁',
#   '정위',
#   '결정',
#   '검토',
#   '은행',
#   '수',
#   '범위',
#   '내',
#   '최대한',
#   '투자자',
#   '보호',
#   '위',
#   '의사결정',
#   '고',
#   '말',
#   '금융투자',
#   '관계자',
#   '부적',
#   '검토',
#   '결정',
#   '계획',
#   '이사회',
#   '결정',
#   '나기',
#   '주일',
#   '정도',
#   '설명',
#   '미래에셋',
#   '대우',
#   '분쟁',
#   '정결',
#   '정문',
#   '수령',
#   '고객',
#   '입장',
#   '고려',
#   '해당',
#   '내용',
#   '검토',
#   '예정',
#   '결정',
#   '문',
#   '보통',
#   '안',
#   '해당',
#   '기관',
#   '통지',
#   '기관',
#   '결정',
#   '문',
#   '통지',
#   '이후',
#   '안',
#   '분쟁',
#   '조정',
#   '수용',
#   '결정',
#   '조정',
#   '이의',
#   '제기',
#   '절차',
#   '수락',
#   '유서',
#   '제출',
#   '수',
#   '분조',
#   '위',
#   '건의',
#   '분쟁',
#   '관',
#   '조정',
#   '결정',
#   '분조',
#   '위',
#   '이후',
#   '가입',
#   '투자자',
#   '제기',
#   '분쟁',
#   '조정',
#   '신청',
#   '건수',
#   '건',
#   '가운데',
#   '대표',
#   '유형',
#   '사례',
#   '건',
#   '심의',
#   '결정',
#   '이기',
#   '때문',
#   '사실',
#   '이후',
#   '플루토',
#   '가입',
#   '모든',
#   '투자자',
#   '원금',
#   '전액',
#   '결정',
#   '플루토',
#   '호',
#   '펀드',
#   '판매',
#   '액',
#   '가운데',
#   '말',
#   '이후',
#   '판매',
#   '규모',
#   '정도',
#   '지금',
#   '중도',
#   '환매',
#   '금액',
#   '개인',
#   '명',
#   '법인',
#   '개사',
#   '분쟁',
#   '조정',
#   '대상',
#   '오른',
#   '셈',
#   '은행권',
#   '수',
#   '원대',
#   '개별',
#   '은행',
#   '판매',
#   '액',
#   '이후',
#   '규모',
#   '판매',
#   '은행',
#   '조정',
#   '결정',
#   '가능성',
#   '관측',
#   '판매',
#   '사가',
#   '건의',
#   '분조',
#   '위',
#   '결정',
#   '수용',
#   '나머지',
#   '투자자',
#   '판매',
#   '반환',
#   '위',
#   '자율',
#   '조정',
#   '절차',
#   '반환',
#   '정안',
#   '판매',
#   '해도',
#   '이전',
#   '플루토',
#   '가입',
#   '투자자',
#   '반환',
#   '대상',
#   '은행',
#   '관계자',
#   '이후',
#   '은행',
#   '판매',
#   '플루토',
#   '호의',
#   '경우',
#   '은행',
#   '운용',
#   '설명',
#   '진위',
#   '제대로',
#   '확인',
#   '못',
#   '판매',
#   '측면',
#   '때문',
#   '조정',
#   '결정',
#   '가능성',
#   '며',
#   '이전',
#   '해당',
#   '펀드',
#   '은행권',
#   '취급',
#   '소수',
#   '판매',
#   '사례',
#   '불완전',
#   '판매',
#   '보기',
#   '게',
#   '은행',
#   '판단',
#   '만큼',
#   '일괄',
#   '반환',
#   '증권사',
#   '경우',
#   '이전',
#   '판매',
#   '규모',
#   '개별',
#   '회사',
#   '수',
#   '천억원',
#   '경우',
#   '만큼',
#   '더욱',
#   '일괄',
#   '반환',
#   '난색',
#   '가능성',
#   '상황'],
#  ['한진',
#   '칼',
#   '발행',
#   '추진',
#   '신주인수권',
#   '부',
#   '사채',
#   '인기',
#   '몰이',
#   '만기',
#   '금리',
#   '비교',
#   '금리',
#   '신주인수권',
#   '행사',
#   '가가',
#   '현',
#   '주가',
#   '대비',
#   '경영',
#   '분쟁',
#   '진행',
#   '중인',
#   '까닭',
#   '개인',
#   '투자자',
#   '중심',
#   '향후',
#   '차익',
#   '실현',
#   '대감',
#   '겹',
#   '강',
#   '성부',
#   '펀드',
#   '비롯',
#   '주주',
#   '연합',
#   '측은',
#   '청약',
#   '참여',
#   '반면',
#   '조원태',
#   '한진',
#   '그룹',
#   '회장',
#   '일가',
#   '불참',
#   '기사',
#   '참전',
#   '주목',
#   '한진',
#   '칼',
#   '발행',
#   '주간',
#   '사인',
#   '유진',
#   '투자',
#   '증권',
#   '규모',
#   '발행',
#   '청약',
#   '개인',
#   '기관',
#   '청약',
#   '증거',
#   '금',
#   '몰리',
#   '최종',
#   '경쟁률',
#   '기록',
#   '신용등급',
#   '전망',
#   '부정',
#   '펀더',
#   '멘털',
#   '대비',
#   '한진',
#   '칼',
#   '주가',
#   '기관',
#   '참여',
#   '상대',
#   '주주',
#   '연합',
#   '측은',
#   '신주인수권',
#   '확보',
#   '위해',
#   '직접',
#   '청약',
#   '반면',
#   '조',
#   '회장',
#   '일가',
#   '청약',
#   '불참',
#   '전언',
#   '관건',
#   '조',
#   '회장',
#   '기사',
#   '투자자',
#   '참여',
#   '기관',
#   '투자가',
#   '참여',
#   '조건',
#   '전략',
#   '제휴',
#   '관계',
#   '염두',
#   '기업',
#   '투자자',
#   '기사',
#   '가능성'],
#  ['노은주',
#   '임',
#   '형남',
#   '가온',
#   '건축',
#   '공동',
#   '대표',
#   '설계',
#   '사무소',
#   '개업',
#   '초창',
#   '기',
#   '시골',
#   '집',
#   '설계',
#   '일이',
#   '집',
#   '땅',
#   '우물',
#   '여러',
#   '가지',
#   '사정',
#   '상황',
#   '그냥',
#   '흙',
#   '시멘트',
#   '방법',
#   '여러',
#   '가지',
#   '궁리',
#   '마침',
#   '이웃',
#   '어르신',
#   '조언',
#   '우물',
#   '먼저',
#   '돌',
#   '위로',
#   '돌',
#   '자갈',
#   '순서',
#   '흙',
#   '래야',
#   '땅',
#   '아래',
#   '물의',
#   '길',
#   '물',
#   '원래',
#   '길',
#   '가게',
#   '사람',
#   '위',
#   '살',
#   '이야기',
#   '사실',
#   '말',
#   '자연',
#   '조화',
#   '이지',
#   '막상',
#   '방법',
#   '실행',
#   '모습',
#   '적',
#   '별로',
#   '무척',
#   '말',
#   '점',
#   '이후',
#   '생각',
#   '내',
#   '책상',
#   '머리',
#   '항상',
#   '인간',
#   '스스로',
#   '무척',
#   '생각',
#   '과학',
#   '기술',
#   '이면',
#   '화성',
#   '이건',
#   '수',
#   '자부',
#   '룻',
#   '저녁',
#   '비',
#   '도로',
#   '물',
#   '잠기',
#   '옹벽',
#   '인명',
#   '피해',
#   '속출',
#   '속수무책',
#   '순간',
#   '세찬',
#   '바람',
#   '집들이',
#   '자동차',
#   '매년',
#   '인간',
#   '자연',
#   '통제',
#   '활용',
#   '수',
#   '정신승리',
#   '구가',
#   '자연',
#   '늘',
#   '길',
#   '간다',
#   '자연',
#   '보호',
#   '자연',
#   '비',
#   '존재',
#   '인간',
#   '살기',
#   '위해',
#   '파악',
#   '자연',
#   '타협',
#   '그게',
#   '길이',
#   '풍수',
#   '알',
#   '자연',
#   '대한',
#   '두려움',
#   '시작',
#   '자연',
#   '방법',
#   '모색',
#   '도선국사',
#   '무학대사',
#   '생각',
#   '한국',
#   '풍수',
#   '사상',
#   '더욱',
#   '돈',
#   '아들',
#   '장수',
#   '술법',
#   '자연',
#   '대한',
#   '외가',
#   '뼈대',
#   '환경',
#   '친',
#   '화란',
#   '소위',
#   '친환경',
#   '자재',
#   '무',
#   '농약',
#   '농산물',
#   '대한',
#   '선호',
#   '자연',
#   '대한',
#   '인간',
#   '자세',
#   '인간',
#   '오만',
#   '탐욕',
#   '대한',
#   '고등',
#   '여러',
#   '번',
#   '외면',
#   '포클레인',
#   '위',
#   '흙',
#   '콘크리트',
#   '옹벽',
#   '집',
#   '기술',
#   '강의',
#   '물길',
#   '산',
#   '허리',
#   '길',
#   '가책',
#   '두려움',
#   '세상',
#   '가장',
#   '공생',
#   '윤리',
#   '부정',
#   '면역',
#   '체계',
#   '파괴',
#   '탐욕',
#   '바이러스',
#   '전',
#   '세상',
#   '생태',
#   '운동',
#   '김종철',
#   '선생',
#   '칼럼',
#   '메시지',
#   '더욱',
#   '절실'],
#  ['전선',
#   '병원',
#   '주년',
#   '제약',
#   '최선',
#   '진료',
#   '제공',
#   '선포',
#   '선',
#   '병원',
#   '병상',
#   '선정',
#   '외과의',
#   '시작',
#   '현재',
#   '개',
#   '전문',
#   '진료',
#   '센터',
#   '개',
#   '진료',
#   '명의',
#   '전문',
#   '의료',
#   '진',
#   '종합병원',
#   '이규',
#   '은',
#   '선',
#   '병원',
#   '재단',
#   '관원',
#   '모든',
#   '제약',
#   '최선',
#   '진료',
#   '병원',
#   '사명',
#   '바탕',
#   '환자',
#   '며',
#   '하루',
#   '변화',
#   '세상',
#   '의료',
#   '환경',
#   '속',
#   '시대',
#   '요구',
#   '변화',
#   '부응',
#   '환자',
#   '배려',
#   '문화',
#   '병원',
#   '수',
#   '노력',
#   '고',
#   '포부'],
#  ['가수',
#   '신용재',
#   '오후',
#   '서울',
#   '마포구',
#   '서교동',
#   '하나투어',
#   '브이',
#   '홀',
#   '첫',
#   '정규',
#   '앨범',
#   '디어',
#   '발매',
#   '기념',
#   '쇼케이스',
#   '참석',
#   '신곡'],
#  ['민관',
#   '협력',
#   '수소',
#   '경제',
#   '컨트롤',
#   '타워',
#   '위원회',
#   '출범',
#   '총리',
#   '주재',
#   '정의선',
#   '수석',
#   '부회장',
#   '명의',
#   '위원',
#   '임명',
#   '위촉',
#   '정',
#   '총리',
#   '수소차',
#   '보조금',
#   '부품',
#   '국산',
#   '투자',
#   '폭',
#   '지원',
#   '정',
#   '수석',
#   '부회장',
#   '정책',
#   '지원',
#   '요청',
#   '산업',
#   '발전',
#   '가능성',
#   '아시아',
#   '경제',
#   '우수',
#   '연',
#   '기자',
#   '김지희',
#   '기자',
#   '대한민국',
#   '경제',
#   '컨트롤',
#   '타워',
#   '위원회',
#   '출범',
#   '정세균',
#   '국무총리',
#   '정의선',
#   '현대',
#   '자동차',
#   '그룹',
#   '총괄',
#   '수석',
#   '부회장',
#   '민관',
#   '핵심',
#   '인사',
#   '위원',
#   '참여',
#   '위원회',
#   '경제',
#   '실현',
#   '위',
#   '정책',
#   '산업',
#   '발전',
#   '역할',
#   '담당',
#   '날',
#   '모빌리티',
#   '쇼',
#   '조직',
#   '위원회',
#   '민관',
#   '참여',
#   '위원회',
#   '일산',
#   '킨텍스',
#   '출범',
#   '경제',
#   '관련',
#   '정책',
#   '현안',
#   '논의',
#   '세계',
#   '최초',
#   '수소',
#   '모빌리티',
#   '전시회',
#   '모빌리티',
#   '쇼',
#   '개막',
#   '일정',
#   '출범',
#   '위원회',
#   '범',
#   '정부',
#   '차원',
#   '수소',
#   '에너지',
#   '컨트롤',
#   '타워',
#   '일원화',
#   '수소',
#   '경제',
#   '정책',
#   '마련',
#   '초석',
#   '기대',
#   '위원회',
#   '정',
#   '총리',
#   '비롯',
#   '개',
#   '부처',
#   '장관',
#   '정부',
#   '위원',
#   '정',
#   '수석',
#   '부회장',
#   '산업',
#   '학계',
#   '임명',
#   '명의',
#   '민간',
#   '위원',
#   '구성',
#   '날',
#   '첫',
#   '회의',
#   '위원',
#   '대한',
#   '위촉',
#   '수여',
#   '상견례',
#   '자리',
#   '수소',
#   '산업',
#   '생태계',
#   '조성',
#   '방안',
#   '전담',
#   '기관',
#   '지정',
#   '구체',
#   '방안',
#   '논의',
#   '위원장',
#   '정',
#   '총리',
#   '수소차',
#   '보조금',
#   '수소',
#   '에너지',
#   '연구개발',
#   '투자',
#   '부품',
#   '소재',
#   '국산',
#   '율',
#   '민간',
#   '주도',
#   '경제',
#   '실현',
#   '위해',
#   '모든',
#   '정책',
#   '지원',
#   '입장',
#   '수소',
#   '에너지',
#   '발전',
#   '중요성',
#   '선도',
#   '국가',
#   '로서',
#   '한국',
#   '위상',
#   '고',
#   '강조',
#   '정',
#   '총리',
#   '수소',
#   '에너지',
#   '생산',
#   '공급',
#   '확대',
#   '약속',
#   '경제',
#   '지속가능성',
#   '언급',
#   '국민',
#   '부담',
#   '가격',
#   '수소',
#   '구매',
#   '수',
#   '산업',
#   '생태계',
#   '창',
#   '출하',
#   '출력',
#   '제한',
#   '전기',
#   '활용',
#   '수소',
#   '생산',
#   '수',
#   '고',
#   '말',
#   '민간',
#   '위원',
#   '임명',
#   '정',
#   '부회장',
#   '범',
#   '정부',
#   '차원',
#   '지속',
#   '수소',
#   '경제',
#   '활성화',
#   '정책',
#   '지원',
#   '요청',
#   '현대차',
#   '그룹',
#   '기술',
#   '개발',
#   '산업',
#   '측면',
#   '글로벌',
#   '경제',
#   '화답',
#   '위원회',
#   '출범',
#   '당초',
#   '내년',
#   '예정',
#   '경제',
#   '컨트롤',
#   '타워',
#   '부재',
#   '정책',
#   '지연',
#   '경쟁',
#   '국가',
#   '기술',
#   '발전',
#   '대응',
#   '사안',
#   '감안',
#   '달',
#   '지난해',
#   '초',
#   '정부',
#   '국내',
#   '수소',
#   '전기차',
#   '누적',
#   '보급',
#   '충전',
#   '소',
#   '개',
#   '구축',
#   '골자',
#   '수소',
#   '경제',
#   '활성화',
#   '로드맵',
#   '발표',
#   '올해',
#   '수소',
#   '전기차',
#   '국내',
#   '누적',
#   '보급',
#   '대수',
#   '육박',
#   '충전',
#   '소',
#   '올해',
#   '설치',
#   '계획',
#   '현대차',
#   '수소',
#   '전용',
#   '트럭',
#   '콘셉트카',
#   '넵튠',
#   '산업',
#   '측면',
#   '경제',
#   '선도',
#   '현대차',
#   '그룹',
#   '수소',
#   '전기',
#   '스포츠',
#   '유틸리티',
#   '차량',
#   '넥쏘',
#   '데',
#   '상용차',
#   '시장',
#   '연료',
#   '전지',
#   '적용',
#   '범위',
#   '확대',
#   '지난해',
#   '현대차',
#   '스위스',
#   '수소',
#   '에너지',
#   '기업',
#   '에너지',
#   '합작',
#   '법인',
#   '설립',
#   '유럽',
#   '시장',
#   '규모',
#   '수소',
#   '전기',
#   '대형',
#   '트럭',
#   '공급',
#   '미국',
#   '커민',
#   '스',
#   '북미',
#   '상용차',
#   '시장',
#   '연료',
#   '시스템',
#   '공급',
#   '업무',
#   '협약',
#   '체결',
#   '양사',
#   '친환경',
#   '파워',
#   '트레인',
#   '공동',
#   '개발',
#   '현대차',
#   '첫',
#   '수소',
#   '전용',
#   '대형',
#   '트럭',
#   '콘셉트',
#   '카',
#   '넵튠',
#   '북미',
#   '시장',
#   '세계',
#   '최초',
#   '공개',
#   '공격',
#   '북미',
#   '상용차',
#   '시장',
#   '진출',
#   '염두',
#   '때문',
#   '날',
#   '현대차',
#   '코스피',
#   '증권',
#   '정보',
#   '현재',
#   '전일',
#   '대비',
#   '등락',
#   '률',
#   '거래',
#   '량',
#   '전일',
#   '장',
#   '모빌리티',
#   '쇼',
#   '통해',
#   '넵튠',
#   '콘셉트카',
#   '국내',
#   '최초',
#   '공개',
#   '이동형',
#   '연료',
#   '전지',
#   '발전기',
#   '연료',
#   '시스템',
#   '분야',
#   '확장',
#   '가능성',
#   '제시',
#   '현대차',
#   '향후',
#   '이내',
#   '대형',
#   '트럭',
#   '최적화',
#   '출력',
#   '연료',
#   '시스템',
#   '개발',
#   '출시',
#   '예정',
#   '한편',
#   '세계',
#   '최초',
#   '수소',
#   '모빌리티',
#   '전시회',
#   '모빌리티',
#   '쇼',
#   '날',
#   '일산',
#   '킨텍스',
#   '개최',
#   '개국',
#   '수소',
#   '모빌리티',
#   '관련',
#   '기관',
#   '기업',
#   '곳',
#   '참여',
#   '현대차',
#   '모빌리티',
#   '쇼',
#   '통해',
#   '콘셉트',
#   '카',
#   '넵튠',
#   '국내',
#   '시장',
#   '최초',
#   '정',
#   '만기',
#   '조직',
#   '위원장',
#   '전시회',
#   '수소',
#   '에너지',
#   '기술',
#   '발전',
#   '최신',
#   '트렌드',
#   '공유',
#   '무역',
#   '거래',
#   '촉진',
#   '위',
#   '교류',
#   '장',
#   '활용',
#   '며',
#   '향후',
#   '모빌리티',
#   '쇼',
#   '국가',
#   '핵심',
#   '전시회',
#   '말'],
#  ['송대',
#   '익',
#   '유튜브',
#   '캡처',
#   '사진',
#   '유튜브',
#   '채널',
#   '정',
#   '배우',
#   '사건',
#   '사고',
#   '이슈',
#   '송대',
#   '익',
#   '채널',
#   '동영상',
#   '삭제',
#   '지난달',
#   '유튜버',
#   '정',
#   '배우',
#   '송대',
#   '익',
#   '자영',
#   '업자',
#   '악의',
#   '주작',
#   '제목',
#   '영상',
#   '게재',
#   '저격',
#   '앞서',
#   '송대',
#   '피자',
#   '치킨',
#   '판매',
#   '브랜드',
#   '피자',
#   '치킨',
#   '공주',
#   '음식',
#   '배달',
#   '해당',
#   '영상',
#   '피자',
#   '채',
#   '치킨',
#   '조각',
#   '튀김',
#   '껍질',
#   '확인',
#   '송대',
#   '당황',
#   '표정',
#   '매장',
#   '항의',
#   '송대',
#   '환불',
#   '요구',
#   '업주',
#   '거절',
#   '미온',
#   '태도',
#   '업주',
#   '비난',
#   '관련',
#   '정',
#   '조작',
#   '방송',
#   '주장',
#   '직접',
#   '가맹',
#   '점',
#   '점주',
#   '통화',
#   '결과',
#   '답변',
#   '본사',
#   '통화',
#   '명예훼손',
#   '라며',
#   '처리',
#   '부탁',
#   '고',
#   '전',
#   '송대',
#   '익',
#   '댓글',
#   '수천',
#   '삭제',
#   '댓글',
#   '못',
#   '달',
#   '조작',
#   '증거',
#   '대한',
#   '답변',
#   '댓글',
#   '삭제',
#   '현재',
#   '송대',
#   '익',
#   '채널',
#   '속',
#   '해당',
#   '영상',
#   '삭제',
#   '상태',
#   '송대',
#   '약',
#   '명',
#   '독자',
#   '보유',
#   '유명',
#   '유튜버',
#   '먹방',
#   '몰카',
#   '개그',
#   '여자친구',
#   '이민영',
#   '데이트',
#   '브이',
#   '로그',
#   '콘텐츠',
#   '주로'],
#  ['지난해',
#   '일본',
#   '정부',
#   '한국',
#   '대한',
#   '수출',
#   '규제',
#   '조치',
#   '단행',
#   '일본',
#   '지식인',
#   '한국',
#   '적',
#   '제목',
#   '성명',
#   '발표',
#   '전직',
#   '외교관',
#   '변호사',
#   '시민사회',
#   '활동가',
#   '명',
#   '주축',
#   '성명',
#   '양국',
#   '반향',
#   '당시',
#   '성명',
#   '게재',
#   '홈페이지',
#   '첫',
#   '화면',
#   '한국',
#   '적',
#   '한국',
#   '적',
#   '인터뷰',
#   '한국',
#   '적',
#   '주도',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '수출',
#   '규제',
#   '조치',
#   '비판',
#   '지식인',
#   '성명',
#   '한국',
#   '적',
#   '발표',
#   '뒤',
#   '현재',
#   '한국',
#   '적',
#   '이름',
#   '홈페이지',
#   '캡쳐',
#   '서명',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '약',
#   '다시',
#   '우치다',
#   '변호사',
#   '역사',
#   '문제',
#   '판결',
#   '해결',
#   '수',
#   '면서',
#   '압류',
#   '자산',
#   '현금화',
#   '전',
#   '일본',
#   '기업',
#   '피해자',
#   '화해',
#   '고',
#   '말',
#   '협정',
#   '역사',
#   '대한',
#   '인식',
#   '처음',
#   '공유',
#   '김대중',
#   '오부',
#   '치',
#   '선언',
#   '문제',
#   '해결',
#   '출발점',
#   '말',
#   '인터뷰',
#   '전문',
#   '작년',
#   '한국',
#   '적',
#   '서명',
#   '운동',
#   '이후',
#   '상황',
#   '달라',
#   '정도',
#   '서명',
#   '참여',
#   '이후',
#   '법률가',
#   '동성',
#   '정부',
#   '별도',
#   '해결',
#   '책',
#   '모색',
#   '앞',
#   '경제',
#   '정계',
#   '전직',
#   '외교관',
#   '참여',
#   '낼',
#   '계획',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '도쿄',
#   '사무실',
#   '중앙',
#   '일보',
#   '인터뷰',
#   '역사',
#   '문제',
#   '문제',
#   '엮',
#   '정책',
#   '일본',
#   '기업',
#   '결코',
#   '결정',
#   '일본',
#   '수출',
#   '기업',
#   '불만',
#   '겉',
#   '청구권',
#   '협정',
#   '해결',
#   '일본',
#   '정부',
#   '논리',
#   '영향',
#   '일반인',
#   '사이',
#   '징용',
#   '공',
#   '단어',
#   '꽤',
#   '일본',
#   '정부',
#   '논리',
#   '널리',
#   '청구권',
#   '문제',
#   '해결',
#   '건',
#   '일본',
#   '정부',
#   '스스로',
#   '인정',
#   '문제',
#   '참의원',
#   '예산',
#   '위원회',
#   '나이',
#   '순',
#   '외무성',
#   '약국',
#   '개인',
#   '청구권',
#   '자체',
#   '국내법',
#   '의미',
#   '소멸',
#   '답변',
#   '아베',
#   '정권',
#   '고',
#   '주장',
#   '미쓰비시',
#   '머터',
#   '리얼',
#   '중국',
#   '강제',
#   '징용',
#   '피해자',
#   '화해',
#   '일본',
#   '정부',
#   '반발',
#   '중',
#   '관계',
#   '중',
#   '동성',
#   '침략',
#   '전쟁',
#   '대한',
#   '인식',
#   '공유',
#   '반면',
#   '조약',
#   '식민',
#   '지배',
#   '대한',
#   '공통',
#   '인식',
#   '반영',
#   '문제',
#   '처음',
#   '언급',
#   '김대중',
#   '대통령',
#   '오부',
#   '치',
#   '게이조',
#   '총리',
#   '세기',
#   '파트너',
#   '선언',
#   '중',
#   '공동',
#   '성명',
#   '수준',
#   '인식',
#   '선언',
#   '출발점',
#   '일본',
#   '정부',
#   '지금',
#   '협정',
#   '지난해',
#   '인터뷰',
#   '수출',
#   '규제',
#   '조치',
#   '관계',
#   '위기',
#   '헌법',
#   '개정',
#   '의도',
#   '지적',
#   '생각',
#   '동시',
#   '한국',
#   '여론',
#   '분열',
#   '의도',
#   '생각',
#   '아베',
#   '정권',
#   '의도',
#   '아베',
#   '정권',
#   '징용',
#   '공',
#   '문제',
#   '해결',
#   '최소한',
#   '관계',
#   '더',
#   '방법',
#   '우치다',
#   '마사토',
#   '시',
#   '변호사',
#   '지난',
#   '도쿄',
#   '사무실',
#   '중앙',
#   '일보',
#   '인터뷰',
#   '일본',
#   '기업',
#   '자산',
#   '현금화',
#   '관계',
#   '악화',
#   '예상',
#   '역사',
#   '문제',
#   '해결',
#   '법률',
#   '해결',
#   '판결',
#   '집행',
#   '해결',
#   '안',
#   '진짜',
#   '해결',
#   '사실',
#   '인정',
#   '책임',
#   '인정',
#   '사죄',
#   '현금화',
#   '절반',
#   '승리',
#   '뿐',
#   '해결',
#   '수',
#   '일본',
#   '기업',
#   '먼저',
#   '압류',
#   '자산',
#   '현금화',
#   '전',
#   '피해자',
#   '측',
#   '화해',
#   '위',
#   '움직임',
#   '구체',
#   '현금화',
#   '움직임',
#   '중단',
#   '수',
#   '화해',
#   '해결',
#   '더',
#   '구체',
#   '얘기',
#   '가해',
#   '사실',
#   '인정',
#   '책임',
#   '인정',
#   '사죄',
#   '게',
#   '첫',
#   '번',
#   '두',
#   '번',
#   '책임',
#   '인정',
#   '증표',
#   '화해',
#   '금',
#   '지급',
#   '세',
#   '번',
#   '잘못',
#   '반복',
#   '위해',
#   '문제',
#   '역사',
#   '거울',
#   '역사',
#   '교육',
#   '게',
#   '위해',
#   '선',
#   '역사',
#   '마주',
#   '김대중',
#   '오부',
#   '치',
#   '선언',
#   '과거',
#   '직시',
#   '공통',
#   '인식',
#   '대전',
#   '제로',
#   '문제',
#   '해결'],
#  ['앵커',
#   '원',
#   '투',
#   '자금',
#   '환매',
#   '중단',
#   '사태',
#   '빚',
#   '라임',
#   '사모펀드',
#   '관련',
#   '금융감독원',
#   '첫',
#   '분쟁',
#   '조정',
#   '결과',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '판매',
#   '사가',
#   '가입자',
#   '원금',
#   '전액',
#   '결정',
#   '금융투자',
#   '상품',
#   '결정',
#   '건',
#   '처음',
#   '라임',
#   '판매',
#   '사가',
#   '부실',
#   '펀드',
#   '계속',
#   '게',
#   '윱니',
#   '김민철',
#   '기자',
#   '보도',
#   '리포트',
#   '투자',
#   '원금',
#   '최대',
#   '손실',
#   '발생',
#   '운용',
#   '판매',
#   '부실',
#   '펀드',
#   '계속',
#   '금융감독원',
#   '금융',
#   '분쟁',
#   '조정',
#   '위원회',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '관련',
#   '판단',
#   '금감원',
#   '판매',
#   '이후',
#   '펀드',
#   '산',
#   '투자자',
#   '원금',
#   '전액',
#   '반환',
#   '결정',
#   '민법',
#   '착오',
#   '계약',
#   '취소',
#   '적용',
#   '원금',
#   '반환',
#   '결정',
#   '금융투자',
#   '상품',
#   '분쟁',
#   '조정',
#   '사상',
#   '처음',
#   '라임',
#   '무역',
#   '금융',
#   '펀드',
#   '금융투자',
#   '수익',
#   '스와프',
#   '대출',
#   '자금',
#   '활용',
#   '개',
#   '해외',
#   '무역',
#   '금융',
#   '펀드',
#   '투자',
#   '중',
#   '개',
#   '펀드',
#   '문제',
#   '금감원',
#   '라임',
#   '금투',
#   '부실',
#   '청산',
#   '절차',
#   '개시',
#   '통지',
#   '투자',
#   '원금',
#   '최대',
#   '달',
#   '손실',
#   '발생',
#   '운용',
#   '사인',
#   '라임',
#   '투자',
#   '제안',
#   '수익률',
#   '투자',
#   '위험',
#   '핵심',
#   '정보',
#   '허위',
#   '부실',
#   '기재',
#   '고',
#   '판매',
#   '사인',
#   '금투',
#   '그대로',
#   '투자자',
#   '제공',
#   '거나',
#   '설명',
#   '착오',
#   '과정',
#   '판매',
#   '자의',
#   '허위',
#   '투자',
#   '정보',
#   '설명',
#   '거나',
#   '투자자',
#   '성향',
#   '임의',
#   '기재',
#   '합리',
#   '투자',
#   '판단',
#   '기회',
#   '박탈',
#   '판단',
#   '분쟁',
#   '조정은',
#   '개',
#   '신청',
#   '건',
#   '중',
#   '대표',
#   '사례',
#   '건',
#   '심의',
#   '결과',
#   '나머지',
#   '투자',
#   '피해자',
#   '대해',
#   '선',
#   '자율',
#   '정이',
#   '진행',
#   '계획',
#   '대해',
#   '금감원',
#   '조정',
#   '절차',
#   '최대',
#   '천',
#   '원',
#   '투자',
#   '원금',
#   '반환',
#   '예상',
#   '고',
#   '대해',
#   '금투',
#   '우리은행',
#   '판매',
#   '내부',
#   '의사결정',
#   '과정',
#   '수락',
#   '결정',
#   '예정',
#   '뉴스',
#   '김민철'],
#  ['인국공',
#   '은',
#   '인천',
#   '국제공항',
#   '약자',
#   '말',
#   '최근',
#   '비정규직',
#   '인천',
#   '국제공항',
#   '보안요원',
#   '정규직',
#   '전환',
#   '논란',
#   '때문',
#   '취업',
#   '난',
#   '층',
#   '중심',
#   '공공기관',
#   '비정규직',
#   '정규직',
#   '전환',
#   '대한',
#   '반감',
#   '논란',
#   '배경',
#   '경쟁',
#   '취업',
#   '취업',
#   '과정',
#   '공정',
#   '문제',
#   '제기',
#   '대해',
#   '인천공항',
#   '공사',
#   '비정규직',
#   '정규직',
#   '화로',
#   '취업',
#   '준비',
#   '생',
#   '일자리',
#   '우려',
#   '사실',
#   '강조',
#   '정규직',
#   '전환',
#   '해도',
#   '비정규직',
#   '당시',
#   '임금',
#   '인상',
#   '해명',
#   '여권',
#   '비정규직',
#   '정규직',
#   '기회',
#   '싸움',
#   '입장',
#   '보이',
#   '최근',
#   '비정규직',
#   '정규직',
#   '전환',
#   '대한',
#   '여론조사',
#   '역차별',
#   '우려',
#   '고려',
#   '보류',
#   '장기',
#   '고용체',
#   '변화',
#   '위해',
#   '지속',
#   '추진',
#   '부정',
#   '의견',
#   '오차',
#   '범위',
#   '내',
#   '취업',
#   '직면',
#   '정규직',
#   '전환',
#   '보류',
#   '응답',
#   '달',
#   '반면',
#   '정규직',
#   '전환',
#   '계속',
#   '추진',
#   '의견',
#   '더',
#   '대조',
#   '현상',
#   '대해',
#   '전문가',
#   '정규직',
#   '비정규직',
#   '사회',
#   '계급',
#   '분석',
#   '사회',
#   '지위',
#   '처우',
#   '현격',
#   '차이',
#   '보이',
#   '우리나라',
#   '정규직',
#   '비정규직',
#   '대한',
#   '인식',
#   '청년',
#   '층',
#   '그대로',
#   '투영',
#   '사실',
#   '비정규직',
#   '문제',
#   '고질',
#   '고용',
#   '불안',
#   '양극화',
#   '것임',
#   '인국공',
#   '논란',
#   '일부',
#   '정치권',
#   '언론',
#   '갈등',
#   '한몫',
#   '인국공',
#   '논란',
#   '그동안',
#   '특권',
#   '층',
#   '이익',
#   '위해',
#   '희생',
#   '강요',
#   '불공정',
#   '경험',
#   '기인',
#   '비정규직',
#   '문제',
#   '해결',
#   '위',
#   '사회',
#   '합의',
#   '장애',
#   '요인',
#   '작용',
#   '싸움',
#   '돌',
#   '리기',
#   '사회',
#   '팽배',
#   '불신',
#   '골',
#   '천남',
#   '수',
#   '강원',
#   '사회',
#   '연구소장'],
#  ['규제',
#   '지역',
#   '주택',
#   '담보',
#   '대출',
#   '집',
#   '사려',
#   '개월',
#   '안',
#   '집',
#   '전입',
#   '주택',
#   '매매',
#   '임대',
#   '사업자',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '금융',
#   '위원회',
#   '금융감독원',
#   '부동산',
#   '대책',
#   '주택',
#   '담보',
#   '대출',
#   '관련',
#   '행정지도',
#   '시행',
#   '먼저',
#   '무',
#   '주택',
#   '투기지역',
#   '투기',
#   '지구',
#   '조정',
#   '대상',
#   '지역',
#   '규제',
#   '지역',
#   '주택',
#   '구매',
#   '위',
#   '주택',
#   '담보',
#   '대출',
#   '개월',
#   '안',
#   '전입',
#   '주택',
#   '가격',
#   '전입',
#   '의무',
#   '부과',
#   '주택',
#   '자의',
#   '경우',
#   '개월',
#   '안',
#   '기존',
#   '주택',
#   '처분',
#   '신규',
#   '주택',
#   '개월',
#   '산정',
#   '시점',
#   '주택',
#   '담보',
#   '대출',
#   '실행',
#   '중도',
#   '금',
#   '주비',
#   '대출',
#   '경우',
#   '신규',
#   '주택',
#   '소유권',
#   '이전',
#   '등기',
#   '일로',
#   '개월',
#   '신규',
#   '행정지도',
#   '시행일',
#   '이후',
#   '신규',
#   '대출',
#   '신청',
#   '규제',
#   '적용',
#   '주택',
#   '매매',
#   '계약',
#   '체결',
#   '계약금',
#   '납부',
#   '사실',
#   '증명',
#   '대출',
#   '금융',
#   '회사',
#   '전산',
#   '등록',
#   '통해',
#   '대출',
#   '신청',
#   '접수',
#   '대출',
#   '금융',
#   '대출',
#   '만기',
#   '연장',
#   '통보',
#   '대출',
#   '종전',
#   '규정',
#   '적용',
#   '집단',
#   '대출',
#   '경우',
#   '입',
#   '주자',
#   '모집',
#   '공고',
#   '입',
#   '주자',
#   '모집',
#   '공고',
#   '경우',
#   '착공',
#   '신고',
#   '재건축',
#   '재개발',
#   '사업',
#   '조합원',
#   '경우',
#   '관리',
#   '처분',
#   '사업',
#   '대해',
#   '종전',
#   '규정',
#   '적용',
#   '달',
#   '모든',
#   '지역',
#   '주택',
#   '매매',
#   '임대',
#   '사업자',
#   '대한',
#   '주택',
#   '담보',
#   '대출',
#   '금지',
#   '주택',
#   '구입',
#   '용',
#   '자금',
#   '주택',
#   '수리',
#   '비',
#   '운전',
#   '자금',
#   '용',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '구입',
#   '주택',
#   '담보',
#   '임차보증금',
#   '반환',
#   '목적',
#   '대출',
#   '취급',
#   '종전',
#   '규정',
#   '적용',
#   '국토교통부',
#   '예외',
#   '인정',
#   '비영리',
#   '법인',
#   '공익',
#   '법인',
#   '주택',
#   '담보',
#   '대출',
#   '수',
#   '박현',
#   '기자'],
#  ['전대',
#   '서울중앙지법',
#   '앞',
#   '기자회견',
#   '등심',
#   '위도',
#   '결산',
#   '역',
#   '공유',
#   '못',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '주장',
#   '소송',
#   '등록금',
#   '반환',
#   '청구',
#   '서울',
#   '뉴시스',
#   '최현호',
#   '기자',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '여파',
#   '대학',
#   '비대',
#   '수업',
#   '온라인',
#   '수업',
#   '진행',
#   '가운데',
#   '대학생',
#   '단체',
#   '수업',
#   '침해',
#   '등록금',
#   '반환',
#   '주장',
#   '대학',
#   '국가',
#   '상대로',
#   '송전',
#   '돌입',
#   '전국',
#   '대학',
#   '학생회',
#   '네트워크',
#   '전대',
#   '서울',
#   '서초구',
#   '서울중앙지법',
#   '앞',
#   '기자회견',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '고',
#   '주장',
#   '학교',
#   '법인',
#   '국가',
#   '상대로',
#   '소송',
#   '접수',
#   '소송',
#   '지난달',
#   '모집',
#   '전국',
#   '여개',
#   '대학',
#   '여명',
#   '대학생',
#   '참여',
#   '전대',
#   '측은',
#   '기자회견',
#   '문',
#   '통해',
#   '대학',
#   '교육부',
#   '국회',
#   '등록금',
#   '반환',
#   '논의',
#   '과정',
#   '학생',
#   '학교',
#   '학생',
#   '법적',
#   '보장',
#   '등록금',
#   '심의',
#   '위원회',
#   '제대로',
#   '결산',
#   '역',
#   '공유',
#   '고',
#   '지난달',
#   '등록금',
#   '반환',
#   '안',
#   '국회',
#   '교육',
#   '위원회',
#   '추경',
#   '예산',
#   '통과',
#   '금액',
#   '학교',
#   '당',
#   '정도',
#   '금액',
#   '반환',
#   '가정',
#   '책정',
#   '금액',
#   '현재',
#   '교육부',
#   '국회',
#   '논의',
#   '흐름',
#   '대학생',
#   '민심',
#   '제대로',
#   '반영',
#   '물',
#   '수',
#   '면서',
#   '대학생',
#   '학습',
#   '교육',
#   '헌법',
#   '명시',
#   '대학',
#   '교육부',
#   '보장',
#   '기본권',
#   '상반기',
#   '등록금',
#   '즉각',
#   '반환',
#   '등록금',
#   '반환',
#   '논의',
#   '학생',
#   '의견',
#   '즉각',
#   '수용',
#   '요구',
#   '소송',
#   '대리인',
#   '단',
#   '민주',
#   '사회',
#   '위',
#   '변호사',
#   '모임',
#   '민변',
#   '날',
#   '접수',
#   '소장',
#   '사립대',
#   '재학생',
#   '학교',
#   '법인',
#   '대한민국',
#   '상대로',
#   '반환',
#   '소송',
#   '국립대',
#   '재학생',
#   '반환',
#   '소송',
#   '사립대',
#   '경우',
#   '전국',
#   '개',
#   '학교',
#   '학생',
#   '명',
#   '참여',
#   '국립대',
#   '전국',
#   '개',
#   '대학',
#   '소속',
#   '학생',
#   '명',
#   '참여',
#   '사립대',
#   '중',
#   '명',
#   '학생',
#   '원고',
#   '참여',
#   '학교',
#   '계원예대',
#   '홍익대',
#   '이화여대',
#   '숙명여대',
#   '한성대',
#   '소송',
#   '통해',
#   '학생',
#   '측',
#   '청구',
#   '반환',
#   '금액',
#   '등록금',
#   '수준',
#   '사립대',
#   '경우',
#   '원고',
#   '국립대',
#   '경우',
#   '원고',
#   '정도',
#   '민변',
#   '관계자',
#   '날',
#   '소송',
#   '차',
#   '소장',
#   '접수',
#   '소송',
#   '과정',
#   '대학',
#   '결산',
#   '자료',
#   '제출',
#   '구체',
#   '산정',
#   '예정',
#   '전',
#   '민변',
#   '관계자',
#   '예술',
#   '계열',
#   '경우',
#   '곳',
#   '더',
#   '등록금',
#   '실기',
#   '비율',
#   '작업실',
#   '사용',
#   '못',
#   '교수',
#   '작품',
#   '피드백',
#   '얻지',
#   '반면',
#   '집',
#   '과제',
#   '상황',
#   '반환',
#   '필요성',
#   '더욱',
#   '절감',
#   '상당수',
#   '학생',
#   '원고',
#   '참여',
#   '고',
#   '전',
#   '홍익대',
#   '이대',
#   '경우',
#   '대표',
#   '적립금',
#   '곳',
#   '학교',
#   '재정',
#   '능력',
#   '입장',
#   '학생',
#   '더',
#   '의식',
#   '날',
#   '기자회견',
#   '발언',
#   '류',
#   '환',
#   '청년',
#   '대표',
#   '소송',
#   '대학',
#   '정부',
#   '대학생',
#   '목소리',
#   '무시',
#   '시작',
#   '면서',
#   '대학생',
#   '학기',
#   '시작',
#   '전',
#   '기자회견',
#   '면담',
#   '설문조사',
#   '통해',
#   '대책',
#   '마련',
#   '요구',
#   '대학',
#   '교육부',
#   '지침',
#   '이유',
#   '묵살',
#   '고',
#   '주장',
#   '대학',
#   '반환',
#   '규정',
#   '때문',
#   '반환',
#   '수',
#   '답변',
#   '등록금',
#   '기준',
#   '책정',
#   '때문',
#   '환불',
#   '기준',
#   '등록금',
#   '반환',
#   '요구',
#   '내',
#   '돈',
#   '반환',
#   '요구',
#   '지금',
#   '무시',
#   '침해',
#   '대학생',
#   '권리',
#   '요구',
#   '의미',
#   '함축',
#   '행동',
#   '말',
#   '지난달',
#   '대학교육',
#   '연구소',
#   '올해',
#   '기준',
#   '대학',
#   '교비',
#   '회계',
#   '결산',
#   '통해',
#   '확인',
#   '발표',
#   '사립',
#   '대학',
#   '누적',
#   '적립금',
#   '현황',
#   '자료',
#   '전체',
#   '사립대',
#   '개',
#   '대학',
#   '중',
#   '개교',
#   '누적',
#   '적립금',
#   '학교',
#   '누적',
#   '적립금',
#   '합계',
#   '달',
#   '최근',
#   '대학생',
#   '상대로',
#   '설문조사',
#   '결과',
#   '응답',
#   '자의',
#   '등록금',
#   '응답',
#   '응답',
#   '등록금',
#   '환액',
#   '판단',
#   '금액',
#   '평균값',
#   '등록금',
#   '대학',
#   '알리',
#   '전국',
#   '대학',
#   '학기',
#   '등록금',
#   '평균',
#   '약'],
#  ['국립대전현충원',
#   '충',
#   '인물',
#   '권',
#   '남궁',
#   '선',
#   '김기봉',
#   '중사',
#   '선정',
#   '비무장지대',
#   '남북',
#   '공동',
#   '유해',
#   '발굴',
#   '사업',
#   '통해',
#   '화살',
#   '머리',
#   '고지',
#   '신원',
#   '확인',
#   '권',
#   '중사',
#   '경남',
#   '사천',
#   '당시',
#   '살의',
#   '나이',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '참전',
#   '화살',
#   '머리',
#   '고지',
#   '중공군',
#   '두',
#   '차례',
#   '전투',
#   '참여',
#   '달',
#   '전사',
#   '남궁',
#   '선',
#   '중사',
#   '강원도',
#   '홍천',
#   '슬하',
#   '남',
#   '녀',
#   '상황',
#   '입대',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '전쟁',
#   '참여',
#   '소총수',
#   '철원',
#   '상석',
#   '지구',
#   '전투',
#   '활약',
#   '중공군',
#   '대적',
#   '공습',
#   '교전',
#   '중',
#   '포탄',
#   '파편',
#   '사망',
#   '김기봉',
#   '중사',
#   '경남',
#   '거제',
#   '당시',
#   '살의',
#   '나이',
#   '국군',
#   '사단',
#   '연대',
#   '소속',
#   '활동',
#   '시작',
#   '중공군',
#   '공격',
#   '두',
#   '차례',
#   '접전',
#   '끝',
#   '고지',
#   '사수',
#   '전투',
#   '전인',
#   '화살',
#   '머리',
#   '고지',
#   '숨',
#   '지난해',
#   '국립대전현충원',
#   '안장'],
#  ['가수',
#   '신용재',
#   '오후',
#   '서울',
#   '마포구',
#   '서교동',
#   '하나투어',
#   '브이',
#   '홀',
#   '첫',
#   '정규',
#   '앨범',
#   '디어',
#   '발매',
#   '기념',
#   '쇼케이스',
#   '참석',
#   '신곡'],
#  ['유럽연합',
#   '한국',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '인천',
#   '국제공항',
#   '출국',
#   '전광판',
#   '유럽',
#   '행',
#   '비행기',
#   '출발',
#   '정보',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확산',
#   '위해',
#   '지난',
#   '외국인',
#   '입국',
#   '제한',
#   '회원',
#   '국',
#   '날',
#   '한국',
#   '개국',
#   '알제리',
#   '호주',
#   '캐나다',
#   '조지아',
#   '일본',
#   '몬테네그로',
#   '모로코',
#   '뉴질랜드',
#   '르완다',
#   '세르비아',
#   '태국',
#   '튀니지',
#   '우루과이',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '사진',
#   '뉴스',
#   '코로나',
#   '하늘',
#   '길이',
#   '리기',
#   '시작',
#   '여름',
#   '수기',
#   '여행객',
#   '국가',
#   '유럽',
#   '초토화',
#   '관광',
#   '산업',
#   '시작',
#   '국내',
#   '여행객',
#   '가장',
#   '선망',
#   '여행지',
#   '유럽',
#   '여행',
#   '교류',
#   '재개',
#   '여행객',
#   '관심',
#   '코로나',
#   '지속',
#   '점',
#   '해외여행',
#   '수요',
#   '회복',
#   '관측',
#   '경제',
#   '회생',
#   '고육책',
#   '유럽',
#   '문',
#   '유럽연합',
#   '한국',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '인천',
#   '국제공항',
#   '출국',
#   '탑승객',
#   '출국',
#   '수속',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확산',
#   '위해',
#   '지난',
#   '외국인',
#   '입국',
#   '제한',
#   '회원',
#   '국',
#   '날',
#   '한국',
#   '개국',
#   '알제리',
#   '호주',
#   '캐나다',
#   '조지아',
#   '일본',
#   '몬테네그로',
#   '모로코',
#   '뉴질랜드',
#   '르완다',
#   '세르비아',
#   '태국',
#   '튀니지',
#   '우루과이',
#   '대해',
#   '입국',
#   '제한',
#   '해제',
#   '사진',
#   '뉴스',
#   '현지',
#   '로이터',
#   '외신',
#   '회원',
#   '국',
#   '대표',
#   '기구',
#   '이사회',
#   '여행',
#   '출장',
#   '목적',
#   '개국',
#   '국민',
#   '대한',
#   '입국',
#   '제한',
#   '해제',
#   '합의',
#   '날',
#   '한국',
#   '비롯',
#   '일본',
#   '호주',
#   '캐나다',
#   '뉴질랜드',
#   '태국',
#   '우루과이',
#   '튀니지',
#   '세르비아',
#   '르완다',
#   '모로코',
#   '몬테네그로',
#   '조지아',
#   '알제리',
#   '개국',
#   '국가',
#   '여행',
#   '코로나',
#   '꽉',
#   '유럽',
#   '여행',
#   '길이',
#   '전망',
#   '찌',
#   '감치',
#   '예견',
#   '앞서',
#   '유럽',
#   '관광',
#   '대국',
#   '이탈리아',
#   '지난달',
#   '개월',
#   '국경',
#   '개방',
#   '그리스도',
#   '외국인',
#   '입국',
#   '허용',
#   '결정',
#   '관광',
#   '교류',
#   '재개',
#   '움직임',
#   '때문',
#   '백신',
#   '개발',
#   '커녕',
#   '세계보건기구',
#   '코로나',
#   '팬데믹',
#   '종식',
#   '근처',
#   '못',
#   '경고',
#   '상황',
#   '관광',
#   '개방',
#   '회생',
#   '위',
#   '고육책',
#   '유럽',
#   '국가',
#   '관광객',
#   '지출',
#   '국가',
#   '경제',
#   '지탱',
#   '관광',
#   '국내총생산',
#   '차지',
#   '고용',
#   '비중',
#   '핵심',
#   '산업',
#   '중',
#   '관광객',
#   '가장',
#   '여름',
#   '수기',
#   '국경',
#   '개방',
#   '이유',
#   '세계',
#   '관광',
#   '기구',
#   '세계',
#   '각국',
#   '여행',
#   '제한',
#   '지속',
#   '전',
#   '세계',
#   '총',
#   '관광객',
#   '수가',
#   '예상',
#   '초',
#   '여행',
#   '제한',
#   '해제',
#   '경우',
#   '대비',
#   '감소',
#   '데',
#   '관광',
#   '나라',
#   '국경',
#   '봉쇄',
#   '해제',
#   '수',
#   '여행',
#   '수',
#   '현실',
#   '불가능',
#   '국내',
#   '유럽',
#   '행',
#   '비행기',
#   '탈',
#   '수',
#   '대한',
#   '여행객',
#   '관심',
#   '회원',
#   '수',
#   '명',
#   '유럽',
#   '여행',
#   '커뮤니티',
#   '유랑',
#   '유럽',
#   '여행',
#   '가능',
#   '질문',
#   '현지',
#   '상황',
#   '대한',
#   '공유',
#   '모습',
#   '여행객',
#   '기대',
#   '달리',
#   '당분간',
#   '유럽',
#   '여행',
#   '전망',
#   '행업',
#   '코로나',
#   '사태',
#   '데',
#   '현지',
#   '사정',
#   '국내',
#   '방역',
#   '현황',
#   '볼',
#   '물리',
#   '여행',
#   '보고',
#   '결정',
#   '회원',
#   '국',
#   '그대로',
#   '이행',
#   '대한',
#   '불분명',
#   '입국',
#   '허용',
#   '격리',
#   '거나',
#   '국가',
#   '비자',
#   '요구',
#   '수도',
#   '유럽',
#   '단일국가',
#   '여행',
#   '국경',
#   '나라',
#   '유람',
#   '경우',
#   '점',
#   '전',
#   '여행',
#   '수',
#   '국내',
#   '상황',
#   '녹록',
#   '전반',
#   '여행',
#   '업계',
#   '직원',
#   '대다수',
#   '유',
#   '무직',
#   '휴직',
#   '돌입',
#   '여행',
#   '관련',
#   '상품',
#   '업무',
#   '민원',
#   '처리',
#   '주요',
#   '여행사',
#   '경우',
#   '여행',
#   '상품',
#   '운영',
#   '아예',
#   '안',
#   '상품',
#   '최소',
#   '상태',
#   '가장',
#   '국내',
#   '방역',
#   '당국',
#   '지침',
#   '여행',
#   '주',
#   '격리',
#   '점',
#   '유럽',
#   '장거리',
#   '만큼',
#   '최소',
#   '일주일',
#   '여행',
#   '게',
#   '일반',
#   '귀국',
#   '주',
#   '자가',
#   '격리',
#   '경우',
#   '업무',
#   '학업',
#   '빚',
#   '차질',
#   '현실',
#   '유럽',
#   '여행',
#   '국내',
#   '최대',
#   '여행사',
#   '하나투어',
#   '조만간',
#   '해외여행',
#   '프로모션',
#   '열',
#   '예정',
#   '이후',
#   '출발',
#   '상품',
#   '예정',
#   '여행',
#   '판단',
#   '여행사',
#   '관계자',
#   '말',
#   '그대로',
#   '여행',
#   '것일',
#   '뿐',
#   '실질',
#   '여행',
#   '수',
#   '환경',
#   '말',
#   '수',
#   '며',
#   '업무',
#   '친지',
#   '방문',
#   '주',
#   '자가',
#   '격리',
#   '수',
#   '경우',
#   '제외',
#   '유럽',
#   '여행',
#   '수',
#   '상황',
#   '말'],
#  ['참여',
#   '환경',
#   '연대',
#   '제주도',
#   '의회',
#   '교육',
#   '제도',
#   '대한',
#   '의견서',
#   '헌법재판소',
#   '제출',
#   '관련',
#   '성명',
#   '제주도',
#   '회의',
#   '가짜',
#   '의견서',
#   '제출',
#   '의혹',
#   '대한',
#   '해명',
#   '요구',
#   '제주도',
#   '의회',
#   '헌법재판소',
#   '제출',
#   '의견서',
#   '교육',
#   '위원회',
#   '교육',
#   '의원',
#   '명',
#   '포함',
#   '명',
#   '전원',
#   '참여',
#   '환경',
#   '대가',
#   '주장',
#   '의견',
#   '반대',
#   '참여',
#   '환경',
#   '연대',
#   '송창',
#   '은실',
#   '의원',
#   '확인',
#   '결과',
#   '교육',
#   '위원회',
#   '차원',
#   '의견',
#   '회의',
#   '공지',
#   '적',
#   '며',
#   '의견서',
#   '작성',
#   '과정',
#   '의혹',
#   '제기',
#   '제주도',
#   '의회',
#   '의견서',
#   '교육',
#   '위원회',
#   '명',
#   '소속',
#   '의원',
#   '전원',
#   '반대',
#   '며',
#   '의견',
#   '서거',
#   '과정',
#   '통해',
#   '작성',
#   '헌법재판소',
#   '제출',
#   '고',
#   '강조',
#   '주',
#   '내',
#   '경위',
#   '경우',
#   '항의',
#   '헌법재판소',
#   '사실',
#   '전달'],
#  ['대전',
#   '초등학생',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '양성',
#   '판정',
#   '건',
#   '관련',
#   '방역',
#   '당국',
#   '교내',
#   '전파',
#   '의심',
#   '사례',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확',
#   '진자',
#   '발생',
#   '폐쇄',
#   '조치',
#   '대전',
#   '초등학교',
#   '교실',
#   '적막',
#   '감',
#   '김성태',
#   '정은경',
#   '중앙',
#   '방역',
#   '대책',
#   '본부장',
#   '정례',
#   '브리핑',
#   '대전',
#   '지역',
#   '초등학교',
#   '학생',
#   '간',
#   '접촉',
#   '감염',
#   '사례',
#   '관련',
#   '교내',
#   '전파',
#   '의심',
#   '고',
#   '말',
#   '확',
#   '진자',
#   '사이',
#   '접촉',
#   '명',
#   '확진',
#   '의정부',
#   '아파트',
#   '주민',
#   '전수',
#   '조사',
#   '정',
#   '본부장',
#   '그동안',
#   '등교',
#   '수업',
#   '관련',
#   '집단',
#   '감염',
#   '사례',
#   '보고',
#   '며',
#   '코로나',
#   '특징',
#   '증',
#   '면서',
#   '무증상',
#   '감염',
#   '이기',
#   '때문',
#   '학교',
#   '밖',
#   '감염',
#   '학',
#   '유입',
#   '가능성',
#   '피',
#   '상황',
#   '전시',
#   '지난달',
#   '대전',
#   '동구',
#   '초등학교',
#   '학년',
#   '학생',
#   '명',
#   '확진',
#   '뒤',
#   '학년',
#   '학생',
#   '명',
#   '추가',
#   '양성',
#   '판정',
#   '중',
#   '명',
#   '첫',
#   '확',
#   '진자',
#   '반',
#   '학생',
#   '확인',
#   '정',
#   '본부장',
#   '대전',
#   '가족',
#   '간',
#   '전파',
#   '초등학생',
#   '명',
#   '감염',
#   '초등학생',
#   '학원',
#   '접촉',
#   '명과',
#   '학교',
#   '반',
#   '학생',
#   '명',
#   '양성',
#   '확인',
#   '고',
#   '말',
#   '급반',
#   '학생',
#   '초등학생',
#   '확',
#   '진자',
#   '사이',
#   '만큼',
#   '라며',
#   '학생',
#   '전파',
#   '보고',
#   '고',
#   '말',
#   '전파',
#   '규모',
#   '역학',
#   '조사',
#   '학생',
#   '전수',
#   '조사',
#   '결과',
#   '뒤',
#   '추후',
#   '발표',
#   '신종',
#   '코로나바이러스',
#   '감염증',
#   '코로나',
#   '확',
#   '진자',
#   '발생',
#   '폐쇄',
#   '조치',
#   '대전',
#   '초등학교',
#   '적막',
#   '감',
#   '김성태',
#   '정',
#   '본부장',
#   '교내',
#   '전파',
#   '의심',
#   '사례',
#   '발생',
#   '함',
#   '학교',
#   '방역',
#   '칙',
#   '준수',
#   '다시',
#   '한번',
#   '당부',
#   '며',
#   '학생',
#   '교직원',
#   '등교',
#   '전',
#   '발열',
#   '호흡기',
#   '증상',
#   '경우',
#   '등교',
#   '출근',
#   '개인',
#   '위생',
#   '칙',
#   '준수',
#   '고',
#   '강조',
#   '한편',
#   '경기',
#   '의정부시',
#   '아파트',
#   '최근',
#   '새',
#   '주민',
#   '명',
#   '확진',
#   '관련',
#   '선',
#   '해당',
#   '명의',
#   '주민',
#   '전수',
#   '검사',
#   '정',
#   '본부장',
#   '세',
#   '가족',
#   '계',
#   '상황',
#   '라며',
#   '가족',
#   '간',
#   '개인',
#   '접촉',
#   '확인',
#   '엘리베이터',
#   '용공',
#   '통한',
#   '접촉',
#   '전파',
#   '가능성',
#   '역학',
#   '조사',
#   '진행',
#   '고',
#   '말',
#   '지난달',
#   '광주',
#   '광역시',
#   '동구',
#   '운림',
#   '광륵사',
#   '문',
#   '앞',
#   '출입',
#   '금지',
#   '간판',
#   '광주',
#   '광역시',
#   '전남',
#   '목포',
#   '전북',
#   '전주',
#   '경기',
#   '파주',
#   '코로나',
#   '확',
#   '진자',
#   '곳',
#   '방문',
#   '프리랜서',
#   '장정',
#   '필',
#   '당국',
#   '광주',
#   '불교',
#   '사찰',
#   '광륵사',
#   '관련',
#   '접촉',
#   '명',
#   '추가',
#   '확진',
#   '관련',
#   '누적',
#   '확',
#   '진자',
#   '명',
#   '감염',
#   '경로',
#   '오리무중',
#   '충북',
#   '옥천군',
#   '소재',
#   '자동차',
#   '부품',
#   '회사',
#   '관련',
#   '초등생',
#   '명',
#   '추가',
#   '확진',
#   '누적',
#   '확',
#   '진자',
#   '총',
#   '명',
#   '집계'],
#  ['앵커',
#   '코로나',
#   '확',
#   '진자',
#   '동선',
#   '마음',
#   '선별',
#   '진료',
#   '소',
#   '사람',
#   '늘',
#   '중증',
#   '환자',
#   '확',
#   '진자',
#   '증가',
#   '폭',
#   '의료',
#   '병상',
#   '확보',
#   '백미',
#   '선',
#   '기자',
#   '리포트',
#   '광주',
#   '시내',
#   '선별',
#   '진료',
#   '소',
#   '코로나',
#   '검사',
#   '사람',
#   '차례',
#   '확',
#   '진자',
#   '수가',
#   '급증',
#   '선',
#   '진료',
#   '소',
#   '방문자',
#   '최근',
#   '나흘',
#   '사이',
#   '배',
#   '김정애',
#   '광주',
#   '보건',
#   '사업',
#   '과장',
#   '평균',
#   '건',
#   '정도',
#   '검사',
#   '지난',
#   '토요일',
#   '이후',
#   '광주시',
#   '전체',
#   '확진',
#   '건',
#   '건',
#   '정도',
#   '검사',
#   '상황',
#   '의심',
#   '신고',
#   '검체',
#   '채취',
#   '병상',
#   '확보',
#   '비상',
#   '전남대',
#   '병원',
#   '마련',
#   '음압',
#   '병상',
#   '격리',
#   '실',
#   '곳',
#   '비롯',
#   '광주시',
#   '가용',
#   '병상',
#   '개',
#   '광주시',
#   '확',
#   '진자',
#   '경우',
#   '대비',
#   '빛고을',
#   '전남대',
#   '병원',
#   '병상',
#   '개',
#   '추가',
#   '확보',
#   '상대',
#   '여유',
#   '인근',
#   '지역',
#   '시설',
#   '이용',
#   '협조',
#   '변수',
#   '확',
#   '진자',
#   '집중',
#   '상당수',
#   '당뇨',
#   '심장병',
#   '질환',
#   '확',
#   '진자',
#   '수가',
#   '폭발',
#   '가능성',
#   '은',
#   '중증',
#   '환자',
#   '수',
#   '이야기',
#   '음압',
#   '병상',
#   '이동식',
#   '시설',
#   '광주',
#   '전남',
#   '개',
#   '류소연',
#   '조선',
#   '대학교',
#   '의과대학',
#   '예방의학',
#   '교실',
#   '교수',
#   '질병',
#   '진행',
#   '경과',
#   '앞',
#   '가능성',
#   '점',
#   '염려',
#   '부분',
#   '보시',
#   '코로나',
#   '확산',
#   '우려',
#   '대비',
#   '병상',
#   '확보',
#   '비상',
#   '뉴스',
#   '백미',
#   '선'],
#  ['뮤',
#   '지엄',
#   '산',
#   '본관',
#   '명',
#   '상관',
#   '향햐',
#   '야외',
#   '길',
#   '강원',
#   '도민',
#   '일보',
#   '자료',
#   '사진',
#   '강원',
#   '도민',
#   '일보',
#   '윤',
#   '종진',
#   '기자',
#   '문화',
#   '체육관',
#   '광부',
#   '한국',
#   '관광',
#   '공사',
#   '약',
#   '개',
#   '월간',
#   '추천',
#   '웰니스',
#   '관광지',
#   '개소',
#   '대한',
#   '할인',
#   '캠페인',
#   '시작',
#   '대상',
#   '강원',
#   '동해',
#   '위치',
#   '동해',
#   '무릉',
#   '건강',
#   '숲',
#   '경북',
#   '김천',
#   '국립',
#   '치유',
#   '숲',
#   '밀',
#   '집도',
#   '자연',
#   '숲',
#   '치유',
#   '시설',
#   '강원',
#   '홍천',
#   '힐리',
#   '언스',
#   '선',
#   '마을',
#   '원주',
#   '뮤',
#   '지엄',
#   '산',
#   '명',
#   '상관',
#   '충북',
#   '충주',
#   '산속',
#   '옹달샘',
#   '아침',
#   '편지',
#   '명상',
#   '치유',
#   '센터',
#   '대표',
#   '힐링',
#   '명상',
#   '시설',
#   '서울',
#   '티',
#   '테라',
#   '피',
#   '대구',
#   '하늘',
#   '호수',
#   '방',
#   '개소',
#   '포함',
#   '개소',
#   '캠페인',
#   '누리집',
#   '여행',
#   '주간',
#   '누리집',
#   '대한민국',
#   '구석구석',
#   '누리집',
#   '통해',
#   '참여',
#   '캠페인',
#   '희망',
#   '시설',
#   '쿠폰',
#   '다운',
#   '현장',
#   '사용',
#   '최대',
#   '할인',
#   '수',
#   '추천',
#   '웰니스',
#   '관광지',
#   '별',
#   '할인',
#   '쿠폰',
#   '수량',
#   '상이',
#   '총',
#   '명',
#   '할인',
#   '혜택',
#   '제공',
#   '쿠폰',
#   '사용',
#   '현장',
#   '사용',
#   '기준',
#   '방문',
#   '전',
#   '쿠폰',
#   '잔',
#   '수량',
#   '꼭',
#   '확인',
#   '한국',
#   '관광',
#   '공사',
#   '의료',
#   '웰',
#   '스팀',
#   '김정아',
#   '팀',
#   '캠페인',
#   '계기',
#   '시기',
#   '국민',
#   '힐링',
#   '한편',
#   '웰니스',
#   '관광업',
#   '도움',
#   '며',
#   '할인',
#   '캠페인',
#   '기간',
#   '시설',
#   '방역',
#   '체크',
#   '리스트',
#   '관리',
#   '동시',
#   '이용자',
#   '대상',
#   '마스크',
#   '안전',
#   '여행',
#   '가이드',
#   '제공',
#   '안전',
#   '여행',
#   '관리',
#   '고'],
#  ['전시',
#   '중구',
#   '박용',
#   '갑',
#   '청장',
#   '중구',
#   '보건소',
#   '위치',
#   '선',
#   '진료',
#   '소',
#   '위',
#   '킹스',
#   '루',
#   '현장',
#   '방문',
#   '민선',
#   '기',
#   '후반기',
#   '시작',
#   '박',
#   '청장',
#   '중구',
#   '선',
#   '진료',
#   '소',
#   '방문',
#   '내',
#   '외부',
#   '시설',
#   '물',
#   '점검',
#   '의료',
#   '진과',
#   '관계자',
#   '노고',
#   '감사',
#   '표',
#   '중구',
#   '청장',
#   '취임',
#   '주년',
#   '민선',
#   '기',
#   '후반기',
#   '맞이',
#   '성과',
#   '미래',
#   '포스트',
#   '코로나',
#   '구정',
#   '방향',
#   '제시',
#   '주민',
#   '화합',
#   '발전',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '고',
#   '다짐',
#   '성과',
#   '도심',
#   '활성화',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '건설',
#   '꼽았다',
#   '중구',
#   '도심',
#   '활성화',
#   '위해',
#   '문화',
#   '흐름',
#   '중교',
#   '조성',
#   '사업',
#   '대흥동',
#   '골목길',
#   '재생',
#   '사업',
#   '공원',
#   '주변',
#   '재창',
#   '사업',
#   '대제',
#   '커플',
#   '존',
#   '가로',
#   '확장',
#   '사업',
#   '린',
#   '공원',
#   '조성',
#   '사업',
#   '선화',
#   '확장',
#   '사업',
#   '대표',
#   '추진',
#   '결과',
#   '대흥동',
#   '은행동',
#   '선화동',
#   '지역',
#   '젊은이',
#   '곳',
#   '탈바꿈',
#   '효',
#   '문화',
#   '중심',
#   '도시',
#   '건설',
#   '위해',
#   '효',
#   '문화',
#   '뿌리',
#   '축제',
#   '뿌리',
#   '공원',
#   '중심',
#   '효',
#   '문화',
#   '확산',
#   '노력',
#   '효',
#   '문화',
#   '뿌리',
#   '축제',
#   '연속',
#   '국가',
#   '유망',
#   '축제',
#   '선정',
#   '지난해',
#   '한국',
#   '기업',
#   '평판',
#   '연구소',
#   '빅데이터',
#   '분석',
#   '결과',
#   '국내',
#   '소비자',
#   '전국',
#   '개',
#   '축제',
#   '중',
#   '브랜드',
#   '평가',
#   '위',
#   '차지',
#   '성과',
#   '개장',
#   '뿌리',
#   '공원',
#   '성씨',
#   '조형',
#   '물',
#   '시작',
#   '현재',
#   '성장',
#   '야간',
#   '경관',
#   '조명등',
#   '설치',
#   '뿌리',
#   '공원',
#   '단장',
#   '인터넷',
#   '포털사이트',
#   '전시',
#   '만',
#   '곳',
#   '위',
#   '분',
#   '명품',
#   '공원',
#   '중구',
#   '민선',
#   '기',
#   '후반기',
#   '구정',
#   '지향',
#   '점',
#   '대한',
#   '미래',
#   '비',
#   '전도',
#   '제시',
#   '대표',
#   '사업',
#   '재개발',
#   '재건축',
#   '도시재생',
#   '뉴딜',
#   '사업',
#   '추진',
#   '효',
#   '문화',
#   '뿌리',
#   '마을',
#   '뿌리',
#   '공원',
#   '조성',
#   '중구',
#   '청사',
#   '건축물',
#   '리뉴얼',
#   '사업',
#   '추진',
#   '민중',
#   '심의',
#   '동행',
#   '정복',
#   '센터',
#   '신축',
#   '전시',
#   '정부',
#   '부처',
#   '협력',
#   '추진',
#   '베이스볼',
#   '드림파크',
#   '중구',
#   '건립',
#   '보문산',
#   '관광',
#   '활성화',
#   '나라',
#   '대전',
#   '통합',
#   '청사',
#   '신축',
#   '코로나',
#   '이후',
#   '사회',
#   '변화',
#   '예측',
#   '중구',
#   '차원',
#   '포스트',
#   '코로나',
#   '대응',
#   '전략',
#   '설명',
#   '주민',
#   '밀착',
#   '지역',
#   '주민',
#   '소외',
#   '수',
#   '현실',
#   '전략',
#   '가장',
#   '개인',
#   '위생',
#   '칙',
#   '준수',
#   '강조',
#   '차원',
#   '전략',
#   '중앙',
#   '지하상가',
#   '특',
#   '거리',
#   '대한',
#   '시설',
#   '개선',
#   '마케팅',
#   '지원',
#   '위생',
#   '단속',
#   '방역',
#   '관리',
#   '환경',
#   '정비',
#   '실시',
#   '주민',
#   '감염병',
#   '대한',
#   '불안감',
#   '해소',
#   '보건관리',
#   '강화',
#   '통한',
#   '감염병',
#   '사전',
#   '예방',
#   '추진',
#   '박용',
#   '갑',
#   '청장',
#   '지역',
#   '내',
#   '코로나',
#   '예방',
#   '확산',
#   '방지',
#   '위해',
#   '촘촘',
#   '방역',
#   '망',
#   '구축',
#   '대책',
#   '마련',
#   '최선',
#   '강조',
#   '앞',
#   '초심',
#   '그대로',
#   '청장',
#   '살림',
#   '청장',
#   '명예',
#   '선',
#   '구청',
#   '고',
#   '소감'],
#  ['전자신문',
#   '금융',
#   '전문',
#   '기업',
#   '풀',
#   '증시',
#   '분석',
#   '전문',
#   '기자',
#   '로봇',
#   '기사',
#   '하이',
#   '투자',
#   '증권',
#   '유한양행',
#   '대해',
#   '레이저',
#   '티닙',
#   '순항',
#   '중',
#   '라며',
#   '투자',
#   '의견',
#   '유지',
#   '제시',
#   '목표',
#   '주가',
#   '하이',
#   '투자',
#   '증권',
#   '박재경',
#   '애널',
#   '리스트',
#   '종목',
#   '대하',
#   '제시',
#   '유지',
#   '의견',
#   '하이',
#   '투자',
#   '증권',
#   '직전',
#   '매매',
#   '의견',
#   '올해',
#   '초반',
#   '매매',
#   '의견',
#   '기준',
#   '볼때',
#   '역시',
#   '매수',
#   '의견',
#   '계속',
#   '유지',
#   '상태',
#   '최근',
#   '분기',
#   '내',
#   '발표',
#   '전체',
#   '증권사',
#   '리포트',
#   '컨센서스',
#   '비교',
#   '경우',
#   '오늘',
#   '발표',
#   '투자',
#   '의견',
#   '체적',
#   '평균',
#   '치',
#   '해당',
#   '수준',
#   '의견',
#   '종목',
#   '대한',
#   '전체',
#   '흐름',
#   '크게',
#   '분석',
#   '목표',
#   '주가',
#   '추이',
#   '최근',
#   '차례',
#   '연속',
#   '목표',
#   '가가',
#   '목표',
#   '가의',
#   '상승',
#   '폭도',
#   '더욱',
#   '모습',
#   '전일',
#   '종가',
#   '기준',
#   '볼때',
#   '종목',
#   '주가',
#   '제시',
#   '목표',
#   '대비',
#   '추가',
#   '상승',
#   '여력',
#   '해석',
#   '제시',
#   '하이',
#   '투자',
#   '증권',
#   '유한양행',
#   '대해',
#   '레이저',
#   '티닙',
#   '상',
#   '종료',
#   '마일',
#   '스톤',
#   '중',
#   '약',
#   '인식',
#   '예정',
#   '연매출',
#   '규모',
#   '글리벡',
#   '도입',
#   '통한',
#   '매출',
#   '성장',
#   '순항',
#   '레이저',
#   '티닙',
#   '하반기',
#   '조건',
#   '부',
#   '허가',
#   '신청',
#   '기대',
#   '내년',
#   '초',
#   '승인',
#   '기대',
#   '분석',
#   '하이',
#   '투자',
#   '증권',
#   '매출',
#   '액',
#   '영업',
#   '이익',
#   '흑자',
#   '전환',
#   '기록',
#   '컨센서스',
#   '상회',
#   '전망',
#   '매출',
#   '액',
#   '영업',
#   '이익',
#   '전망',
#   '하이',
#   '투자',
#   '증권',
#   '종목',
#   '대한',
#   '최근',
#   '개월',
#   '투자',
#   '의견',
#   '전체',
#   '변화',
#   '유지',
#   '목표',
#   '주가',
#   '점',
#   '반대',
#   '점',
#   '제시',
#   '이후',
#   '수준',
#   '조정',
#   '오늘',
#   '하이',
#   '투자',
#   '증권',
#   '발표',
#   '유지',
#   '의견',
#   '목표',
#   '주가',
#   '전체',
#   '컨센서스',
#   '대비',
#   '체적',
#   '평균',
#   '치',
#   '해당',
#   '수준',
#   '의견',
#   '종목',
#   '대한',
#   '전체',
#   '흐름',
#   '크게',
#   '파악',
#   '목표',
#   '평균',
#   '대비',
#   '차이',
#   '집계',
#   '참고',
#   '최근',
#   '목표',
#   '주가',
#   '가장',
#   '공격',
#   '제시',
#   '금융투자',
#   '증권',
#   '투자',
#   '의견',
#   '목표',
#   '주가',
#   '제일',
#   '보수',
#   '의견',
#   '제시',
#   '투자',
#   '증권',
#   '투자',
#   '의견',
#   '하향',
#   '목표',
#   '주가',
#   '제시',
#   '바',
#   '하이',
#   '투자',
#   '증권',
#   '투자',
#   '의견',
#   '추이',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '전체',
#   '증권사',
#   '최근',
#   '리포트',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '하이',
#   '투자',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '현대차',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '증권',
#   '목표',
#   '투자',
#   '의견',
#   '유지',
#   '한화',
#   '투자',
#   '증권']]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori as apriori2
from mlxtend.frequent_patterns import association_rules

te = TransactionEncoder()
te_result = te.fit(transactions).transform(transactions)

print(te_result.shape[0]*te_result.shape[1])
# Out:
# 65070

# %%
df2 = pd.DataFrame(te_result, columns=te.columns_)
df2
# Out:
#        가가     가게     가격    가까이     가능    가능성     가량     가로     가맹     가세  ...  \
# 0   False  False  False  False  False  False  False  False  False  False  ...
# 1   False  False   True   True  False   True  False  False  False  False  ...
# 2   False  False  False  False  False  False  False  False  False  False  ...
# 3   False  False  False  False  False  False   True  False  False  False  ...
# 4   False  False  False  False  False  False  False  False  False  False  ...
# 5   False  False   True  False  False  False  False  False  False  False  ...
# 6   False  False  False  False  False  False  False  False  False  False  ...
# 7   False  False  False  False  False  False  False  False  False   True  ...
# 8   False  False  False  False  False  False  False  False  False  False  ...
# 9   False  False  False  False  False   True  False  False  False  False  ...
# 10   True  False  False  False  False   True  False  False  False  False  ...
# 11  False   True  False  False  False  False  False  False  False  False  ...
# 12  False  False  False  False  False  False  False  False  False  False  ...
# 13  False  False  False  False  False  False  False  False  False  False  ...
# 14  False  False   True  False  False   True  False  False  False  False  ...
# 15  False  False  False  False  False  False  False  False   True  False  ...
# 16  False  False  False  False  False  False  False  False  False  False  ...
# 17  False  False  False  False  False  False  False  False  False  False  ...
# 18  False  False  False  False  False  False  False  False  False  False  ...
# 19  False  False   True  False  False  False  False  False  False  False  ...
# 20  False  False  False  False  False  False  False  False  False  False  ...
# 21  False  False  False  False  False  False  False  False  False  False  ...
# 22  False  False  False  False  False  False  False  False  False  False  ...
# 23  False  False  False  False   True  False  False  False  False  False  ...
# 24  False  False  False  False  False  False  False  False  False  False  ...
# 25  False  False  False  False  False   True  False  False  False  False  ...
# 26  False  False  False  False  False   True  False  False  False  False  ...
# 27  False  False  False  False  False  False  False  False  False  False  ...
# 28  False  False  False  False  False  False  False   True  False  False  ...
# 29   True  False  False  False  False  False  False  False  False  False  ...
#
#       후반기     휴직     흐름     흑자      흙     희망     희생     힐리     힐링      힘
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2    True  False  False  False  False  False  False  False  False   True
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False   True  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False   True  False  False  False  False  False
# 12  False  False  False  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False  False  False  False
# 15  False  False  False  False  False  False  False  False  False  False
# 16  False  False  False  False  False  False  False  False  False  False
# 17  False  False  False  False  False  False  False  False  False  False
# 18  False  False  False  False  False  False   True  False  False  False
# 19  False  False  False  False  False  False  False  False  False  False
# 20  False  False   True  False  False  False  False  False  False  False
# 21  False  False  False  False  False  False  False  False  False  False
# 22  False  False  False  False  False  False  False  False  False  False
# 23  False   True  False  False  False  False  False  False  False  False
# 24  False  False  False  False  False  False  False  False  False  False
# 25  False  False  False  False  False  False  False  False  False  False
# 26  False  False  False  False  False  False  False  False  False  False
# 27  False  False  False  False  False   True  False   True   True  False
# 28   True  False   True  False  False  False  False  False  False  False
# 29  False  False   True   True  False  False  False  False  False  False
#
# [30 rows x 2169 columns]

# %%
# keyword = '손흥민'

df2 = pd.DataFrame(te_result, columns=te.columns_)

itemset = apriori2(df2, min_support=0.1, use_colnames=True)
itemset


# itemset = association_rules(itemset, metric="confidence", min_threshold=0.1)
# itemset

# itemset.shape

# itemset3 = association_rules(itemset2, metric="lift", min_threshold=0.1)


# 조건이 손흥민
# zz = itemset[itemset['antecedents'].apply(lambda x : (keyword in x) & (len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x : (len(x) == 1))]


# 타겟이 손흥민
# zz = itemset[itemset['antecedents'].apply(lambda x : (len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x : (keyword in x) & (len(x) == 1))]


# 전체 데이터
# zz = itemset[itemset['antecedents'].apply(lambda x :(len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x :(len(x) == 1))]


# zz = itemset

# pd.set_option('display.max_rows', 1000)
# zz.sort_values(by=['support'], axis='index', ascending=False)

# zz

# %%
itemset2 = association_rules(itemset, metric="confidence", min_threshold=0.0001)
itemset2
# Out:
#       antecedents           consequents  antecedent support  \
# 0             (고)                 (가능성)            0.582240
# 1           (가능성)                   (고)            0.104464
# 2           (가능성)                  (대한)            0.104464
# 3            (대한)                 (가능성)            0.344437
# 4           (가능성)                   (말)            0.104464
# ...           ...                   ...                 ...
# 34675        (판정)   (진자, 명, 확진, 확, 코로나)            0.082429
# 34676         (명)  (진자, 판정, 확진, 확, 코로나)            0.299283
# 34677        (확진)   (진자, 판정, 명, 확, 코로나)            0.082618
# 34678         (확)  (진자, 판정, 명, 확진, 코로나)            0.119987
# 34679       (코로나)    (진자, 판정, 명, 확진, 확)            0.358309
#
#        consequent support   support  confidence       lift  leverage  \
# 0                0.104464  0.072379    0.124311   1.189996  0.011556
# 1                0.582240  0.072379    0.692864   1.189996  0.011556
# 2                0.344437  0.056148    0.537489   1.560484  0.020167
# 3                0.104464  0.056148    0.163014   1.560484  0.020167
# 4                0.472209  0.062235    0.595754   1.261632  0.012906
# ...                   ...       ...         ...        ...       ...
# 34675            0.063131  0.053128    0.644533  10.209449  0.047924
# 34676            0.060017  0.053128    0.177519   2.957805  0.035166
# 34677            0.058837  0.053128    0.643061  10.929460  0.048267
# 34678            0.053128  0.053128    0.442784   8.334251  0.046754
# 34679            0.054685  0.053128    0.148275   2.711423  0.033534
#
#        conviction
# 0        1.022665
# 1        1.360177
# 2        1.417399
# 3        1.069954
# 4        1.305619
# ...           ...
# 34675    2.635604
# 34676    1.142862
# 34677    2.636761
# 34678    1.699291
# 34679    1.109882
#
# [34680 rows x 9 columns]

# %%
# 조건이 키워드
keyword = '서울'
zz = itemset2[itemset2['antecedents'].apply(lambda x : (keyword in x) & (len(x) == 1))]
zz = zz[zz['consequents'].apply(lambda x : (len(x) == 1))]

pd.set_option('display.max_rows', 1000)
zz.sort_values(by=['lift','support','confidence'], axis='index', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-13439d067e24> in <module>
#       1 # 조건이 키워드
#       2 keyword = '서울'
# ----> 3 zz = itemset2[itemset2['antecedents'].apply(lambda x : (keyword in x) & (len(x) == 1))]
#       4 zz = zz[zz['consequents'].apply(lambda x : (len(x) == 1))]
#       5
#
# NameError: name 'itemset2' is not defined
