# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %% [markdown]
# ### 2.3.1 간단한 구현부터
# -----

# %%
def AND1(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1 * w1 + x2 * w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1
    
AND1(0,0) # 0
AND1(1,0) # 0
AND1(1,1) # 1
# Out:
# 1

# %% [markdown]
# ### 2.3.2 퍼셉트론 가중치 편향 도입
# -----

# %%
img = imread('img/3-1.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np
x = np.array([0, 1])
w = np.array([0.5, 0.5])
b = -0.7

w*x
# Out:
# array([0. , 0.5])

# %%
np.sum(w*x)
# Out:
# 0.5

# %%
np.sum(w*x)+b
# Out:
# -0.19999999999999996

# %% [markdown]
# ### 2.3.3 가중치와 편향 구현하기
# ------

# %%
def AND(x1, x2):
    
    x = np.array([x1, x2])   # 파라메터
    w = np.array([0.5, 0.5]) # 가중치
    b = -0.7                 # 편향값
    
    tmp = np.sum(x*w)+b

    if tmp <= 0 :
        return 0
    elif tmp > 0 :
        return 1
    

AND(1,1)
# Out:
# 1

# %%
def NAND(x1, x2):
    
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.7
    tmp = np.sum(x*w) + b
    if tmp <= 0:
        return 0
    elif tmp > 0:
        return 1
    

NAND(1,1)
# Out:
# 0

# %%
def OR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([0.5, 0.5])
    b = -0.2
    tmp = np.sum(x*w)+b
    if tmp <= 0:
        return 0
    elif tmp > 0:
        return 1
    

OR(0,0)
# Out:
# 0

# %%
OR(1,0)
# Out:
# 1

# %%
OR(1,1)
# Out:
# 1

# %%
def NOR(x1, x2):
    x = np.array([x1, x2])
    w = np.array([-0.5, -0.5])
    b = 0.2
    tmp = np.sum(x*w)+b
    if tmp <= 0:
        return 0
    elif tmp > 0:
        return 1
    

NOR(0,0)
# Out:
# 1

# %% [markdown]
# ### 2.5.2 XOR 게이트 구현하기
# -----

# %%
def XOR(x1, x2):
    s1 = OR(x1, x2)
    s2 = NAND(x1, x2)
    y = AND(s1, s2)
    return y

# %%
XOR(0, 1)
# Out:
# 1

# %%
img = imread('img/3-2.png')
plt.imshow(img)
plt.show()

# 뉴런을 이용한 XOR의 퍼센트론 표현
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-286e9b049bfb> in <module>
# ----> 1 img = imread('img/3-3.png')
#       2 plt.imshow(img)
#       3 plt.show()
#       4
#       5 # 뉴런을 이용한 XOR의 퍼센트론 표현
#
# ~\anaconda3\envs\test1\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# ~\anaconda3\envs\test1\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\envs\test1\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~\anaconda3\envs\test1\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/3-3.png'
