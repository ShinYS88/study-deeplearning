# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. 키워드 추출
#
# #### [2-1) 텍스트 데이터 전처리]

# %% [markdown]
# #### [2-2) KoNLPy를 이용한 키워드 추출 (형태소 분석기)]
# #### 한국어 약식 불용어 사전 사용 (http://ranks.nl/stopwords/korean)

# %%
# csv파일 불러오기
df = pd.read_csv('news_data_ori_0701_0705.csv')



from konlpy.tag import Okt
from collections import Counter
from IPython.display import clear_output
import time


korean_stopwords_path = './korean_stopwords.txt'
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]

nouns_cnt = 1
count_data = []


def get_nouns(data):
    global nouns_cnt, count_data
    
#     fchamgo = lambda x : x.split('/')
#     list(map(fchamgo,tmp_arr1, 1))   # map에 스칼라 숫자 전달
#     print(list(map(fchamgo,tmp_arr1)) )

    tmp_arr1 = data.split(' ')
    result_arr = []
    result_arr.extend([tmp1.split('/')[0] for tmp1 in tmp_arr1 if len(tmp1.split('/')) == 2 and 'NN' in tmp1.split('/')[1] ])
#     print([tmp1.split('/')[0] if len(tmp1.split('/')) == 2 and 'NN' in tmp1.split('/')[1] else 'd' for tmp1 in tmp_arr1 ])

    count_data.extend([x for x in result_arr])
#     count_data.extend([z for y in result_arr for z in y])

    clear_output(wait=True)
    per = round((nouns_cnt / df.shape[0])*100,3)
#     if per % 1 = 0 :
    print(f'형태소,불용어 제거중 .. {per} %')
    nouns_cnt+=1
    time.sleep(0.001)
    
    return result_arr

df.head()
# Out:
#                                                   본문  \
# 0   인천해양경찰서(서장 신동삼)는 도서 지역 치안 강화를 위해 인천 중부경찰서와 지난...
# 1   작년말 대비 두 배 가까이 늘어 지난달 26일 하룻새 4조 급증 SK바이오팜 청약...
# 2   ［중부매일 서인석 기자］ 이차영 괴산군수가 1일 열린 직원조회에서 민선 7기 2년...
# 3   라임자산운용(라임)의 1조6000억원 펀드 환매 중단 사건을 수사 중인 검찰이 1...
# 4   시모네타 소마루가 스위스 대통령 [EPA=연합뉴스 자료사진] . (제네바=연합뉴스...
#
#                                                  형태소
# 0   인천해양경찰/NNG 서/JKB (/SS 서장/NNG 신동삼/NNG )/SS 는/J...
# 1   작년/NNG 말/NNB 대비/NNG 두/MM 배/NNG 가까이/MAG 늘/VV 어...
# 2   ［/SL 중부매/NNG 이/VCP ㄹ/ETM 서인석/NNP 기자/NNG ］/SL ...
# 3   라임자산운/NNG 용/XSN (/SS 라임/NNG )/SS 의/JKG 1/SN 조...
# 4   시모네/NNG 하/XSA 다/EC 소마루/NNG 가/JKS 스위스/NNP 대통령/...

# %%
# df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
df['nouns'] = df['형태소'].apply(lambda x: get_nouns(x))
print(df.shape)
df.head()
# Out:
# 형태소,불용어 제거중 .. 100.0 %
# (21194, 3)
#                                                   본문  \
# 0   인천해양경찰서(서장 신동삼)는 도서 지역 치안 강화를 위해 인천 중부경찰서와 지난...
# 1   작년말 대비 두 배 가까이 늘어 지난달 26일 하룻새 4조 급증 SK바이오팜 청약...
# 2   ［중부매일 서인석 기자］ 이차영 괴산군수가 1일 열린 직원조회에서 민선 7기 2년...
# 3   라임자산운용(라임)의 1조6000억원 펀드 환매 중단 사건을 수사 중인 검찰이 1...
# 4   시모네타 소마루가 스위스 대통령 [EPA=연합뉴스 자료사진] . (제네바=연합뉴스...
#
#                                                  형태소  \
# 0   인천해양경찰/NNG 서/JKB (/SS 서장/NNG 신동삼/NNG )/SS 는/J...
# 1   작년/NNG 말/NNB 대비/NNG 두/MM 배/NNG 가까이/MAG 늘/VV 어...
# 2   ［/SL 중부매/NNG 이/VCP ㄹ/ETM 서인석/NNP 기자/NNG ］/SL ...
# 3   라임자산운/NNG 용/XSN (/SS 라임/NNG )/SS 의/JKG 1/SN 조...
# 4   시모네/NNG 하/XSA 다/EC 소마루/NNG 가/JKS 스위스/NNP 대통령/...
#
#                                                nouns
# 0  [인천해양경찰, 서장, 신동삼, 도서, 지역, 치안, 강화, 인천, 중부경찰서, 지...
# 1  [작년, 말, 대비, 배, 지난달, 일, 하룻새, 조, 급증, 바이오팜, 청약, 뭉...
# 2  [중부매, 서인석, 기자, 이차영, 괴산군수, 일, 직원조회, 민선, 기, 년, 군...
# 3  [라임자산운, 라임, 조, 원, 펀드, 환매, 중단, 사건, 수사, 중, 검찰, 일...
# 4  [시모네, 소마루, 스위스, 대통령, 연합뉴스, 자료사진, 제네바, 연합뉴스, 임은...

# %%
#빈도 수 구하기.

# count_data = [y for x in df['nouns'].tolist() for y in x]

from collections import Counter
count = Counter(count_data)

node_df = pd.DataFrame(count.items(), columns=['node', 'nodesize'])
# node_df = node_df[node_df['nodesize'] >= 50]

# 형태소 데이터 / csv파일로 저장
df.to_csv('save/tmp_data3.csv', index=False)
# 카운트 데이터 / csv파일로 저장
node_df.to_csv('save/tmp_count3.csv', index=False)

node_df.head()
# Out:
#      node  nodesize
# 0  인천해양경찰         5
# 1      서장       201
# 2     신동삼         2
# 3      도서       108
# 4      지역      7375

# %%
from ast import literal_eval

# literal_eval이 기본 자료형만
# eval은 모든 스트링을 코드화

df = pd.read_csv('save/tmp_data3.csv',  converters={'nouns': literal_eval})
# df = pd.read_csv('save/tmp_data2.csv', converters={'nouns': eval})
node_df = pd.read_csv('save/tmp_count3.csv')

# %% [markdown]
# ## 3. 연관 키워드 추출하기

# %% [markdown]
# ### [트위터 연관 키워드 분석]

# %%
transactions = df['nouns'].tolist()
transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지합니다.and
# transactions

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori as apriori2
from mlxtend.frequent_patterns import association_rules

te = TransactionEncoder()
te_result = te.fit(transactions).transform(transactions)

print(te_result.shape[0]*te_result.shape[1])
# Out:
# 2666989378

# %%
df2 = pd.DataFrame(te_result, columns=te.columns_)
print(df2)
print('======================')
df2['확진'].sum()
# Out:
#        가길래  가사처럼  가장  가지도  간호사님한테    갈  갈거라는  \
# 0        False      False  False   False           False  False       False
# 1        False      False  False   False           False  False       False
# 2        False      False  False   False           False  False       False
# 3        False      False  False   False           False  False       False
# 4        False      False  False   False           False  False       False
# ...        ...        ...    ...     ...             ...    ...         ...
# 21189    False      False  False   False           False  False       False
# 21190    False      False  False   False           False  False       False
# 21191    False      False  False   False           False  False       False
# 21192    False      False  False   False           False  False       False
# 21193    False      False  False   False           False  False       False
#
#        감았을때  갔는데  같다  ...    힙시트     힙입     힙합    힙합감    힙합걸  \
# 0            False     False  False  ...  False  False  False  False  False
# 1            False     False  False  ...  False  False  False  False  False
# 2            False     False  False  ...  False  False  False  False  False
# 3            False     False  False  ...  False  False  False  False  False
# 4            False     False  False  ...  False  False  False  False  False
# ...            ...       ...    ...  ...    ...    ...    ...    ...    ...
# 21189        False     False  False  ...  False  False  False  False  False
# 21190        False     False  False  ...  False  False  False  False  False
# 21191        False     False  False  ...  False  False  False  False  False
# 21192        False     False  False  ...  False  False  False  False  False
# 21193        False     False  False  ...  False  False  False  False  False
#
#          힙합곡    힙합신    힙합씬    힙합축      힛
# 0      False  False  False  False  False
# 1      False  False  False  False  False
# 2      False  False  False  False  False
# 3      False  False  False  False  False
# 4      False  False  False  False  False
# ...      ...    ...    ...    ...    ...
# 21189  False  False  False  False  False
# 21190  False  False  False  False  False
# 21191  False  False  False  False  False
# 21192  False  False  False  False  False
# 21193  False  False  False  False  False
#
# [21194 rows x 125837 columns]
# ======================
# 2574

# %%
# keyword = '손흥민'

df2 = pd.DataFrame(te_result, columns=te.columns_)

itemset = apriori2(df2, min_support=0.05, use_colnames=True)
itemset


# itemset = association_rules(itemset, metric="confidence", min_threshold=0.1)
# itemset

# itemset.shape

# itemset3 = association_rules(itemset2, metric="lift", min_threshold=0.1)


# 조건이 손흥민
# zz = itemset[itemset['antecedents'].apply(lambda x : (keyword in x) & (len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x : (len(x) == 1))]


# 타겟이 손흥민
# zz = itemset[itemset['antecedents'].apply(lambda x : (len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x : (keyword in x) & (len(x) == 1))]


# 전체 데이터
# zz = itemset[itemset['antecedents'].apply(lambda x :(len(x) == 1))]
# zz = zz[zz['consequents'].apply(lambda x :(len(x) == 1))]


# zz = itemset

# pd.set_option('display.max_rows', 1000)
# zz.sort_values(by=['support'], axis='index', ascending=False)

# zz

# %%
itemset2 = association_rules(itemset, metric="confidence", min_threshold=0.0001)
itemset2

# %%
# 연관키워드 알고리즘 데이터 csv저장
itemset2.to_csv('save/tmp_last3.csv', index=False)

# %%
# load파일
itemset2 = pd.read_csv('save/tmp_last3.csv', converters={'antecedents': eval, 'consequents': eval})
itemset2.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0        (가능)         (개)            0.186421            0.218741  0.051194
# 1         (개)        (가능)            0.218741            0.186421  0.051194
# 2         (것)        (가능)            0.702982            0.186421  0.157167
# 3        (가능)         (것)            0.186421            0.702982  0.157167
# 4        (가능)        (결과)            0.186421            0.189629  0.052185
#
#    confidence      lift  leverage  conviction
# 0    0.274614  1.255429  0.010416    1.077025
# 1    0.234038  1.255429  0.010416    1.062167
# 2    0.223572  1.199288  0.026117    1.047849
# 3    0.843078  1.199288  0.026117    1.892771
# 4    0.279929  1.476193  0.016834    1.125404

# %%
# 조건이 키워드
keyword = '코로나'

# 조건과 결과 1개씩만
zz = itemset2[itemset2['antecedents'].apply(lambda x : (keyword in x) & (len(x) == 1))]
zz = zz[zz['consequents'].apply(lambda x : (len(x) == 1))]

#카운트 추가
node_df = pd.read_csv('save/tmp_count3.csv')
def getcount(data) :
    return node_df[node_df['node'].apply(lambda x : data == frozenset({x}))]['nodesize'].values[0]

def getcount_news(data) :
    return df2[next(iter(data))].sum()

zz['출현_카운트'] = zz['consequents'].apply(lambda x : getcount(x))
zz['뉴스_카운트'] = zz['consequents'].apply(lambda x : getcount_news(x))

# iat는 한개의 값만 사용할 수 있고 iloc나 loc는 슬라이싱 해서도 사용할 수 있다
# 슬라이싱 하면 결과가 문자값만 나오는게 아니라서 안예쁘지만

# node_df[node_df['node'].apply(lambda x : '의원' == x)]['nodesize'].iat[0]
# node_df[node_df['node'].apply(lambda x : '의원' == x)]['nodesize'].iloc[0]
# node_df[node_df['node'].apply(lambda x : '의원' == x)]['nodesize'].values[0]



pd.set_option('display.max_rows', 1000)
zz.sort_values(by=['lift','출현_카운트','support','confidence'], axis='index', ascending=False)
# Out:
#      antecedents consequents  antecedent support  consequent support  \
# 148        (코로나)       (감염증)            0.357129            0.106398
# 3984       (코로나)   (코로나바이러스)            0.357129            0.100359
# 3238       (코로나)        (신종)            0.357129            0.112202
# 3998       (코로나)        (확진)            0.357129            0.121449
# 2668       (코로나)        (방역)            0.357129            0.064028
# 124        (코로나)        (감염)            0.357129            0.082995
# 3986       (코로나)        (판정)            0.357129            0.077852
# 3872       (코로나)        (접촉)            0.357129            0.064877
# 3994       (코로나)        (확산)            0.357129            0.108380
# 4000       (코로나)        (환자)            0.357129            0.068227
# 2800       (코로나)        (사태)            0.357129            0.085685
# 3476       (코로나)        (위기)            0.357129            0.076720
# 292        (코로나)        (검사)            0.357129            0.099509
# 3848       (코로나)         (자)            0.357129            0.188685
# 2806       (코로나)        (사회)            0.357129            0.087383
# 2656       (코로나)        (방문)            0.357129            0.082335
# 1728       (코로나)        (대응)            0.357129            0.091347
# 2636       (코로나)        (발생)            0.357129            0.176088
# 3980       (코로나)        (추가)            0.357129            0.155374
# 3344       (코로나)        (우려)            0.357129            0.103001
# 3952       (코로나)        (지원)            0.357129            0.138766
# 3950       (코로나)        (지역)            0.357129            0.185383
# 1202       (코로나)        (국내)            0.357129            0.105737
# 2546       (코로나)         (명)            0.357129            0.338350
# 3940       (코로나)       (지난달)            0.357129            0.207889
# 1392       (코로나)        (기준)            0.357129            0.121214
# 3996       (코로나)        (확인)            0.357129            0.153723
# 3330       (코로나)        (올해)            0.357129            0.134708
# 2864       (코로나)        (상황)            0.357129            0.241719
# 3352       (코로나)        (운영)            0.357129            0.116165
# 3306       (코로나)        (오전)            0.357129            0.128810
# 3974       (코로나)         (초)            0.357129            0.156978
# 3976       (코로나)        (최근)            0.357129            0.185571
# 2692       (코로나)         (번)            0.357129            0.169246
# 90         (코로나)       (가운데)            0.357129            0.179296
# 3988       (코로나)        (포함)            0.357129            0.126168
# 3962       (코로나)        (진행)            0.357129            0.252477
# 3970       (코로나)         (차)            0.357129            0.175710
# 3626       (코로나)        (이후)            0.357129            0.242144
# 1718       (코로나)        (대상)            0.357129            0.154997
# 3186       (코로나)         (시)            0.357129            0.290648
# 3972       (코로나)        (참여)            0.357129            0.119987
# 3878       (코로나)        (정부)            0.357129            0.182599
# 832        (코로나)        (결과)            0.357129            0.189629
# 2274       (코로나)        (마련)            0.357129            0.120883
# 3294       (코로나)        (예정)            0.357129            0.208266
# 240        (코로나)         (개)            0.357129            0.218741
# 3992       (코로나)        (현재)            0.357129            0.198735
# 50         (코로나)        (가능)            0.357129            0.186421
# 1686       (코로나)         (대)            0.357129            0.235774
# 2294       (코로나)         (만)            0.357129            0.126404
# 3218       (코로나)        (시작)            0.357129            0.169057
# 3532       (코로나)        (이날)            0.357129            0.319241
# 958        (코로나)        (계획)            0.357129            0.173587
# 3914       (코로나)         (중)            0.357129            0.417713
# 2122       (코로나)         (등)            0.357129            0.717090
# 912        (코로나)        (경우)            0.357129            0.179296
# 1036       (코로나)       (관계자)            0.357129            0.182552
# 3990       (코로나)        (필요)            0.357129            0.170520
# 3382       (코로나)         (원)            0.357129            0.232990
# 3584       (코로나)        (이상)            0.357129            0.182882
# 3458       (코로나)         (월)            0.357129            0.435925
# 2652       (코로나)        (발표)            0.357129            0.132302
# 3264       (코로나)         (앞)            0.357129            0.152638
# 2260       (코로나)        (때문)            0.357129            0.178494
# 3572       (코로나)        (이번)            0.357129            0.266207
# 2922       (코로나)        (설명)            0.357129            0.163018
# 3772       (코로나)         (일)            0.357129            0.900491
# 3318       (코로나)        (오후)            0.357129            0.174672
# 728        (코로나)         (것)            0.357129            0.702982
# 3870       (코로나)         (점)            0.357129            0.143956
# 3096       (코로나)         (수)            0.357129            0.567378
# 1822       (코로나)         (뒤)            0.357129            0.173445
# 2898       (코로나)        (서울)            0.357129            0.194772
# 2458       (코로나)         (말)            0.357129            0.475229
# 2722       (코로나)         (분)            0.357129            0.166226
# 1146       (코로나)        (관련)            0.357129            0.283429
# 2764       (코로나)        (사람)            0.357129            0.163537
# 1360       (코로나)        (기자)            0.357129            0.316977
# 2220       (코로나)         (때)            0.357129            0.215155
# 1570       (코로나)         (년)            0.357129            0.407474
#
#        support  confidence      lift  leverage  conviction  출현_카운트  뉴스_카운트
# 148   0.105266    0.294755  2.770304  0.067268    1.267080    2464    2255
